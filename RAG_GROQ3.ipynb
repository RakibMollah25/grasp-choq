# %%
# %pip install --upgrade --quiet  langchain langchain-community langchain-openai langchain-experimental neo4j wikipedia tiktoken yfiles_jupyter_graphs
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install --upgrade --quiet  langchain langchain-community langchain-groq neo4j
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Start

# %%
from langchain_core.runnables import (
    RunnableBranch,
    RunnableLambda,
    RunnableParallel,
    RunnablePassthrough,
)
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts.prompt import PromptTemplate
from typing import Tuple, List, Optional
from langchain_core.messages import AIMessage, HumanMessage
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import ConfigurableField
from yfiles_jupyter_graphs import GraphWidget
from neo4j import GraphDatabase

from langchain_community.vectorstores import Neo4jVector
from dotenv import load_dotenv
load_dotenv()
import os

# %%
# os.environ["OPENAI_API_KEY_PAPER"] = OPENAI_API_KEY
# OPENAI_API_KEY = os.getenv("OPENAI_API_KEY_PAPER")

NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USERNAME = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")

# os.environ["NEO4J_URI"] = NEO4J_URI
# os.environ["NEO4J_USERNAME"] = NEO4J_USERNAME
# os.environ["NEO4J_PASSWORD"] = NEO4J_PASSWORD
from langchain_community.graphs import Neo4jGraph
graph = Neo4jGraph()

# %% [markdown]
# # Scrape from Wikipedia

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import nltk

# Download required NLTK data
nltk.download('stopwords')

def generate_wordcloud_from_excel(excel_file, column_name):
    """
    Generate a word cloud from an Excel column while removing stop words.
    
    Parameters:
    excel_file (str): Path to the Excel file
    column_name (str): Name of the column containing text data
    """
    # Read the Excel file
    df = pd.read_excel(excel_file)
    
    # Combine all text from the column into a single string
    text = ' '.join(df[column_name].astype(str).values)
    
    # Get English stop words
    stop_words = set(stopwords.words('english'))
    
    # Create and configure the WordCloud object
    wordcloud = WordCloud(
        width=800,
        height=400,
        background_color='white',
        stopwords=stop_words,
        min_font_size=10,
        max_font_size=150,
        random_state=42
    )
    
    # Generate the word cloud
    wordcloud.generate(text)
    
    # Display the word cloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.tight_layout(pad=0)
    plt.show()
    
    # Save the word cloud to a file
    wordcloud.to_file('wordcloud.png')

# Example usage
if __name__ == "__main__":
    # Replace these with your actual file path and column name
    excel_file = r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\all_embedding.xlsx"
    column_name = "translation"
    
    generate_wordcloud_from_excel(excel_file, column_name)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
import nltk

# Download required NLTK data
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

def remove_verbs_and_stopwords(text):
    """
    Remove verbs and stopwords from the text.
    Returns cleaned text as a single string.
    """
    # Tokenize and tag parts of speech
    tokens = word_tokenize(text.lower())
    tagged = pos_tag(tokens)
    
    # Get stop words
    stop_words = set(stopwords.words('english'))
    
    # Keep words that are not verbs (don't start with 'V') and not stopwords
    cleaned_words = [word for word, tag in tagged 
                    if not tag.startswith('V') 
                    and word.isalnum()
                    and word not in stop_words]
    
    return ' '.join(cleaned_words)

def generate_wordcloud_from_excel(excel_file, column_name):
    """
    Generate a word cloud from an Excel column while removing verbs and stop words.
    
    Parameters:
    excel_file (str): Path to the Excel file
    column_name (str): Name of the column containing text data
    """
    # Read the Excel file
    df = pd.read_excel(excel_file)
    
    # Combine all text from the column into a single string
    text = ' '.join(df[column_name].astype(str).values)
    
    # Clean the text by removing verbs and stopwords
    cleaned_text = remove_verbs_and_stopwords(text)
    
    # Create and configure the WordCloud object
    wordcloud = WordCloud(
        width=800,
        height=400,
        background_color='white',
        min_font_size=10,
        max_font_size=150,
        random_state=42
    )
    
    # Generate the word cloud
    wordcloud.generate(cleaned_text)
    
    # Display the word cloud
    plt.figure(figsize=(6, 4))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.tight_layout(pad=0)
    plt.show()
    
    # Save the word cloud to a file
    wordcloud.to_file('wordcloud.png')

# Example usage
if __name__ == "__main__":
    # Replace these with your actual file path and column name
    excel_file = r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\all_embedding.xlsx"
    column_name = "translation"
    
    generate_wordcloud_from_excel(excel_file, column_name)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
from langchain.document_loaders import WikipediaLoader
raw_documents = WikipediaLoader(query="bangladesh student uprising of july 2024").load()
raw_documents

# %%
len(raw_documents)
# Out:
# 25

# %%
from langchain.text_splitter import TokenTextSplitter
# text_splitter = TokenTextSplitter(chunk_size=512, chunk_overlap=24)
text_splitter = TokenTextSplitter(chunk_size=256, chunk_overlap=50)
documents = text_splitter.split_documents(raw_documents)


print(len(documents))
documents

# %%
import tiktoken

MAX_TOKENS = 20000

def token_count(messages):
    """Calculate the number of tokens in the messages."""
    enc = tiktoken.get_encoding("cl100k_base")  # Use the encoding that matches your model
    total_tokens = 0
    for message in messages:
        total_tokens += len(enc.encode(message))
    return total_tokens


for doc in documents_list:
    print(token_count(str(doc)))

# %% [markdown]
# # Groq

# %%
# from langchain_groq import ChatGroq

# groq_api_key = os.getenv("groq_api_key")
# # llm=ChatGroq(groq_api_key=groq_api_key,model_name="gemma2-9b-it")
# # llm=ChatGroq(groq_api_key=groq_api_key,model_name="llama-3.1-8b-instant")
# llm=ChatGroq(groq_api_key=groq_api_key,model_name="llama-3.3-70b-versatile")



# llm


import os
from langchain_mistralai import ChatMistralAI

# Retrieve the API key from environment variables
mistral_api_key = os.getenv("MISTRAL_API_KEY")

# Initialize the LLM instance with the desired model
llm = ChatMistralAI(mistral_api_key=mistral_api_key, model_name="mistral-large-latest", max_retries=50)

llm
# Out:
# ChatMistralAI(client=<httpx.Client object at 0x00000178C9260890>, async_client=<httpx.AsyncClient object at 0x00000178C6B833E0>, mistral_api_key=SecretStr('**********'), endpoint='https://api.mistral.ai/v1', max_retries=50, model='mistral-large-latest')

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
llm_transformer = LLMGraphTransformer(llm=llm)

# %%
print(documents[0].page_content)
documents[0].page_content = f'''However in 2021, seven children of freedom fighters, including Ahidul Islam, filed a writ petition in the High Court challenging this decision. Finally, on 5 June 2024, a High Court bench of Justice KM Kamrul Quader and Justice Khizir Hayat declared the decision to scrap the quota system invalid. Immediately after the announcement of the verdict, students started protesting against this verdict in various universities of the country.

The movement became more intense in July, with students staging blockades including the "Bangla Blockade". During this time, police used excessive force to quell the agitation led to clashes and a student named Abu Sayed was shot dead by the police in Rangpur. This incident intensified the movement and increased tension across the country.[29]'''

print(documents[0].page_content)

# %%
documents[0]
# Out:
# Document(metadata={'title': "Students–People's uprising (Bangladesh)", 'summary': "The Students–People's uprising, also known as the July Revolution, was a pro-democracy mass uprising in Bangladesh. It began as a quota reform movement in early June 2024, led by the Anti-discrimination Students Movement, after the Bangladesh Supreme Court invalidated the government's 2018 circular regarding job quotas in the public sector. The movement escalated into a full-fledged mass uprising after the government carried out mass killings of protesters, known as the July massacre, by late July. By early August, the movement evolved into a non-cooperation movement, ultimately leading to the ouster of the then-prime minister, Sheikh Hasina, who fled Bangladesh to India. Hasina's ouster triggered a constitutional crisis, leading to the formation of an interim government led by the country's only Nobel laureate, Muhammad Yunus, as the chief adviser.", 'source': 'https://en.wikipedia.org/wiki/Students%E2%80%93People%27s_uprising_(Bangladesh)'}, page_content='However in 2021, seven children of freedom fighters, including Ahidul Islam, filed a writ petition in the High Court challenging this decision. Finally, on 5 June 2024, a High Court bench of Justice KM Kamrul Quader and Justice Khizir Hayat declared the decision to scrap the quota system invalid. Immediately after the announcement of the verdict, students started protesting against this verdict in various universities of the country.\n\nThe movement became more intense in July, with students staging blockades including the "Bangla Blockade". During this time, police used excessive force to quell the agitation led to clashes and a student named Abu Sayed was shot dead by the police in Rangpur. This incident intensified the movement and increased tension across the country.[29]')

# %%
graph_documents = llm_transformer.convert_to_graph_documents([documents[0]])
graph_documents
# Out:
# [GraphDocument(nodes=[Node(id='Ahidul Islam', type='Person', properties={}), Node(id='Writ Petition', type='Event', properties={}), Node(id='High Court', type='Organization', properties={}), Node(id='K M Kamrul Quader', type='Person', properties={}), Node(id='Khizir Hayat', type='Person', properties={}), Node(id='Quota System', type='Concept', properties={}), Node(id='Students', type='Group', properties={}), Node(id='Universities', type='Organization', properties={}), Node(id='Bangla Blockade', type='Event', properties={}), Node(id='Police', type='Organization', properties={}), Node(id='Abu Sayed', type='Person', properties={}), Node(id='Rangpur', type='Location', properties={})], relationships=[Relationship(source=Node(id='Ahidul Islam', type='Person', properties={}), target=Node(id='Writ Petition', type='Event', properties={}), type='FILED', properties={}), Relationship(source=Node(id='Ahidul Islam', type='Person', properties={}), target=Node(id='High Court', type='Organization', properties={}), type='FILED', properties={}), Relationship(source=Node(id='K M Kamrul Quader', type='Person', properties={}), target=Node(id='High Court', type='Organization', properties={}), type='DECLARED', properties={}), Relationship(source=Node(id='Khizir Hayat', type='Person', properties={}), target=Node(id='High Court', type='Organization', properties={}), type='DECLARED', properties={}), Relationship(source=Node(id='High Court', type='Organization', properties={}), target=Node(id='Quota System', type='Concept', properties={}), type='DECLARED', properties={}), Relationship(source=Node(id='Students', type='Group', properties={}), target=Node(id='Universities', type='Organization', properties={}), type='PROTESTED', properties={}), Relationship(source=Node(id='Students', type='Group', properties={}), target=Node(id='Bangla Blockade', type='Event', properties={}), type='STAGED', properties={}), Relationship(source=Node(id='Police', type='Organization', properties={}), target=Node(id='Students', type='Group', properties={}), type='USED_FORCE', properties={}), Relationship(source=Node(id='Police', type='Organization', properties={}), target=Node(id='Abu Sayed', type='Person', properties={}), type='KILLED', properties={}), Relationship(source=Node(id='Police', type='Organization', properties={}), target=Node(id='Rangpur', type='Location', properties={}), type='KILLED', properties={})], source=Document(metadata={'title': "Students–People's uprising (Bangladesh)", 'summary': "The Students–People's uprising, also known as the July Revolution, was a pro-democracy mass uprising in Bangladesh. It began as a quota reform movement in early June 2024, led by the Anti-discrimination Students Movement, after the Bangladesh Supreme Court invalidated the government's 2018 circular regarding job quotas in the public sector. The movement escalated into a full-fledged mass uprising after the government carried out mass killings of protesters, known as the July massacre, by late July. By early August, the movement evolved into a non-cooperation movement, ultimately leading to the ouster of the then-prime minister, Sheikh Hasina, who fled Bangladesh to India. Hasina's ouster triggered a constitutional crisis, leading to the formation of an interim government led by the country's only Nobel laureate, Muhammad Yunus, as the chief adviser.", 'source': 'https://en.wikipedia.org/wiki/Students%E2%80%93People%27s_uprising_(Bangladesh)'}, page_content='However in 2021, seven children of freedom fighters, including Ahidul Islam, filed a writ petition in the High Court challenging this decision. Finally, on 5 June 2024, a High Court bench of Justice KM Kamrul Quader and Justice Khizir Hayat declared the decision to scrap the quota system invalid. Immediately after the announcement of the verdict, students started protesting against this verdict in various universities of the country.\n\nThe movement became more intense in July, with students staging blockades including the "Ba ...

# %%
#   Nodes Table
# Node ID	Type	Properties
# Ahidul Islam	Person	N/A
# Writ Petition	Event	N/A
# High Court	Organization	N/A
# K M Kamrul Quader	Person	N/A
# Khizir Hayat	Person	N/A
# Quota System	Concept	N/A
# Students	Group	N/A
# Universities	Organization	N/A
# Bangla Blockade	Event	N/A
# Police	Organization	N/A
# Abu Sayed	Person	N/A
# Rangpur	Location	N/A

# Relationships Table
# Source Node	Relationship Type	Target Node	Properties
# Ahidul Islam	FILED	Writ Petition	N/A
# Ahidul Islam	FILED	High Court	N/A
# K M Kamrul Quader	DECLARED	High Court	N/A
# Khizir Hayat	DECLARED	High Court	N/A
# High Court	DECLARED	Quota System	N/A
# Students	PROTESTED	Universities	N/A
# Students	STAGED	Bangla Blockade	N/A
# Police	USED_FORCE	Students	N/A
# Police	KILLED	Abu Sayed	N/A
# Police	KILLED	Rangpur	N/A

# %%
graph.add_graph_documents(
    graph_documents,
    baseEntityLabel=True,
    include_source=True
)

# %% [markdown]
# # openai

# %%
import tiktoken
import time

MAX_TOKENS = 20000

def token_count(messages):
    """Calculate the number of tokens in the messages."""
    enc = tiktoken.get_encoding("cl100k_base")  # Use the encoding that matches your model
    total_tokens = 0
    for message in messages:
        total_tokens += len(enc.encode(message))
    return total_tokens

for doc in documents[56:]:
    print(token_count(str(doc)))
    # print(doc)
    graph_documents = llm_transformer.convert_to_graph_documents([doc])
    graph.add_graph_documents(
    graph_documents,
    baseEntityLabel=True,
    include_source=True
    )
    time.sleep(5)

# %%
# directly show the graph resulting from the given Cypher query
# default_cypher = "MATCH (s)-[r:!MENTIONS]->(t) RETURN s,r,t LIMIT 50"
default_cypher = "MATCH (s)-[r:!MENTIONS]->(t) RETURN s,r,t"

# default_cypher = '''MATCH (s)-[r:!MENTIONS]->(t)
# WHERE (ID(s) CONTAINS 'islam' OR ID(t) CONTAINS 'islam')
# RETURN s, r, t LIMIT 50'''

# %%
from yfiles_jupyter_graphs import GraphWidget
from neo4j import GraphDatabase
def showGraph(cypher: str = default_cypher):
    # create a neo4j session to run queries
    driver = GraphDatabase.driver(
        uri = os.environ["NEO4J_URI"],
        auth = (os.environ["NEO4J_USERNAME"],
                os.environ["NEO4J_PASSWORD"]))
    session = driver.session()
    widget = GraphWidget(graph = session.run(cypher).graph())
    widget.node_label_mapping = 'id'
    display(widget)
    return widget
# showGraph()

# %%
from typing import Tuple, List, Optional
from langchain_community.vectorstores import Neo4jVector

# %%
# %pip install sentence-transformers

# %% [markdown]
# # Embedding

# %%
graph.query("MATCH (n:Document) REMOVE n.embedding")
# Out:
# []

# %%
# groq_api_key = os.getenv("groq_api_key")

# groq_llm = ChatGroq(
#     groq_api_key=groq_api_key,
#     # model_name="Gemma2-9b-It"
#     model_name='llama-3.3-70b-versatile'
# )
# from langchain_groq import ChatGroq
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Neo4jVector


# embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# from langchain_mistralai import MistralAIEmbeddings

# embeddings = MistralAIEmbeddings(
#     model="mistral-embed",
# )


# Create a vector store instance from the existing graph
vector_index = Neo4jVector.from_existing_graph(
    embeddings,
    search_type="hybrid",
    node_label="Document",
    text_node_properties=["text"],
    embedding_node_property="embedding"
)
# vector_index = Neo4jVector.from_existing_graph(
#     embeddings,
#     search_type="hybrid",
#     node_label="Document",
#     text_node_properties=["text"],
#     embedding_node_property="embedding_mistral",  # New property for Mistral embeddings
#     index_name="mistral_vector" # Create a new index for the Mistral embeddings

# )
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_51672\808670806.py:14: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# f:\EUCLIDO\Tasks\.venv8\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# f:\EUCLIDO\Tasks\.venv8\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
graph.query("CREATE FULLTEXT INDEX entity IF NOT EXISTS FOR (e:__Entity__) ON EACH [e.id]")
# Out:
# []

# %%
import pandas as pd
result = graph.query("""
MATCH (e:__Entity__)
RETURN e.id AS id
""")

# Fetch results
data = [{"id": record["id"]} for record in result]

# Save to Excel
df = pd.DataFrame(data)
file_name = r"F:\EUCLIDO\Tasks\knowledge_graph\all dataset\id_wiki.xlsx"
df.to_excel(file_name, index=False)
print(f"Data saved to {file_name}")
# Out:
# Data saved to F:\EUCLIDO\Tasks\knowledge_graph\all dataset\id_wiki.xlsx

# %% [markdown]
# # Structured data retrieve

# %%
from langchain_core.pydantic_v1 import BaseModel, Field
# Extract entities from text
class Entities(BaseModel):
    """Identifying information about entities."""

    names: List[str] = Field(
        ...,
        description="All the person, organization, or business entities that "
        "appear in the text",
    )

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts.prompt import PromptTemplate
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are extracting organization and person entities from the text.",
        ),
        (
            "human",
            "Use the given format to extract information from the following "
            "input: {question}",
        ),
    ]
)
entity_chain = prompt | llm.with_structured_output(Entities)
entity_chain.invoke({"question": "Where was Amelia Earhart born?"}).names
from langchain_community.vectorstores.neo4j_vector import remove_lucene_chars
def generate_full_text_query(input: str) -> str:
    full_text_query = ""
    words = [el for el in remove_lucene_chars(input).split() if el]
    for word in words[:-1]:
        full_text_query += f" {word}~2 AND"
    full_text_query += f" {words[-1]}~2"
    return full_text_query.strip()

# Fulltext index query
def structured_retriever(question: str) -> str:
    time.sleep(.5)
    result = ""
    # question = f'Awami League - {question}'

    entities = entity_chain.invoke({"question": question})
    for entity in entities.names:
        response = graph.query(
            """CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})
            YIELD node,score
            CALL {
              WITH node
              MATCH (node)-[r:!MENTIONS]->(neighbor)
              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output
              UNION ALL
              WITH node
              MATCH (node)<-[r:!MENTIONS]-(neighbor)
              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output
            }
            RETURN output LIMIT 50
            """,
            {"query": generate_full_text_query(entity)},
        )

 



        result += "\n".join([el['output'] for el in response])
    return result
# Out:
# f:\EUCLIDO\Tasks\.venv8\Lib\site-packages\IPython\core\interactiveshell.py:3577: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
entities = entity_chain.invoke({"question": "The illegal Yunos government wants to erase all the history of the establishment of Bangladesh by pressing the reset button. #StepDownYunus #SheikhMujib #FatheroftheNation #Bangladesh"})
for entity in entities.names:
    print(entity)
# Out:
# Yunos
# Sheikh Mujib
# Bangladesh

# %%
# print(structured_retriever("bnp"))
# print(structured_retriever(text))
import time
text = 'Hasina Yunus July'
relational_text = structured_retriever(text)
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (node, node) { ... }} {position: line: 3, column: 13, offset: 104} for query: "CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})\n            YIELD node,score\n            CALL {\n              WITH node\n              MATCH (node)-[r:!MENTIONS]->(neighbor)\n              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output\n              UNION ALL\n              WITH node\n              MATCH (node)<-[r:!MENTIONS]-(neighbor)\n              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output\n            }\n            RETURN output LIMIT 50\n            "

# %%
print(relational_text)

# %%
token_count(retriever(text))
# Out:
# Search query: hasina
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (node, node, node, node) { ... }} {position: line: 4, column: 13, offset: 118} for query: "\n            CALL db.index.fulltext.queryNodes('entity', $query, {limit:4})\n            YIELD node, score\n            CALL {\n            WITH node\n            MATCH (node)-[r:ALLY]->(ally)\n            RETURN 'Ally: ' + node.id + ' - ' + type(r) + ' -> ' + ally.id AS output\n            UNION ALL\n            WITH node\n            MATCH (node)<-[r:ALLY]-(ally)\n            RETURN 'Ally: ' + ally.id + ' - ' + type(r) + ' -> ' + node.id AS output\n            UNION ALL\n            WITH node\n            MATCH (node)-[r:OPPOSITION]->(opposition)\n            RETURN 'Opposition: ' + node.id + ' - ' + type(r) + ' -> ' + opposition.id AS output\n            UNION ALL\n            WITH node\n            MATCH (node)<-[r:OPPOSITION]-(opposition)\n            RETURN 'Opposition: ' + opposition.id + ' - ' + type(r) + ' -> ' + node.id AS output\n            }\n            RETURN output LIMIT 50\n            "
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL () { ... }} {position: line: 1, column: 1, offset: 0} for query: "CALL { CALL db.index.vector.queryNodes($index, $k, $embedding) YIELD node, score WITH collect({node:node, score:score}) AS nodes, max(score) AS max UNWIND nodes AS n RETURN n.node AS node, (n.score / max) AS score UNION CALL db.index.fulltext.queryNodes($keyword_index, $query, {limit: $k}) YIELD node, score WITH collect({node:node, score:score}) AS nodes, max(score) AS max UNWIND nodes AS n RETURN n.node AS node, (n.score / max) AS score } WITH node, max(score) AS score ORDER BY score DESC LIMIT $k RETURN reduce(str='', k IN ['text'] | str + '\\n' + k + ': ' + coalesce(node[k], '')) AS text, node {.*, `embedding`: Null, id: Null, `text`: Null} AS metadata, score"
# 10033

# %%
unstructured_data = [el.page_content for el in vector_index.similarity_search('hasina')]
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL () { ... }} {position: line: 1, column: 1, offset: 0} for query: "CALL { CALL db.index.vector.queryNodes($index, $k, $embedding) YIELD node, score WITH collect({node:node, score:score}) AS nodes, max(score) AS max UNWIND nodes AS n RETURN n.node AS node, (n.score / max) AS score UNION CALL db.index.fulltext.queryNodes($keyword_index, $query, {limit: $k}) YIELD node, score WITH collect({node:node, score:score}) AS nodes, max(score) AS max UNWIND nodes AS n RETURN n.node AS node, (n.score / max) AS score } WITH node, max(score) AS score ORDER BY score DESC LIMIT $k RETURN reduce(str='', k IN ['text'] | str + '\\n' + k + ': ' + coalesce(node[k], '')) AS text, node {.*, `embedding`: Null, id: Null, `text`: Null} AS metadata, score"

# %%
# "#Document ". join(unstructured_data)
# print(unstructured_data[:5000])
# token_count(unstructured_data[:5000])
unstructured_data = [el.page_content for el in vector_index.similarity_search('hasina')]
length = len(str(unstructured_data))
length = int(length/4)
len(str(unstructured_data)[:length])
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL () { ... }} {position: line: 1, column: 1, offset: 0} for query: "CALL { CALL db.index.vector.queryNodes($index, $k, $embedding) YIELD node, score WITH collect({node:node, score:score}) AS nodes, max(score) AS max UNWIND nodes AS n RETURN n.node AS node, (n.score / max) AS score UNION CALL db.index.fulltext.queryNodes($keyword_index, $query, {limit: $k}) YIELD node, score WITH collect({node:node, score:score}) AS nodes, max(score) AS max UNWIND nodes AS n RETURN n.node AS node, (n.score / max) AS score } WITH node, max(score) AS score ORDER BY score DESC LIMIT $k RETURN reduce(str='', k IN ['text'] | str + '\\n' + k + ': ' + coalesce(node[k], '')) AS text, node {.*, `embedding`: Null, id: Null, `text`: Null} AS metadata, score"
# 2503

# %%
text_splitter = TokenTextSplitter(chunk_size=512, chunk_overlap=24)
documents = text_splitter.split_text(str(unstructured_data))

# %%
documents
# Out:
# ["['\\ntext: �I don’t care what the West wants. What matters is whether we want democracy, human rights and freedom of the press. If they want what we want, it is a matter of happiness. If they don’t want it, we will continue to want it. Why let it be imposed on us like them?” He added, “It doesn’t matter when or what they said. Each country will formulate its foreign policy according to its own rules.”\\n\\nDespite Yunus’s past remarks about the United States, he is favored by the Democratic Party, as reflected in a January 22 letter from 12 U.S. senators urging Hasina to “end the persistent harassment of Nobel Peace Prize laureate Professor Muhammad Yunus – and the pattern of abusing laws and the justice system to target critics of the government more broadly.” As a leader with a better global image, Yunus will face the significant task of resetting ties with the United States and addressing contentious human rights issues.\\n\\nMeanwhile, the United States is alleged to have had a role in toppling Hasina’s government. An unconfirmed statement by Hasina has circulated in the Indian media claiming that the United States orchestrated her removal because she refused to surrender the sovereignty of Saint Martin Island, located in the northeastern Bay of Bengal. The tiny island has strategic importance because of its proximity to major shipping lanes and potential offshore resources, making it a point of interest for the United States’ regional security and economic influence. Had the United States made such a demand, it would have gone too far in pushing Dhaka.\\n\\nIndeed, like every great power, the United States seeks to increase its outreach in the Indo-Pacific, but not when the cost is too high – such as toppling an elected government. Difference makes partnerships grow and improve, but baseless accusations are outlandish. The State Department has firmly refuted such claims, calling them “laughable … any implication that the United States was involved in Sheikh Hasina’s resignation is absolutely false. We have seen a lot of disinformation in recent weeks, and we remain incredibly committed to strengthening information integrity across the digital ecosystem, especially with our partners in South Asia.” Considering that the two countries have spent decades developing multisector cooperation, especially with respect to tackling terrorism, staging something of this sort would be a serious political blunder on the United States’ part.\\n\\",
#  ", staging something of this sort would be a serious political blunder on the United States’ part.\\n\\nWhere does the Islamic world stand on the unfolding situation in Bangladesh', '\\ntext: ami League. In the days following the July 21 decision, the Bangladesh Chhatra League, an Awami League–affiliated student wing, clashed with protesters at Dhaka University. The situation quickly turned violent, with arson and killings taking place across Bangladesh. On August 5, the ADSM, a coalition of student representatives from different groups protesting the Hasina administration, organized the “Long March to Dhaka,” whose sole agenda was the resignation of the Hasina administration. In response, the government reportedly shut down the internet, imposed a curfew, and announced a three-day holiday.\\n\\nSeeing no improvement in spite of preventive measures, the army briefed the prime minister on the deteriorating law and order situation across the country. Hasina seems to have ordered even stricter measures, but the army refused. Lacking support from the military, Hasina made a quick decision to resign on August 5. Reports suggest that she had already sensed disquiet within the army a day earlier, but, thinking that the army would take strong action against the protesters, she believed her power and position were assured. Following Hasina’s resignation, Army Chief General Zaman took responsibility for the country and promised to form an interim government. Fearing for her life, Hasina sought approval to go to India, a request that was quickly approved by Delhi.\\n\\nWhy was the 30% quota so crucial for the Hasina government that she imposed a curfew, shut down the internet, curtailed civil liberties, and sought to take military action against the protesters?\\n\\nThese actions were taken primarily to assert her political authority and ensure unconditional support from the Awami League even as her standing as a democratic leader waned. This reasoning, however, would seem to contradict the outcome of Bangladesh’s January 2024 parliamentary elections, which gave Hasina a fourth term in office.\\n\\nThis brings us to the second reason for Hasina’s downfall: perceived authoritarian rule. Hasina’s time in power was seen as somewhat autocratic, as the politics of favoritism seemed to thrive and democratic norms appeared to be compromised. Since 2018, Hasina has been criticized for failing to abide by democratic norms and for dismantling the political opposition by imprisoning opponents on charges of corruption, anti-",
#  " for failing to abide by democratic norms and for dismantling the political opposition by imprisoning opponents on charges of corruption, anti-national activities, and so on. Leading BNP opposition leaders were barred from contesting in the 2018 elections, including former Prime Minister Zia, who was then serving a 10-year prison sentence for corruption. Even as Hasina used the state machinery to counter', '\\ntext: �s independence from Pakistan in 1971, the two countries have come a long way. Under Hasina’s leadership, the relationship between India and Bangladesh became stronger. However, when the military or the BNP and its allies were in power, suspicion arose in India and the country was accused of openly supporting Hasina and the Awami League. Today, this perception that Delhi’s influence is linked primarily to the Awami League may play a spoiler in normalizing bilateral ties.\\n\\nIn the immediate aftermath of August 5, Yunus conveyed his displeasure with India’s position on the protests and emphasized that it is an internal matter for Bangladesh. But India has been put on the spot by providing a safe haven to Hasina after her resignation. Political groups such as the BNP are asking India to return Hasina. In a press statement, a joint secretary general of the BNP added, “We want to maintain a good relationship with the people of India. Please arrest Sheikh Hasina and Sheikh Rehana, who fled the country, and send them back to Bangladesh. Sheikh Hasina has killed many people in Bangladesh.” The BNP cited the 2013 India-Bangladesh Extradition Extradition Treaty as requiring her return for cases filed against the former prime minister in Bangladesh, including murder cases, which qualify under Article 2(a) of the treaty.\\n\\nHowever, Article 8 of the treaty provides immunity against extradition if a person “satisfies the Requested State that it would, having regard to all the circumstances, be unjust or oppressive to extradite him by reasons of…the accusation not having or been made in good faith in the interests of justice.” India is unlikely to extradite Hasina to Bangladesh, especially considering her long-standing close relationship with India, which was a significant ally during her time in power.\\n\\nIndia must walk a tightrope to better its ties with Bangladesh’s new leaders. The interim government already has a strong anti-India voice in Hifazat-e-Islam, which",
#  " leaders. The interim government already has a strong anti-India voice in Hifazat-e-Islam, which is known to have supported the “India-out” campaign earlier this year. Even if Yunus makes a concerted effort to use his personal experience with India’s top leadership to improve bilateral ties, the chances of his advisers sabotaging the relationship are even greater, primarily because of Delhi’s alleged support for the Hasina regime.\\n\\nAccording to Bangladesh watchers in India, Delhi has taken a massive risk by', '\\ntext: The third reason for Hasina’s downfall is the romanticization of Bangladesh’s war of independence, even after 50 years. By keeping the memory of the 1971 war alive, Hasina reminded the nation of the great sacrifices made by her father, Sheikh Mujibur Rahman. Hasina identified herself with her father’s legacy. The 1971 Liberation War was the cornerstone of the Bangladeshi nation, and by romanticizing this history, she attempted to bolster her own and the party’s image. This romanticization closely mirrors the Communist regime in China, where almost all leaders in the past seven decades have romanticized Mao’s peasant revolution.\\n\\nWhat does the interim government reflect?\\nAfter Hasina’s resignation, the student protesters expressed their preference for Yunus to lead the interim government. They seem to have regarded him as a neutral candidate with significant experience in governance and economy, earning both respect and criticism across party lines. The army may have agreed to the 84-year-old Nobel laureate to lead the interim government to counter allegations of democratic backsliding coming from the West during Hasina’s tenure. However, some claim that Yunus was appointed at the behest of the U.S. Central Intelligence Agency – a typical “foreign hand” accusation often used in South Asia.\\n\\nIn addition to Yunus, the interim government initially included 17 advisers and later it was expanded to 21, including a former governor of the Reserve Bank of Bangladesh, several legal experts, a retired army brigadier, a former foreign secretary, women’s and Indigenous rights activists, bankers, academics, a medical practitioner, an Islamic studies expert, and two student leaders from the ADSM. The government has attempted to project an image of gender inclusiveness, with 25% of members (four advisers) being women.\\n\\nWhat is worrying is the resurgence",
#  "iveness, with 25% of members (four advisers) being women.\\n\\nWhat is worrying is the resurgence of political vendettas against the Awami League by Islamic fundamentalists in politics and governance. For instance, the inclusion of advisers such as A. F. Hassan Ariff – who served as attorney general of Bangladesh (2001–2005) under the BNP-led government and as an adviser to the interim government from 2008 to 2009 – may push for the political prosecution of Awami League. The inclusion of A. F. M. Khalid Hossain – a professor of Islamic studies and Nayab-e-Amir (administrator) of the Hifazat-e-Islam (Protectorate of Islam or']"]

# %% [markdown]
# # Unstructured data

# %%
def retriever(question: str):
    print(f"Search query: {question}")
    structured_data = structured_retriever(question)
    unstructured_data = [el.page_content for el in vector_index.similarity_search(question)]
    final_data = f"""Structured data:
{structured_data}
Unstructured data:
{"#Document ". join(unstructured_data)}
    """
    return final_data


# _template = """Given the following conversation and a follow up question, rephrase the follow up question to be a standalone question,
# in its original language.
# Chat History:
# {chat_history}
# Follow Up Input: {question}
# Standalone question:"""
# CONDENSE_QUESTION_PROMPT = PromptTemplate.from_template(_template)
# def _format_chat_history(chat_history: List[Tuple[str, str]]) -> List:
#     buffer = []
#     for human, ai in chat_history:
#         buffer.append(HumanMessage(content=human))
#         buffer.append(AIMessage(content=ai))
#     return buffer
# _search_query = RunnableBranch(
#     # If input includes chat_history, we condense it with the follow-up question
#     (
#         RunnableLambda(lambda x: bool(x.get("chat_history"))).with_config(
#             run_name="HasChatHistoryCheck"
#         ),  # Condense follow-up question and chat into a standalone_question
#         RunnablePassthrough.assign(
#             chat_history=lambda x: _format_chat_history(x["chat_history"])
#         )
#         | CONDENSE_QUESTION_PROMPT
#         | ChatGroq(groq_api_key=groq_api_key,model_name="Gemma2-9b-It")
#         | StrOutputParser(),
#     ),
#     # Else, we have no chat history, so just pass through the question
#     RunnableLambda(lambda x : x["question"]),
# )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 36
#      24         buffer.append(AIMessage(content=ai))
#      25     return buffer
#      26 _search_query = RunnableBranch(
#      27     # If input includes chat_history, we condense it with the follow-up question
#      28     (
#      29         RunnableLambda(lambda x: bool(x.get("chat_history"))).with_config(
#      30             run_name="HasChatHistoryCheck"
#      31         ),  # Condense follow-up question and chat into a standalone_question
#      32         RunnablePassthrough.assign(
#      33             chat_history=lambda x: _format_chat_history(x["chat_history"])
#      34         )
#      35         | CONDENSE_QUESTION_PROMPT
# ---> 36         | ChatGroq(groq_api_key=groq_api_key,model_name="Gemma2-9b-It")
#      37         | StrOutputParser(),
#      38     ),
#      39     # Else, we have no chat history, so just pass through the question
#      40     RunnableLambda(lambda x : x["question"]),
#      41 )
#
# NameError: name 'ChatGroq' is not defined

# %%
# template = """Answer the question based only on the following context:
# {context}

# Question: {question}
# Use natural language and be concise.
# Answer:"""
template = """Find if a tweet is pro awami league or anti-awami league based only on the following context:
If its pro awami league return 0 and if anti-awami league return 1
{context}

Question: {question}
return only 0 or 1.
Answer:"""
prompt = ChatPromptTemplate.from_template(template)
chain = (
    RunnableParallel(
        {
            "context": _search_query | retriever,
            "question": RunnablePassthrough(),
        }
    )
    | prompt
    | llm
    | StrOutputParser()
)

# %%
chain.invoke({"question": f"Find whether this tweet is pro awami league or anti awami league with the help of the relations tweet:---{text}----      "})
# Out:
# Search query: Find whether this tweet is pro awami league or anti awami league with the help of the relations tweet:---Grassroots Factions Opposing Exploitation----
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (node, node) { ... }} {position: line: 3, column: 13, offset: 104} for query: "CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})\n            YIELD node,score\n            CALL {\n              WITH node\n              MATCH (node)-[r:!MENTIONS]->(neighbor)\n              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output\n              UNION ALL\n              WITH node\n              MATCH (node)<-[r:!MENTIONS]-(neighbor)\n              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output\n            }\n            RETURN output LIMIT 50\n            "
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (node, node) { ... }} {position: line: 3, column: 13, offset: 104} for query: "CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})\n            YIELD node,score\n            CALL {\n              WITH node\n              MATCH (node)-[r:!MENTIONS]->(neighbor)\n              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output\n              UNION ALL\n              WITH node\n              MATCH (node)<-[r:!MENTIONS]-(neighbor)\n              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output\n            }\n            RETURN output LIMIT 50\n            "
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL () { ... }} {position: line: 1, column: 1, offset: 0} for query: "CALL { CALL db.index.vector.queryNodes($index, $k, $embedding) YIELD node, score WITH collect({node:node, score:score}) AS nodes, max(score) AS max UNWIND nodes AS n RETURN n.node AS node, (n.score / max) AS score UNION CALL db.index.fulltext.queryNodes($keyword_index, $query, {limit: $k}) YIELD node, score WITH collect({node:node, score:score}) AS nodes, max(score) AS max UNWIND nodes AS n RETURN n.node AS node, (n.score / max) AS score } WITH node, max(score) AS score ORDER BY score DESC LIMIT $k RETURN reduce(str='', k IN ['text'] | str + '\\n' + k + ': ' + coalesce(node[k], '')) AS text, node {.*, `embedding`: Null, id: Null, `text`: Null} AS metadata, score"
# '1'

# %%
chain
# Out:
# {
#   context: RunnableBranch(branches=[(RunnableBinding(bound=RunnableLambda(lambda x: bool(x.get('chat_history'))), kwargs={}, config={'run_name': 'HasChatHistoryCheck'}, config_factories=[]), RunnableAssign(mapper={
#              chat_history: RunnableLambda(lambda x: _format_chat_history(x['chat_history']))
#            })
#            | PromptTemplate(input_variables=['chat_history', 'question'], input_types={}, partial_variables={}, template='Given the following conversation and a follow up question, rephrase the follow up question to be a standalone question,\nin its original language.\nChat History:\n{chat_history}\nFollow Up Input: {question}\nStandalone question:')
#            | ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x00000156D5150650>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000156D53FAEA0>, model_name='Gemma2-9b-It', model_kwargs={}, groq_api_key=SecretStr('**********'))
#            | StrOutputParser())], default=RunnableLambda(lambda x: x['question']))
#            | RunnableLambda(retriever),
#   question: RunnablePassthrough()
# }
# | ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='Find if a tweet is pro awami league or anti-awami league based only on the following context:\nIf its pro awami league return 0 and if anti-awami league return 1\n{context}\n\nQuestion: {question}\nreturn only 0 or 1.\nAnswer:'), additional_kwargs={})])
# | ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x00000156B72981A0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000156B7298C80>, model_name='Gemma2-9b-It', model_kwargs={}, groq_api_key=SecretStr('**********'))
# | StrOutputParser()

# %%
chain.invoke(
    {
        "question": "What is quota system",
        "chat_history": [("Which house did Elizabeth I belong to?", "House Of Tudor")],
    }
)
# Out:
# Search query: What is a quota system?
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (node, node) { ... }} {position: line: 3, column: 13, offset: 104} for query: "CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})\n            YIELD node,score\n            CALL {\n              WITH node\n              MATCH (node)-[r:!MENTIONS]->(neighbor)\n              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output\n              UNION ALL\n              WITH node\n              MATCH (node)<-[r:!MENTIONS]-(neighbor)\n              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output\n            }\n            RETURN output LIMIT 50\n            "
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL () { ... }} {position: line: 1, column: 1, offset: 0} for query: "CALL { CALL db.index.vector.queryNodes($index, $k, $embedding) YIELD node, score WITH collect({node:node, score:score}) AS nodes, max(score) AS max UNWIND nodes AS n RETURN n.node AS node, (n.score / max) AS score UNION CALL db.index.fulltext.queryNodes($keyword_index, $query, {limit: $k}) YIELD node, score WITH collect({node:node, score:score}) AS nodes, max(score) AS max UNWIND nodes AS n RETURN n.node AS node, (n.score / max) AS score } WITH node, max(score) AS score ORDER BY score DESC LIMIT $k RETURN reduce(str='', k IN ['text'] | str + '\\n' + k + ': ' + coalesce(node[k], '')) AS text, node {.*, `embedding`: Null, id: Null, `text`: Null} AS metadata, score"
# 'The quota system refers to a policy in Bangladesh that reserves a certain percentage of government job openings for descendants of freedom fighters from the 1971 Bangladesh Liberation War. \n'

# %%
unstructured_data = [el.page_content for el in vector_index.similarity_search("jamat")]
unstructured_data
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL () { ... }} {position: line: 1, column: 1, offset: 0} for query: "CALL { CALL db.index.vector.queryNodes($index, $k, $embedding) YIELD node, score WITH collect({node:node, score:score}) AS nodes, max(score) AS max UNWIND nodes AS n RETURN n.node AS node, (n.score / max) AS score UNION CALL db.index.fulltext.queryNodes($keyword_index, $query, {limit: $k}) YIELD node, score WITH collect({node:node, score:score}) AS nodes, max(score) AS max UNWIND nodes AS n RETURN n.node AS node, (n.score / max) AS score } WITH node, max(score) AS score ORDER BY score DESC LIMIT $k RETURN reduce(str='', k IN ['text'] | str + '\\n' + k + ': ' + coalesce(node[k], '')) AS text, node {.*, `embedding`: Null, id: Null, `text`: Null} AS metadata, score"
# ["\ntext: attogram)\nNusrat Tabassum\nAbdul Kader\nMahin Sarker\nHasib Al Islam\nUmama Fatema (spokesperson)\nAbdullah Salehin Ayon\n\n\n== See also ==\nStudent-People's uprising – 2024 mass uprising in BangladeshPages displaying short descriptions of redirect targets\nJuly Shaheed Smrity Foundation – Welfare organisation in Bangladesh\nJatiya Nagorik Committee – Bangladeshi political platform\nGonotantrik Chhatra Shakti – Student organization in Bangladesh\n\n\n== Notes ==\n\n\n== References ==",
#  '\ntext:  July 2024, in support of civil service reservation quota reform in Bangladesh. From 2 to 6 July, students of various institutions held protests, human chains, highway blockades, etc. in different parts of the country. On 7 July, the platform called for the "Bangla Blockade", under which students staged demonstrations, marches, civil disobedience and blockades of highways and railways.\nOne of the group\'s coordinators, Abu Sayed of Rangpur\'s Begum Rokeya University, was shot and killed by the police on 16 July 2024.\n\nThe group led a nationwide students and public uprising against the dictatorial Awami League regime and successfully pushed her to resign on 5 August 2024. On 8 August 2024, Nahid Islam and Asif Mahmud, two members of the group were appointed as advisers in the interim government led by the Yunus ministry. After the Yunus interim government took the responsibility of Bangladesh\'s administration, the group announced a liaison committee to work on the new political arrangement. On the same day, it announced a new coordination team.\nAs of August 2024, members of the organisation were suggesting the formation of a political party within a month.\nOn 22 October 2024, The organisation announced a four-member central convener committee during',
#  "\ntext:  unverified, exaggerated, or misleadingly framed. Fact checkers highlighted the situation's complexity and the difficulties in accurately assessing causes of violence.\n\n\n== Background ==\n\nOn July 2024, the quota reform movement morphed into a fierce anti-government mass uprising, known as the Student–People's uprising, ultimately removed the Awami League government from state power. Over the years, all major political parties of the country have taken turn in inciting violence against Hindus. The Jatiya Party did it in 1990, Bangladesh Nationalist Party (BNP) in 2001, Jamaat-e-Islami in 2013, BNP and Jamaat together in 2014, which forced these parties to lose the backing of the Hindu community. Awami League, being the last bastion of secularism, was seen as the protector of the Hindu minority though several attacks have taken place during the tenure of the Awami League government, like the murder of Biswajit Das & anti-Hindu violence in 2021.\n\n\n== Attacks ==\nFollowing Hasina's departure, a series of communal attacks were reported, particularly targeting Hindus in Bangladesh. These incidents included alleged attacks on temples, houses, and shops belonging to minority communities, as well as reports of looting and murder across several districts",
#  '\ntext:  same day, it announced a new coordination team.\nAs of August 2024, members of the organisation were suggesting the formation of a political party within a month.\nOn 22 October 2024, The organisation announced a four-member central convener committee during press conference at the Central Shaheed Minar. Hasnat Abdullah was made convener, Arif Sohel member secretary, Abdul Hannan Masud chief organiser, and Umama Fatema the spokesperson of the committee.\n\n\n== Coordinators ==\n\nNahid Islam\nSarjis Alam\nAsif Mahmud\nMahfuz Alam (liaison committee)\nShadik Kayem (DU Shibir President)\nRifat Rashid\nHasnat Abdullah (convener)\nAbu Sayed (Rangpur)\nAbu Baker Mazumder\nAbdul Hannan Masud (chief organiser)\nArif Shohel (member secretary)\nKhan Talat Mahmud Rafy (Chattogram)\nNusrat Tabassum\nAbdul Kader\nMahin Sarker\nHasib Al Islam\nUmama Fatema (spokesperson)\nAbdullah Salehin Ayon\n\n\n== See also ==\n']

# %% [markdown]
# # Translated tweet

# %%
import google.generativeai as genai
from dotenv import load_dotenv
load_dotenv()
import os

from mistralai import Mistral

# api_key = os.environ["MISTRAL_API_KEY"]
api_key = os.getenv("MISTRAL_API_KEY")

model = "mistral-large-latest"

client = Mistral(api_key=api_key)

safety_settings = [
    {
        "category": "HARM_CATEGORY_DANGEROUS",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_NONE",
    },
]


def translate_with_gemini(text, model='gemini-1.0-pro'):
    GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')

    genai.configure(api_key=GOOGLE_API_KEY)
    model = genai.GenerativeModel(model,safety_settings=safety_settings)


    response = model.generate_content(
    f'''Translate the text into ENGLISH [{text}].

    # Do not include pleasantries or explanations in your responses.''',
    generation_config=genai.types.GenerationConfig(
        # candidate_count=1,
        # stop_sequences=['space'],
        # max_output_tokens=200,
        temperature=0)
    )



    items = response.text
    # Remove numbering from each line
    # subjects = [item.split('. ', 1)[-1] for item in items]
    return items

# %%
import os
from openai import OpenAI
from mistralai import Mistral

# api_key = os.environ["MISTRAL_API_KEY"]
# api_key = os.getenv("MISTRAL_API_KEY")

# model = "mistral-large-latest"

# client = Mistral(api_key=api_key)
# groq_api_key
client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=os.getenv("GROQ_API_KEY")

)

# client = OpenAI(
#     # base_url="https://api.groq.com/openai/v1",
#     # api_key=os.environ.get("GROQ_API_KEY")
#     api_key=os.environ.get("OPENAI_API_KEY_PAPER")

# )

def translate_tweet(tweet, model="mixtral-8x7b-32768"):

    
    # LLM prompt to extract entities
    entity_extraction_prompt = f"""
    Translate the tweet into ENGLISH. And Remove hashtags if any.
    Do not give any pleasantries in the reponse. Only the translation, No extra words. or explanation.

    tweet:
    {tweet}
    """
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "system", "content": "You are a helpful assistant. You translate text into english. Dont give explanation"},
                    {"role": "user", "content": entity_extraction_prompt}],
        temperature=0
    )
    # time.sleep(15)
    # print(response)
    # entities = response["choices"][0]["message"]["content"].strip()
    translated_tweet = response.choices[0].message.content
    return translated_tweet

    # Answer in just 0 and 1. You detect political stance whether in favour of awami league:1 or against awami league:0.
    # NO EXTRA WORDS OR EXPLANATION OR PLEASANTARIES IN YOUR RESPONSE.
    #     in favour of awami league:1 or against awami league:0.
#     For example, The tweet [The head of the UN Human Rights Commission's visit to Bangladesh raises concerns over the illegal Yunus government!
# ] is pro-awami league. Beacuse it says 'illegal Yunus government'.

# def detect_political_stance(tweet, relational_text='', tweet_info='', unstructured_data='', model = "mistral-large-latest"):
def detect_political_stance(tweet, relational_text='', tweet_info='', unstructured_data='', model = "deepseek-r1-distill-llama-70b"):


    # LLM prompt to extract entities
    entity_extraction_prompt = f"""
    tweet:
    {tweet}
    Read the tweet above. The tweet has a political stance. The tweet can say in favour of awami league of Bangladesh
    or against awami league, which is a political party of Bangladesh.
    Detect whether a tweet is in favour of awami league or against.


    usually pro-awami tweets praise Awami league, Sheikh Hasina and allies or label them a victim.
    Anti-awami tweets criticize hasina and allies and label them as criminal.
    Sheikh Hasina's enemies are: Student-Led Movements, Muhammad Yunus, Bangladesh Nationalist Party (BNP)

    Current government is yunus government and previous government was of Shikh Hasina.

    EXAMPLE:
    The head of the UN Human Rights Commission's visit to Bangladesh raises concerns over the illegal Yunus government!
    -------- 
    The head of the UN Human Rights Commission, Volker Turk, came to Bangladesh and met with the legal advisor 
    He talked about all aspects of the July-August movement. Why was the student killings

    ASK QUESTIONS TO DETECT STANCE:
    Q: Who is being criticized here?
    A: Muhammad Yunus. Beacuse the tweet uses 'illegal' to refer him. And yunus was appointed by students, that makes him Hasina's Enemy.
    So it is in favour of Awami league.
    Q: Which government is in power in the tweet?
    A: Muhammad Yunus's goverment is in power in the tweet. Yunus came to power after hasina.
    So it is in favour of Awami league.
    


    for your decision making a few general info is given. from this info you can figure out the political relations in bangladesh


    TWEET_INFO:
    {tweet_info}
    
    GENERAL INFO:
    {relational_text}

    Extra info:
    {unstructured_data}
    """
    print(f"length: {len(entity_extraction_prompt)}")
    response = client.chat.completions.create(
    # response = client.chat.complete(

        model=model,
        messages=[{"role": "system", "content": "You are a helpful assistant. You detect political stance in favour of awami league, or against awami league."},
                    {"role": "user", "content": entity_extraction_prompt}],
        temperature=0
    )
    # time.sleep(30)
    # print(response)
    # entities = response["choices"][0]["message"]["content"].strip()
    translated_tweet = response.choices[0].message.content
    return translated_tweet

def transform(text, model="gemma2-9b-it"):


    # LLM prompt to extract entities
    entity_extraction_prompt = f"""
    If the text below says tweet is in favour of awami league then return 1.
    else, if the text below says the tweet is against awami league then return 0.
    NO EXTRA WORDS OR EXPLANATION OR PLEASANTARIES IN YOUR RESPONSE. Only 1 or 0.

    text:
    {text}
 
    """
    print(f"length: {len(entity_extraction_prompt)}")
    # response = client.chat.complete(
    response = client.chat.completions.create(

        model=model,
        messages=[{"role": "system", "content": "You are a helpful assistant. You answer in just 0 or 1."},
                    {"role": "user", "content": entity_extraction_prompt}],
        temperature=0
    )
    # time.sleep(30)
    # print(response)
    # entities = response["choices"][0]["message"]["content"].strip()
    translated_tweet = response.choices[0].message.content
    return translated_tweet


# def detect_political_stance(text, model = "mistral-large-latest"):


#     # LLM prompt to extract entities
#     entity_extraction_prompt = f"""
#     Read The text below and if the text says tweet is in favour of awami league then return 1.
#     else return 0.

#     EXAMPLE:
#     The head of the UN Human Rights Commission's visit to Bangladesh raises concerns over the illegal Yunus government!
#     STANCE: 1
#     NO EXTRA WORDS OR EXPLANATION OR PLEASANTARIES IN YOUR RESPONSE. Only 1 or 0.

#     text:
#     {text}



#     """
#     print(f"length: {len(entity_extraction_prompt)}")
#     # response = client.chat.completions.create(
#     response = client.chat.complete(

#         model=model,
#         messages=[{"role": "system", "content": "You are a helpful assistant. You response in just 1 or 0"},
#                     {"role": "user", "content": entity_extraction_prompt}],
#         temperature=0
#     )
#     # time.sleep(30)
#     # print(response)
#     # entities = response["choices"][0]["message"]["content"].strip()
#     translated_tweet = response.choices[0].message.content
#     return translated_tweet

# %%
import os
print(os.getenv("OPENAI_API_KEY_PAPER"))
# Out:
# sk-ga0Zhkx2p8oc32Gm9aF37e6bF6Ac4878B6CcB752B876Cd37

# %%
import os

print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: f:\EUCLIDO\Tasks\knowledge_graph

# %%
from dotenv import load_dotenv, find_dotenv

dotenv_path = find_dotenv()
print("Environment File Path:", dotenv_path)

if dotenv_path:
    load_dotenv(dotenv_path)
# Out:
# Environment File Path: f:\EUCLIDO\Tasks\knowledge_graph\.env

# %%
import os

env_var = os.getenv("OPENAI_API_KEY_PAPER")
# print("OPENAI_API_KEY_PAPER:", env_var)

# %% [markdown]
# # @

# %%
import os
from openai import OpenAI
from mistralai import Mistral
from dotenv import load_dotenv
load_dotenv()
import os

# api_key = os.environ["MISTRAL_API_KEY"]
# api_key = os.getenv("MISTRAL_API_KEY")
# api_key = os.getenv("OPENAI_API_KEY")


# model = "mistral-large-latest"

# client = Mistral(api_key=api_key)
# groq_api_key
# client = OpenAI(base_url="https://api.mixrai.com/v1", api_key=api_key)
# client = OpenAI(api_key=api_key)


client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=os.environ.get("GROQ_API_KEY")
    # api_key=os.environ.get("OPENAI_API_KEY_PAPER")

)

def detect_political_stance(tweet, related_text, model="gpt-4o-mini"):
# def detect_political_stance(tweet, model = "mistral-large-latest"):


    
    # LLM prompt to extract entities
    entity_extraction_prompt = f"""
    Read the tweet Below. The tweet has a political stance. The tweet can say in favour of awami league of Bangladesh
    or against awami league, which is a political party of Bangladesh.
    Detect whether a tweet is in favour of awami league or against.
    If the tweet is in favour of awami league then return 1.
    else, if the tweet is against awami league then return 0.

    EXAMPLE:
    The head of the UN Human Rights Commission's visit to Bangladesh raises concerns over the illegal Yunus government!
    STANCE: 1
    
    NO EXTRA WORDS OR EXPLANATION OR PLEASANTARIES IN YOUR RESPONSE. Only 1 or 0.
    tweet:
    {tweet}

    related_text:
    {related_text}
    """
    print(f"length: {len(entity_extraction_prompt)}")

    response = client.chat.completions.create(
    # response = client.chat.complete(

        model=model,
        messages=[{"role": "system", "content": "You are a helpful assistant.You response in just 1 or 0"},
                    {"role": "user", "content": entity_extraction_prompt}],
        temperature=0
    )
    # time.sleep(15)
    # print(response)
    # entities = response["choices"][0]["message"]["content"].strip()
    translated_tweet = response.choices[0].message.content
    return translated_tweet

    # Tweet:I welcome the swearing in of Dr. Muhammad Yunus to lead the interim government in Bangladesh. 
    # The United States supports his call for calm and peace and remains committed to working with 
    # Bangladesh as it charts a democratic and prosperous future the people in Bangladesh.
    # Stance: Against awami league

    # ASK QUESTIONS TO DETECT STANCE:
    # Q: Who is being criticized here?
    # A: Muhammad Yunus. Beacuse the tweet uses 'illegal' to refer him. And yunus was appointed by students, that makes him Hasina's Enemy.
    # So it is in favour of Awami league.
    # Q: Which government is in power in the tweet?
    # A: Muhammad Yunus's goverment is in power in the tweet. Yunus came to power after hasina.
    # So it is in favour of Awami league.
# def detect_political_stance(tweet, relational_text='', tweet_info='', unstructured_data='', model = "mistral-large-latest"):
def detect_political_stance(tweet, relational_text='', tweet_info='', unstructured_data='', model="gemma2-9b-it"):


    # LLM prompt to extract entities
    entity_extraction_prompt = f"""
    tweet:
    {tweet}
    Read the tweet above. The tweet has a political stance. The tweet can say in favour of awami league of Bangladesh
    or against awami league, which is a political party of Bangladesh.
    Detect whether a tweet is in favour of awami league or against.

    EXAMPLE:
    Tweet: The head of the UN Human Rights Commission's visit to Bangladesh raises concerns over the illegal Yunus government!
    -------- 
    The head of the UN Human Rights Commission, Volker Turk, came to Bangladesh and met with the legal advisor 
    He talked about all aspects of the July-August movement. Why was the student killings
    Stance: in favour of awami league


    ASK QUESTIONS TO DETECT STANCE:
    Q: Who is being criticized here?
    A: Muhammad Yunus. Beacuse the tweet uses 'illegal' to refer him. And yunus was appointed by students, that makes him Hasina's Enemy.
    So it is in favour of Awami league.
    Q: Which government is in power in the tweet?
    A: Muhammad Yunus's goverment is in power in the tweet. Yunus came to power after hasina.
    So it is in favour of Awami league.
    Q: Who are the person or organization friends or enmeies with?

    GENERATE A FEW QUESTIONS YOURSELF AND BY ANSWERING THEM FIND STANCE.
    usually pro-awami tweets praise Awami league, Sheikh Hasina and allies or label them a victim.
    Anti-awami tweets criticize hasina and allies and label them as criminal.
    Sheikh Hasina's enemies are: Student-Led Movements, Muhammad Yunus, Bangladesh Nationalist Party (BNP)

    Current government is yunus government and previous government was of Shikh Hasina.





    for your decision making a few general info is given. from this info you can figure out the political relations in bangladesh


    TWEET_INFO:
    {tweet_info}
    
    GENERAL INFO:
    {relational_text}

    Extra info:
    {unstructured_data}
    """
    print(f"length: {len(entity_extraction_prompt)}")
    response = client.chat.completions.create(
    # response = client.chat.complete(

        model=model,
        messages=[{"role": "system", "content": "You are a helpful assistant. You detect political stance in favour of awami league, or against awami league."},
                    {"role": "user", "content": entity_extraction_prompt}],
        temperature=0
    )
    # time.sleep(30)
    # print(response)
    # entities = response["choices"][0]["message"]["content"].strip()
    translated_tweet = response.choices[0].message.content
    return translated_tweet


def transform(text, model="gpt-4o"):


    # LLM prompt to extract entities
    entity_extraction_prompt = f"""
    If the text below says tweet is in favour of awami league then return 1.
    else, if the text below says the tweet is against awami league then return 0.
    NO EXTRA WORDS OR EXPLANATION OR PLEASANTARIES IN YOUR RESPONSE. Only 1 or 0.

    text:
    {text}
 
    """
    print(f"length: {len(entity_extraction_prompt)}")
    response = client.chat.completions.create(
    # response = client.chat.complete(

        model=model,
        messages=[{"role": "system", "content": "You are a helpful assistant. You answer in just 0 or 1."},
                    {"role": "user", "content": entity_extraction_prompt}],
        temperature=0
    )
    # time.sleep(30)
    # print(response)
    # entities = response["choices"][0]["message"]["content"].strip()
    translated_tweet = response.choices[0].message.content
    return translated_tweet

# %%
tweet = ''' Very stimulating meeting with Hon'ble Adviser in charge of ICT, Post and Telecom, and Information & Broadcasting this afternoon #Connectivity #InternetForAll #StudentsPower #RiskPrevention #FreedomOfExpression #MediaFreedom'''
detect_political_stance(tweet, relational_text='', tweet_info='', unstructured_data='', model="gemma2-9b-it")
# Out:
# length: 2056
# 'Let\'s analyze the tweet:\n\n**Tweet:** Very stimulating meeting with Hon\'ble Adviser in charge of ICT, Post and Telecom, and Information & Broadcasting this afternoon #Connectivity #InternetForAll #StudentsPower #RiskPrevention #FreedomOfExpression #MediaFreedom\n\n**Questions:**\n\n1. **Who is being praised or highlighted in the tweet?**  The tweet mentions a "Hon\'ble Adviser" in charge of key ministries. This suggests a positive portrayal of this individual and their role.\n\n2. **What are the hashtags associated with the tweet?**  The hashtags focus on positive themes like connectivity, internet access, student empowerment, risk prevention, freedom of expression, and media freedom. These are generally aligned with progressive and development-oriented agendas.\n\n3. **Considering the general political landscape of Bangladesh, who might benefit from these positive associations?**  The Awami League government, under Sheikh Hasina, has often emphasized digital development, internet access, and freedom of expression as key priorities. \n\n**Answering the Questions:**\n\n* The tweet praises an individual in a position of power within the government.\n* The hashtags promote positive themes often associated with the Awami League\'s policies.\n* The positive portrayal aligns with the Awami League\'s focus on development and progressive values.\n\n\n**Stance:**\n\nBased on the analysis, the tweet appears to be **in favor of the Awami League**. \n'

# %%
import pandas as pd

# Read the CSV file
df = pd.read_excel(r"F:\EUCLIDO\Tasks\knowledge_graph\all dataset\Journalist data\Anit Uprising person\final_500_translated3.xlsx")

models = [
    "gemma2-9b-it",
    "llama-3.1-8b-instant",
    "llama-guard-3-8b",
    "llama3-8b-8192",
    "llama3-groq-70b-8192-tool-use-preview"    ]

for index, row in df.iterrows():
    # if(index <300):
    #     continue

    x = index % 5
    model = models[x]
    # model
    # print(f"Tweet: {row['Content']}")
    translation = str(row['translated_text'])
    # tweet_info = structured_retriever(translation)
    # unstructured_data = [el.page_content for el in vector_index.similarity_search(translation)]
    # unstructured_data = []
    try:
        structured_data = structured_retriever(translation)
    except Exception as e:
        continue
    # try:
    #     unstructured_data = [el.page_content for el in vector_index.similarity_search(translation)]
    # except Exception as e:
    #     continue

    # length = len(str(unstructured_data))
    # length = int(length/30)
    # unstructured_data= (str(unstructured_data)[:1000])
    # print(f"Translated Tweet: {translation}")  
    stance = detect_political_stance(translation, relational_text, str(structured_data), unstructured_data='', model=model)
    print(f"{index}: {stance}")
    # print(f"Stance:\n {detect_political_stance(translation)}")

    # print("---")
    # break  # Break after the first row to test
    df.at[index, 'prediction'] = stance

    # new_row_df = pd.DataFrame([{'university': 'toronto', 'dept_name': dept, 'source_url': href, 
    #                             'name': name, 'designation': designation,'email': email, 
    #                             'personal_url': personal_url, 'research_interest': research_interests}])

    # professor_df = pd.concat([professor_df, new_row_df], ignore_index=True)

df.to_excel(r"F:\EUCLIDO\Tasks\knowledge_graph\all dataset\Journalist data\Anit Uprising person\final_500_translated3_predicted.xlsx", index=False)

# %%
import pandas as pd

# Read the CSV file
df = pd.read_excel(r"F:\EUCLIDO\Tasks\knowledge_graph\all dataset\non_matches_again.xlsx")
cnt=0
for index, row in df.iterrows():
    # if(index>350):
    #     break
    if (str(row['label'])==str(row['prediction'])):
        cnt+=1


print(cnt)
# Out:
# 60

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel(r"F:\EUCLIDO\Tasks\knowledge_graph\all dataset\non_matches_again.xlsx")

# Create two new DataFrames
df_match = df[df['label'].astype(str) == df['prediction'].astype(str)]
df_no_match = df[df['label'].astype(str) != df['prediction'].astype(str)]

# Count the number of matches
cnt = len(df_match)

print(f"Number of matches: {cnt}")

# Save the new DataFrames to Excel or CSV if needed
df_match.to_excel(r"F:\EUCLIDO\Tasks\knowledge_graph\all dataset\matches_non_matches_again.xlsx", index=False)
df_no_match.to_excel(r"F:\EUCLIDO\Tasks\knowledge_graph\all dataset\non_matches_non_matches_again.xlsx", index=False)
# Out:
# Number of matches: 60

# %%
file_path = r"F:\EUCLIDO\Tasks\knowledge_graph\all dataset\Journalist data\Anit Uprising person\label_1_label_0_predicted.xlsx"

excel_file_path = file_path

try:
    existing_data = pd.read_excel(excel_file_path)
    # combined_data = existing_data.append(new_df, ignore_index=True)
    combined_data = pd.concat([existing_data, df], ignore_index=True)

    combined_data.to_excel(excel_file_path, index=False)

except Exception as e:
    df.to_excel(excel_file_path, index=False)

# %%
models = [
    "gemma-7b-it",
    "gemma2-9b-it",
    "llama-3.1-8b-instant",
    "llama-guard-3-8b",
    "llama3-8b-8192",
    "llama3-groq-70b-8192-tool-use-preview",
    "llava-v1.5-7b-4096-preview"
    ]
index =100
x = index % 7
model = models[x]
model
# Out:
# 'llama-3.1-8b-instant'

# %%
tweet_info = structured_retriever(translation)
print(unstructured_data)
print(tweet_info)

# %%
import pandas as pd
import time
df = pd.read_excel(r"F:\EUCLIDO\Tasks\knowledge_graph\all dataset\Journalist data\Anit Uprising person\final_500_translated3.xlsx")
# models = [
#     "gemma2-9b-it",
#     "llama-3.1-8b-instant",
#     "llama-guard-3-8b",
#     "llama3-8b-8192",
#     "llama3-groq-70b-8192-tool-use-preview"    
#     ]
	
models = [
    "llama-3.1-70b-versatile",
    "mixtral-8x7b-32768",
    "llama-3.3-70b-versatile" 
    ]

for index, row in df.iterrows():
    # if(index <95):
    #     continue
    # print(f"Tweet: {row['text']}")
    x = index % 3
    model = models[x]
    # translation = (translate_tweet(row['Content'], model = model))
    # translation = translate_with_gemini(row['Content'])
    # translation = GoogleTranslator(source='auto', target='en').translate(str(row['Content']))
    try:
        translation = GoogleTranslator(source='auto', target='en').translate(str(row['Content']))
    except Exception as e:
        print(f"Error translating row {index}: {e}")
        continue
    print(index)
    print(translation)

    df.at[index, 'translated_text_google_translator'] = translation  # Add translation at the current index
    time.sleep(2)

df.to_excel(r"F:\EUCLIDO\Tasks\knowledge_graph\all dataset\Journalist data\Anit Uprising person\final_500_translated3_google.xlsx", index=False)
# Out:
# 0
# The Indian government was literally running a Sikh assassination program from Canadian soil.
#
# Consular officials had approval, gathered intelligence & worked with organized crime to murder Sikhs.
#
# This isn’t fiction. Trudeau said it yesterday and global media is now reporting it.
# 1
# The blood stains are not dry yet, everyone needs to be patient to get their demands met: Mushfiqul Fazal Ansari jugantor.com/national/841434…
# 2
# More than one million people are now internally displaced in #Lebanon.
#
# @Refugees representative in the country @IFreijsen shares what he has witnessed:
# 3
# Met with Foreign Minister of Bangladesh, Dr Hasan Mahmud, and reiterated deep concern at BD law enforcement authorities’ excessive use of force in recent protests
#
# I called for accountability & dialogue with student protesters
#
# Human rights are a fundamental element of 🇪🇺-🇧🇩 ties
# 4
# In Bangladesh's new political dispensation, student groups and political parties should continue to demand that the Jamaat-e-Islami acknowledge it role in supporting the Pakistan military in 1971 and apologise for its crimes and the conduct of its leaders.
# 5
# I am closely observing the situation in Bangladesh with deep concern. The right to peaceably assemble and protest is a cornerstone of a democratic society. Violent repression of the student protest is wrong and will only lead to more unrest.
# 6
# You can decide which ideas you like.
# You can decide what the future should look like.
#
# Use your vote in the #National Council election on Sunday! (vdb)
# 7
# (9)
# Another criticism in the opposition to the song "Amar Sonar Bangla" is that this song brings forward language-based nationalism. Although language-centered Bengali nationalism was important during the Pakistan period due to the language movement, people of many other language-speaking ethnicities live in independent Bangladesh. As a result, there is no need to keep such language-based nationalist songs as the national anthem. In response to this, it can be said that if you listen carefully to the words of the song "Amar Sonar Bangla", you will understand that here "Bangla" is not a language, but a territory. The love for that land called Bengal is being spoken, there is the scent of mango forests in the spring, fields full of fragrance, the fields spread out at the roots of banyan trees and on the banks of rivers - these are actually descriptions of the territory, not the language. Just as the language of Bengalis is Bengali, so is the name of our country Bangladesh. We find the Bengali of this Bangladesh in the Bengali of "Amar Sonar Bangla". However, if this song, written in the language of the majority of people, has to be taken to people who speak other languages, then I think there should be a system for translating and singing it in all languages.
# 8
# Chinese Fairy Tales: The Story of the Blue Bird, Sacrifice of Love
#
# dorpon.com.bd/%e0%a6%b0%e0%a…
# 9
# Abul Kashem Fazlul Haque is the president of Bangla Academy.
#
# Congratulations to him.
# 10
# Note: Have corrected this tweet as happened yesterday, not today.
# 11
# yewtu.be/live/gwXuvdWZAWY…
# 12
# Too little? Too Late? .... And just too many, just too many lies?
# 13
# India is systematically crippling  Bangladesh 🇧🇩 — First they divert power from the Adani Group meant for us and now they cause floods by opening dams without notice. This exploitation must end. Bangladesh deserves respect and fairness!
#
# #FloodInBangladesh
# 14
# kalerkantho.com/online/natio…
# 15
# Why is the name of the political party like a brand of biscuits?
# 16
# "It is clear that there was an official policy of enforced disappearances and arbitrary detention under Sheikh Hasina's regime, and it is telling that Arman was released immediately upon her fleeing to India."  telegraph.co.uk/news/2024/08…
# 17
# I can understand the rationale for certain pro-Awami Judges to resign, but using thousands of students to barrack the courts is surely not the way. Is this how, in the future students will act when an important judicial decision does not go their way?
#
# As far as I know, no-one has put together a proper public document setting out exactly why particular High Court judges should resign - what particularly biased decisions they have made, or ways in which they are corrupt. Surely this should be done, before judges are asked (or indeed as here) forced, to resign. Otherwise this looks like mob "justice".
#
# Moreover, as yet, there is no clear policy established to ensure new competent, non-partisan judges will be appointed - so there remains a risk of just getting a slew of pro-BNP/JI judges appointed to replace the old pro-AL ones. It seems to me, until a new policy has been created, there should be no replacement of judges. #bangladesh thedailystar.net/news/bangla…
# 18
# barrons.com/news/bangladesh-…
# 19
# The Bangladesh Jamaat-e-Islami's leader refusal in his interview with @dailystarnews to apologise for crimes committed by his party during the 1971 war is either "exceedingly disappointing" or "exactly what you would expect" depending on your view point of the conservative Islamic party.
#
# Shafiqur Rahman told the paper that he would only apologise  - "personally beg for forgiveness from the nation with full responsibility", as he put it - if the crimes were "proved beyond doubt".
#
# First of all it should be noted that the criminal standard of proof, not just in Bangladesh but everywhere in the world, is "beyond reasonable doubt" not, as the Jamaat leader put it, "beyond doubt". Even were the fairest court in the world to convict "the Jamaat" for 1971 crimes, the Jamaat leader would, it seems, still say, "Well that was proved 'beyond reasonable doubt', not 'beyond doubt' so it is not yet proven against us."
#
# Secondly, it seems that Rahman feels confident about saying that the allegations against the Jamaat are not proven because of the increasingly widespread understanding that the trials at the International Crimes Tribunal, which convicted and executed all of Jamaat's top leadership for 1971 crimes, were unfair. Indeed he claims that they were "a complete Kangaroo court."
#
# The problem with this line of argument is that although there were many weaknesses in the process - making the trials against the Jamaat leaders significantly unfair and many of the charges laid against them as individuals arguably unproven - the case against the  Jamaat-e-Islami's involvement in war crimes as an organisation or party remains very strong indeed.
#
# In my view, the Jamaat leader cannot and should not use the unfair trials against the individual Jamaat leaders as a way of exonerating the organisation.
#
# Undoubtedly, the Jamaat were involved in serious crimes during 1971, and it is difficult to take it seriously now as a political party until it acknowledges that and apologises.  The Jamaat - no longer under the Awami League cosh - is seeking to mainstream itself, but clearly it still has quite a way to go if it still cannot acknowledge its actions in 1971.
# thedailystar.net/news/bangla…
# 20
# So is @TulipSiddiq the next to fall on the sword?
# 21
# Hold my hand forever ❤️
# 22
# Who is responsible for the current situation in Bangladesh?
# 23
# There have been a number of really outstanding panel discussions in recent days about the situation in #Bangladesh, and I know there are more planned for the coming days.   I am pleased that @rtoforg can contribute to this larger discussion with an outstanding panel on August 30.  For those unable to tune in live, a recording will be posted after the event.
#
# As moderator, I will be asking our panelists questions after their opening remarks.   We will solicit these from those who join us live, but if you have questions you would like me to ask any of these distinguished experts, please post them below.
#
# Thanks in advance to @MichaelKugelman @badiulm @FahmidaKcpd and Ali Riaz for joining us.    I look forward to a lively discussion.
# 24
# The rumor has spread well, and it has become clear why a particular group of people is destroying their clothes here and there. The dose will be doubled in the future.
# 25
# This is unfortunately the kind of criminal damage that the Bangladesh government will say justifies a harsh law enforcement response. The student protestors themselves must remain peaceful.
# 26
# yewtu.be/watch?v=AlTbEL…
# 27
# Footage courtesy of journalist Golam Mortoza, editor of @dailystarnews bangla, highlights the flood-affected areas along the Comilla-Chittagong Highway. The flood situation in the southeastern region of Bangladesh continues to worsen.
# 28
# #Bangladesh: The student leadership that brilliantly led the revolution to oust dictator #SheikhHasina is now dictating the terms for the interim government. They have just declared country's Nobel Laureat @Yunus_Centre as the head of the interim government!  Very smart move!
# 29
# You can't unblur everything from your life, can you?
# 30
# This is how authoritarian governments find a way to stay in power
# 31
# Police arrested a Hindu man in connection with the vandalism of idols in Rajbari on October 8.
#
# After an investigation and reviewing CCTV footage, the police arrested Ranapada Sarker, who is intellectually disabled, in connection with the vandalism, where the idols were slightly damaged.
#
# According to the police, during interrogation, he confessed to accidentally damaging the idols while collecting puja flowers that morning. Out of curiosity, he entered the pandal, collided with the Ganesha idol, and unconsciously touched and damaged other idols.
# 32
# While mobile internet has now been restored, Proton VPN has recorded a significant increase in VPN use in Bangladesh, with a 3500% spike in signups above normal level.
# 33
# According to the Bangladeshi Health Ministry, more than 1,000 people died in the violence that erupted during recent protests. Many were students and young people. DW spoke with parents who are seeking justice for their son, who was killed during the protests.
# 34
# Siblings from different mother 😂
# 35
# Nobel Laureate Professor @Yunus_Centre urged world leaders and the UN to end the violence and investigate the killings. Internet and phone services are cut off, silencing citizens as #Bangladesh faces a worsening crisis with at least 200 deaths and 700 injuries from attacks on protesters by police, Border Guard, and Chatra League. @JakeSullivan46 @SecBlinken @SenatorDurbin @SenMarkKelly @SenateDems @SenateGOP @SenateForeign @HouseForeign @TLHumanRights @antonioguterres @SecDef @StephDujarric @PressSec @RepMcGovern @RepLloydDoggett @Lacroix_UN @State_SCA protectyunus.wpcomstaging.co…
# 36
# Can someone from the @bdbnp78  preferably from the Zia Rahman family itself, please make a public statement that it does not support third-party defamation cases relating to anything said about Zia Rahman. These cases are just forms of harassment, and nothing else. #Bangladesh has had enough of such cases involving Sheikh Mujib. Please let us not start again with Zia Rahman. somoynews.tv/news/2024-10-14…
# 37
# yewtu.be/JJ-U3PB4xjQ
# 38
# Certainly not just "a dusty old academic"! ... And definitely worth following on twitter.
# 39
# Who will lead which sector reforms, says chief advisor
#
# Star Newsbytes
#
# A decision has been taken to initially form six commissions as part of the state reforms, said Dr. Muhammad Yunus, chief advisor to the interim government.
#
# He announced the matter in his address to the nation on Wednesday.
#
# #Bangladesh #MuhammedYunus #NewsUpdates
# 40
# yewtu.be/7wBSSw95NJ8
# 41
# Chilling statistics of 15 years of deprivation of voting rights & freedom of speech, enforced disappearances, extrajudicial killings, police oppression of opposition and dissidents, state-sponsored looting of banks & extensive corruption by Hasina’s regime thegreatwave.thedailystar.ne…
# 42
# agreed, hope they demonstrate some clear intention in the coming days.
# 43
# Hundreds of Hindutva group students protesting and chanting ‘Jai Shri Ram’ after seeing a single Muslim female student offering Namaz in the corner of a University campus in Uttarkhand, India. Modi has turned India to a crazy place!
# 44
# Why #bangladesh law enforcement officers may get away with murder!
# 45
# 9 Best #Bangladeshi Traditions: A Glimpse into a Rich Culture
# #bangladesh
#
# sera10.com/2024/07/25/9-best…
# 46
# Yet more detentions.
# 47
# This is the first thing that the international community has actually DONE in response to the massacre of Bangladeshi students by their own state. For now, it is just a postponement.
#
# Will other aid donors also get cold feet WRT Bangladesh?
# 48
# Considering the recent events in Bangladesh, an Australian legal firm has filed a communique with the International Criminal Court @IntlCrimCourt to consider the matter for preliminary examination, claiming that crimes against humanity have been committed in the country. The petition also seeks to accuse a total of 26 individuals, including Sheikh Hasina, of being involved in crimes against humanity.
#
# You as an individual can also assist in this petition by directly submitting all evidence to the ICC's OTP link. The link and instructions are mentioned in the following thread.
# 49
# Happy Diwali to you from all of us at team @UN in India 🪔🪔🪔🪔
# 50
# Trump is really popular in USA! Oh no! Where are you Kamala Haris?
# 51
# Increasing difficult to see the governing Awami league government in Bangladesh coming back from this. The only thing they have in their Arsenal is increased violence and repression which will not solve the crisis.
# 52
# One of #Bangladesh’s interim government’s strengths is having principled people like @SyedaRizwanaH and @AdilurKhan supporting @ChiefAdviserGoB.   They need to be vocal in standing up for the principles they defended so courageously before joining government.
# 53
# Impressive decision by new #Bangladesh government to dismiss all "speech offences" cases filed by the Awami League government under cyber-crimes legislation. en.prothomalo.com/bangladesh…
# 54
# A recent confidential report by a special intelligence agency has revealed that in the changing political situation, some people have been involved in extortion by occupying various establishments in different parts of the country. Today, detailed information about Dhaka and some of its related areas is to be released.
# 55
# It was the involvement of the Awami League’s student wing in attacking protesting students on 16 July that started this whole mess which could well result in the fall of the party/govt. It is therefore all the more remarkable that no one in the Awami League leadership thought to tell the leaders of its student wing that perhaps they should stay off the streets for the time being!
# 56
# What do you think about me?
# 57
# UPDATE: I dont know the details but I am hearing credible reports that Michael Chakma, an indigenous rights activist, who was picked up in 2019 and was disappeared, has been released from secret detention in #Bangladesh. Below is what Amnesty International wrote about him at the time of his detention. Will provide further details as soon as receive them. amnesty.org/en/documents/asa….
# 58
# It's been almost a month!
# 59
# I am being told that the @DhakaTribune 's reporting of some of what Azmi said was inaccurate. Going to get this checked and will remove/edit this tweet if this is the case.
# 60
# In this case about Government quotas, the Supreme Court may well be happy to do the government's bidding, but remember the last time that the court did not comply, back in 2017 when Surendra Kumar Sinha was Chief Justice, the government forced him to resign and leave the country. (if you dont know that story, it is worth while reading here - it involved the military intelligence threatening to kill one of Sinha's friends if he didn't leave!). aljazeera.com/news/2018/9/28…
# 61
# And more tbsnews.net/bangladesh/corru…
# 62
# Spelling correction: should be Lamiya Morshed
# 63
# This story is developing quickly. I have just spoken to AFP's fact checker Qadaruddin Shishir, who has confirmed that the video was (a) first posted on social media at least six years ago in 2018; (b) that in 2019, the Daily Mail along with other media, showing screen shots from the video, attributed responsibility for the crime to members of the Primer Comando da Capital, a Brazil-based criminal organisation, who were dismembering an associate of another group in a Paraguayan jail cell.
#
# Therefore the crime was not committed "yesterday" as @ArifaRahmanRuma claims. It also never occurred in #Bangladesh  at all, so Jamaat-e-Islami (as she also claimed) could not have been responsible.
#
# So just to be absolutely clear. Jamaat-e-Islami is totally exonerated from any involvement in the crimes depicted in this video.
#
# It is now clear that the posting of this video is a perfect example of disinformation being spread by certain supporters of the Awami League.  I think @ArifaRahmanRuma has totally discredited herself in relation to all her comments on Bangladesh.
#
# dailymail.co.uk/news/article…
# 64
# Nice to see @TheDavidBergman appears on Prothom Alo.
# He argues a crucial issue for the justice delivery system.
# Why the Bangladesh govt needs to appoint international judges to the ICT en.prothomalo.com/opinion/op…
# 65
# The Bangladesh government has now opened up the broadband internet in the capital Dhaka - after closing it as part of its crackdown on student protests. But unless you are connected to the internet by wires (i.e phones/laptops) there remains no internet (though in Gulshan, the exclusive part of Dhaka, there seems to be some WiFi  in some areas). The government remains scared.
# 66
# I think you should read my tweet again.
# 67
# You are right @volker_turk
# 68
# With the fall of #Bangladesh’s former prime minister Sheikh Hasina, it is time to bring renewed prominence to this investigation by @ZulkarnainSaer into how an aide to Hasina acquired a US property portfolio and hope authorities in Bangladesh and the US investigate occrp.org/en/investigation/b…
# 69
# Great news.
# 70
# A pure specimen of a pathological liar—see for yourself who is attacking whom. We are all aware of who provoked some members of the Ansar and the underlying reasons.
# 71
# Finally, a Bangladeshi television channel is bringing our investigative reporting to the general public.
#
# Thank you @ntvdigitals
# 72
# Khondoker Rashed Maqsood’s appointment as the BSEC chairman is yet another disastrous appointment.
#
# After the course correction the interim government went with within 24 hours of making its last announcement for BSEC chairman, we thought they would slow down and actually look for the best candidate. But no, they were in a rush to fill up this post.
#
# No offence against Mr Maqsood but he neither has the qualifications nor the profile to head the top post of a consequential regulatory body. And, most importantly, he doesn’t know the capital market well. What were the criteria for appointing Mr Maqsood? The interim government must come clean on this. This is unacceptable — and this appointment must be revoked. After the damages of the past 15 years, we cannot have the wrong person in this post.
#
# Seriously, if this is how the interim government led by Muhammad Yunus will go about its business, the sooner they call for elections the better it will be for the nation. This government says it has been in office for just a week and that we should give it some time. But the pace at which it is making one wrong appointment after another in that week — when there is no urgent need to fill up those posts — does not bode well at all. When all its focus should be on ensuring treatment for the injured and ensuring justice for the people wronged by the previous regime, this interim government is focused on promoting second-grade Awami League-affiliated people to consequential posts.
# 73
# Best #virtualcard in #bangladesh
#
# url.hk/i/en/zp755
# 74
# the path is long, but we are hopeful
# 75
# More than 200 officers from the armed forces have written to Chief Adviser Muhammad Yunus to consider their ordeal over the past 15 years.
# 76
# He may be a bit too old, but it would certainly be one in the eye for Sheikh Hasina if @yunuscentre becomes chief of the caretaker government.
# 77
# Professor Golam Rabbani
# Department of History
# Jahangirnagar University
# 29 July 2024
# 78
# None
# 79
# A retired officer of the Bangladesh Army, Lt. Iftekhar, expressed his solidarity with the student protesters today and urged others to join the cause. He said, "Our children are being killed, and we can't sit idle and watch this. Everyone must come forward, stand beside the students, and support their cause."
# 80
# Emirates flight 585, which was taxiing on the runway, was brought back to the boarding bridge, and Major General (dismissed) Ziaul Ahsan has been detained. Directorate General of Forces Intelligence (DGFI) members are taking him back to Dhaka Cantonment. Sincere thanks to everyone who assisted in the arrest of Zia.
# 81
# Check this out! foreign.senate.gov/press/dem… @SFRCdems @SenatorCardin @SenBooker @SenatorDurbin @EdMarkey
# 82
# History tells the history!
# 83
# And difficult now even to make phone calls.
# 84
# Amb Renggli attended the oath-taking ceremony of the interim government of 🇧🇩, led by Prof. Muhammad Yunus. The Embassy wishes the interim government every success in fulfilling the aspirations of the people of 🇧🇩 and in reinforcing social cohesion throughout the country.
# 85
# In case you forget Sheikh Hasina’s regime , here is a video that showed her force.
# 86
# Hasina identified as 'terrorist PM' worldwide! || #Bangla... yewtu.be/P5BEFsHWAF4?si=k72N… via @YouTube
# 87
# She is a total psychopath.
# 88
# "One of the men appointed as a judge to the #Bangladesh international tribunal due to hear allegations that Awami League politicians and others committed Crimes against Humanity during the post-July 2024 killings (a perfectly legitimate claim), is aligned with the Bangladesh Nationalist Party, a party in direct opposition to the Awami League, and victimised by it for many years. He also has never been a judge before (though a few days before this appointment he was made a High Court judge)."
# 89
# 150. Bangladesh 🇧🇩
# 90
# Which exchange please!
# 91
# The work worth 350 crores was completed in 1 crore 25 lakhs. The Awami fascist government has turned the country into a bottomless basket by stealing money from every sector of the country. Corruption in every sector will be brought to the fore in this way. There will be no place for corruption in the new Bangladesh.
#
# (-Admin)
# 92
# Here are the 86 people whom Human Rights Watch identified a few years back as disappeared in #Bangladesh, picked up by Awami League authorities, but whose wherabouts remain unknown. The new government authorities should now given each and every family an explanation now of what happened to them.
# netra.news/2022/whereabouts-…
# Error translating row 93: Request exception can happen due to an api connection error. Please check your connection and try again
# 94
# "This is like the metamorphosis of Sukumar Roy's H J B R Law. It was a handkerchief, but it became a cat. Let's open it up. The Ministry of Land has allocated a sandy beach-class land in Chittagong to Bashundhara, the country's influential business group, by showing it as a sink in the documents.
#
# The then Awami League government allocated 470 acres of land on the beach from three mouzas in Char Banshbaria Union of Sitakunda Upazila of Chittagong. Bashundhara wants to build petrochemical products, an oil refinery, an LPG plant and a port terminal there."
# 95
# Protestors have taken the streets of Chittagong, Bangladesh's port city.
# 96
# Stop spreading such propaganda, if you do not know who they are then please don't post such material. These are members of Bangladesh's Armed Police Battalion (APBN).
# 97
# The BTRC (Bangladesh Telecommunication Regulatory Commission) and NTMC (National Telecommunication Monitoring Center) of the authoritarian Bangladesh government are making every effort to cut off Bangladesh's communication with the outside world and to intensify the suppression of the ongoing student movement. These two agencies have instructed all mobile operators to block cellular data and have significantly limited the net speed provided by internet service providers.
# 98
# A country where hatred is nurtured can never prosper. The very rights for which so many sacrificed their lives are now being usurped. Bangladesh is not a land of a single group or ideology; it is a country of 170 million people, each with the right to express their opinion — freely. For instance, yesterday many danced in front of the burnt-down house of Sheikh Mujibur Rahman and no one stopped them! They danced and celebrated with joy. This is the beauty of democracy and living in a free nation.
#
# So why were those who went to pay their respects at Sheikh Mujib's house today attacked? Don’t they have the right to pay homage to their ideological guru? Many had their phones snatched and journalists were not spared too. Doesn’t this behaviour remind you of the oppressive regime that hundreds gave their life to get rid of? Doesn’t this behaviour remind you of the Chhatra League that we speak of with much disgust?
#
# We speak of Bangladesh 2.0, but if historical figures like Huseyn Shaheed Suhrawardy, Sher-e-Bangla AK Fazlul Huq, Maulana Abdul Hamid Khan Bhashani, Sheikh Mujibur Rahman, Tajuddin Ahmad, and Ziaur Rahman are not given their due respect, this new Bangladesh will come caving down like a house of cards. One cannot deny that Bangladesh was built on the work of these men. And followers of these men must be guaranteed the freedom to pay homage to them and engage in politics without obstruction. Bangladesh 2.0 is for all — including the Awami League that hundreds sacrificed their lives to get rid of. No section of society should be disenfranchised in Bangladesh 2.0.
#
# As long as we do not emerge out of this culture of pettiness, hatred, intolerance, bitterness, vengeance and animosity, we cannot really build a new Bangladesh, one that is a model to the world. Otherwise, it will be rinse and repeat of the repression of the past 15 years.
# 99
# “For the #bangladesh police to arrest them, there needs to be a criminal case which they can allege that person has committed, and because there has been no time to investigate whether these Awami League ministers have committed any offences, they are arrested on the basis of murder cases with which the detainees actually have no connection. The arrest for murder is simply a mechanism to get them out of army custody.”
# 100
# Who is head of Bangladesh's police, the particular force in Bangladesh that appears to be responsible for most of the shooting and killings of students and protestors in recent weeks? None other than Chowdhury Abdullah Al-Mamun. In December 2021, as then Director General of the Rapid Action Battalion, he (along with five other men) was sanctioned  by the US government for "widespread allegations of serious human rights abuse". Although the US invited the UK, EU and other countries  to sanction Al Mamun and others, they took no action. Will they act now? netra.news/2021/us-governmen…
# 101
# You are a Hindu Jihadist, a hindutva agent, not a Bangladeshi. I have many Hindu friends, they are peaceful and logical.
# 102
# ZI Khan Panna, a well-respected lawyer and human rights activist in Bangladesh, told journalists that the severity of the present Bangladeshi regime's cruelty would embarrass the SS forces of N**i Germany.
#
# 🎥 @channel24online
# 103
# On 24 July 2024, at an important turning point in the student-public movement, the then Prime Minister Sheikh Hasina met with editors, senior journalists and heads of news from various media outlets. The complete audio record of the meeting, which lasted for about 1 hour and 40 minutes, has been obtained. And it will be revealed step by step what opinions and advice these eminent journalists gave to Hasina that day.
# 104
# Dr. Muhammad Yunus being emotional after remembering the first martyr Abu Sayeed..
#
# #Bangladesh
# 105
# #Lebanon
#
# "16 attacks on health care have been recorded leaving behind 65 deaths and 40 injuries among health staff." - @WHO
#
# "We are seeing the same patterns that we saw in Gaza, the same methods of warfare and, as a result, civilians pay the ultimate price." - @UNHumanRights
# 106
# July Movement, Hasina Out
# 107
# Former Biman chairman Mustafa Kamal Uddin, accused of thousands of corruption charges, is seeking to flee the country.
#
# He was the senior secretary of the Public Security Department of the Ministry of Home Affairs for 6 consecutive years (until January 2023) from 2017. He has already secretly sent his son Mustafa Shadman Shakib, a member of the Youth and Sports Sub-committee of the Bangladesh Awami League, abroad. Reliable sources claim that his son is currently in Dubai, but his real destination is the United States.
#
# The source said that Mustafa Kamal Uddin has smuggled at least 5 billion taka abroad through hundi in the last few weeks after the fall of the government. This person can flee the country at any time if appropriate measures are not taken quickly.
# 108
# Well if you have as you say criticised the post July 16 Awami League law enforcement killings, it is neither on your own or @icsforum Twitter accounts, which I went through before writing my post. Now of course your Twitter account is full of criticism of the current government. Indeed you go so far as to suggest that “genocide” may have been committed post August 5th which is the most extraordinary assertion. I think my point is made.
# 109
# If Bangladesh’s Awami League no longer holds the mantle of holding “the spirit of the liberation war”, it has nothing! And therefore as professor Anu Mohammed says, it now has nothing.
# 110
# Good morning.
# Today is 11 Kartik 1431 Bengali.
# 111
# Dhaka University now at 12am..
# #Bangladesh
# #StepDownHasina
# 112
# I wrote stories against tyranny even during Sheikh Hasina's tenure. You will find those stories in the book "Paygambar" (The Prophet's Storybook). Next year I am writing a full-fledged book of stories against tyranny.
# 113
# Kudos to you all!
# 114
# Are you sure? Because @bdbnp78 was formed sometime in 1978/1979 Mujib was assassinated back in 1975 and I'm not sure why would the CIA get their hands dirty by killing a leader of one third world country?
# 115
# The signature shadow 🥰
# 116
# The Bangladesh Hindu Buddhist Christian Unity Council’s claims that the deaths of nine Hindu men in August were part of anti-Hindu “communal atrocities” in Bangladesh don’t hold up to scrutiny.
#
# "None of the deaths bore clear signs of religious or sectarian motives."
#
# Details: netra.news/2024/little-evide…
# 117
# The General Secretary of the UK Awami, League, Syed Farouq, who organised the rally (see below) was kind enough to agree to be interviewed. He blamed all the violence on the opposition parties, and when I tried to ask him about the killings by Bangladesh law enforcement authorities of at least 200 students/protestors/onlookers, well, he walked away ….
# 118
# Yes, it happened! ⁦@WSJ⁩ reporter Evan Gershkovich, ex-Marine Paul Whelan, and journalist Alsu Kurmasheva are back in the US. A joyous reunion at Joint Base Andrews, welcomed by ⁦@POTUS⁩  & ⁦⁦@VP⁩ tonight.  cnn.com/2024/08/02/us/video/…
# 119
# This is what Las Vegas looked like in 1895.
# 120
# Harish-Joseph's days are over, Picchi Helal's bus stand.
#
# Recently, the presidents and general secretaries of Wards 29, 31, 32, 33, 34 of BNP led by Mohammadpur Police Station BNP Senior Joint Convener Enayetul Hafiz held a meeting with the top terrorist Picchi Helal, who was released from prison.
#
# Also, Picchi Helal was seen standing and taking pictures with senior BNP leaders at the wedding of the daughter of notorious businessman Gias Uddil Al Mamun.
#
# According to reliable sources, Picchi Helal has started extortion at various places in Mohammadpur, including bus stands, markets, footpaths, business establishments, etc. On September 6, under the leadership of Ward 33 BNP President Mannan Hossain Shaheen, the company's employee Humayun was beaten up while extorting money at the Lalmatia office of Dot Internet.
#
# Humayun is physically disabled. Victim Humayun has filed a GDO with Mohammadpur Police Station against unknown persons in this incident.
#
# These incidents are absolutely undesirable, just as it is not desirable for top leaders of any political party to take pictures with someone known as a top terrorist or to attend a controversial businessman's invitation.
#
# We have worked for a changed Bangladesh, and in that Bangladesh, such activities must be strictly suppressed, there will be no opportunity here to operate a terrorist network using extortion-corruption-political identities.
# 121
# If you want to see "Bangladesh's Response To India" Video on other platforms:
#
# Facebook: tinyurl.com/yra5sm8j
# YouTube: yewtu.be/6vgM0TbrvEI
#
# Thank You for the Support!
# 122
# One of the primary reasons why #Bangladesh's Monsoon Revolution succeeded in overthrowing the Hasina regime was that it was a broad-based popular movement united around a single goal.  It was an indigenous movement that drew support from the Bangladeshi diaspora and like minded individuals around the world.   As the movement grew during the month of July and into early August, there was little doubt which side was in the right.
#
# As the focus shifts from toppling a dictator to building a new country, it is inevitable that divisions will emerge within the popular coalition.   Differences of opinion are not  bug in a democracy, rather they are a feature.
# It is essential that these differences come to the surface and are debated openly.   Bangladesh has a unique opportunity to develop a culture of tolerance and mutual respect that can be passed along to future generations.
#
# At the same time, history is full of examples of the revolutionaries turning on each other, diverting energy from achieving the revolution's goals.    Chaos ensues as the reign of terror proceeds, ultimately setting the stage for counter revolution and a return to the status quo ante.   While a majority clearly wants to see the current interim government succeed in meeting the aspirations of the people, there is a determined minority that wants it to fail.    For Bangladesh, this is not a prediction but it is a warning.
# 123
# Most probably
# 124
# 🧵1/2
#
# Muhammad Yunus's glorification of students has been fuelling mob justice on campuses and across the country — there is no better way to put it. In every speech, he is excessively praising the students and attributing them as the sole reason for the fall of the autocratic Sheikh Hasina government.
#
# However, the narrative Muhammad Yunus is peddling is fundamentally flawed. In so doing, he is disregarding the sacrifices of the common people, who had their backs to the wall from the 15 years of kleptocratic, treasonous Hasina government. I can’t stress enough that it was not just the students who ousted the dictator — the sight of the common people who stood shoulder to shoulder with the students or in some cases, as shields to the students, elicited the barbarity of the state forces that the world witnessed. In fact, more common people died than public university students. The brutality of the regime angered the nation so much that after 18 July, it was the ordinary citizens — the poor & the middle class, the private university students, the madrassa students — who carried forward the protests. The students were outnumbered in the protests.
#
# From that point forward, these ordinary people became the flag bearers of the movement, transforming it into a mass uprising. They took bullets for the students. Many impoverished individuals, slum dwellers, and those suffering from skyrocketing inflation marched towards the automatic rifles — unarmed, with bare chests and arms wide open.
#
# Before the students even announced their one-point demand for Hasina's resignation, it was the citizens who first made that call. Hundreds of pictures and videos from 2, 3 and 4 August show ordinary people and civil society members demanding Hasina’s resignation. Without the participation of BNP and Jamaat supporters — who took control of the streets on 4 and 5 August and suffered numerous casualties— removing the dictator would have been impossible.
#
# Mr Yunus's exergerattaed narrative, which gives students sole credit, risks causing great harm to the nation. Ordinary people, already frustrated by mob justice and student misconduct, feel increasingly disenfranchised as students dominate the political scene. The poor and the middle class, the unsung heroes of the movement, who fuelled it with their lives are discovering no change in their circumstances and are beginning to feel betrayed. This is most ironic considering that Mr Yunus earned his fame for his pro-poor activities. By harping on and on that he is here to materialise the students’ aspirations, he is dividing society.
#
# This narrative is also causing long-term damage to the students. Many are struggling to return to their studies or their previous way of life as they get themselves overly involved in the so-called “state repairs”. It’s almost as if these 20-somethings have a panacea for all of Bangladesh’s problems — and only their opinion is valid. While students can play a role in rebuilding, the task of shaping the nation should be left to the experienced, capable individuals — and not those who were beneficiaries of the previous regime.
# 125
# "We don't know why we agreed to pay this huge amount of public money without any financial viability -- it's like the value of money has been reduced to that of jackfruit leaves and we are feeding it to a goat which will never yield any benefit to us," said a top official of the BTRC on the condition of anonymity to speak candidly on the issue.
# 126
# The key article on this is netra.news/2022/secret-priso… which has some other fascinating information form those who were detained within it.
# 127
# We are waiting oliver 🍅
# 128
# @revolt_71
# @TheDavidBergman
# @ZulkarnainSaer
#
# What do you think of the new advisors?
# 129
# A must watch interview of Mr Mahfuz Anam, Editor, @dailystarnews on the recent developments in #Bangladesh
#
# yewtu.be/PmDsTFQDsVg?si=51or…
# 130
# Smita Sharma, an independent Indian journalist, who is currently visiting Bangladesh, talks about the state of Indian media in response to various questions from a Bangladeshi student, Tathira Baatul.
#
# I am actually quite impressed with Tathira, another good example of our savvy Gen Z.
# 131
# 🎉 We just hit 4 MILLION players! 🎉
# A huge shoutout to the #CapybaraNation fam for getting us here—y’all are the real MVPs. 🙌🚀
#
# But the best is yet to come—get ready for major partnerships dropping soon, along with our EPIC Q4 airdrop that you won’t want to miss! 💥💸
#
# Who’s ready to take Capybara Nation to the next level? 💪🌍 Play now: t.me/capybara_nation_bot
#
#  #Airdrop
# 132
# Fascinating. The loosening of loyalty towards #bangladesh’s governing party, the Awami League, is the beginning of the undoing of the prime minister Sheikh Hasina’s power.
# 133
# Binance is exciting 😜
# 134
# And then there is this detailed interview with Michael Chakma, the third disappeared person to be released. It is difficult to know how any of these three men found the fortitude to survive. theguardian.com/global-devel…
# 135
# Let me be clear on Bangladesh. Interim govt is secular left. It doesn’t seek the persecution of Hindus and other minorities, but extremely worrisome incidents are occurring on a regular basis. Chalk this up to a chaotic transition that the Yunus govt will hopefully rein in soon.
# 136
# Transforming Ganabhaban into a Museum
#
# In today’s video, I explore the government’s decision to turn it into a museum and whether it could have been put to better use for the people.
#
# • The Role of Museums
# • The Power of Art & Film
# • Missed Opportunities for Public Use
# 137
# Chinese Fairy Tale: The Monkey King
#
# dorpon.com.bd/%e0%a6%b0%e0%a…
# 138
# Protest in front of the @WhiteHouse expressing solidarity with the student movement in #Bangladesh and the non-cooperation movement from abroad. #WATCH more in the video-
# 139
# @WHO @UNHumanRights the perpetrator of a mass Slaughter who just fled #Bangladesh works for you ... The daughter @drSaimaWazed of fallen despot #hasina  is your proud Asia Director appointed by recommendations from the fallen dictatotor .
#
# @TuckerCarlson @NickJFuentes check this out ... @WHO  employed politically appointed daughter and key advisor of a fallen despot whose regime members were already under US sanctions for rights violations. It is like employing Gaddafi or Saddam children as Directors of @WHO claiming innocence.
#
# @WHO continued to employ the daughter as Asia Director even after both the despot and the daughter fled #bangladesh after killing at least 500 student protestors. @cnm @BBCWorld
# 140
# I have always been on the side of the oppressed, I am on the side of the oppressed, and I will remain on the side of the oppressed.
# 141
# Yesterday, during clash with security forces, agitated students set fire to a metro rail station in Dhaka, Bangladesh.
#
# 🎥 Hasan Abid
# 142
# Requesting @elonmusk to look into the ongoing issues in #Bangladesh, where the authoritarian government has completely disconnected the country from the rest of the world. All cellular networks and the internet have been shut down. Today, police violence resulted in the deaths of at least 32 people, most were students aged between 17-25. They were continuing a protest, demanding the reform of a highly controversial quota system.
#
# I'm drawing your attention to the urgent need for a temporary @Starlink solution for the people in Bangladesh, as we believe the government is planning a major offensive operation tonight. Kindly provide some form of support so that the people in Bangladesh can regain connectivity with the rest of the world.
#
# Your kind assistance in this matter would be greatly appreciated.
# 143
# Debunking the myth: A coordinated disinformation campaign, spearheaded by some Indian media and cronies of Sheikh Hasina’s autocratic regime, is spreading false claims about Muslim attacks in Bangladesh. #FactCheck
# bbc.com/news/articles/cx2n8p…
# 144
# Sacha Deshmukh, Amnesty International's UK CEO at a meeting in parliament yesterday evening:  "There is overwhelming evidence that the protestors in #Bangladesh were exercising a human right to protest. There is overwhelming evidence that the use of lethal and sometimes less lethal but still severe force has been used unlawfully by security forces in Bangladesh. We have rarely seen at Amnesty International such film footage evidence of such brazen and clear open firing nf protestors and we look at the situation all around the world. We should remember that the security forces in Bangladesh have a near total monopoly on holding fire arms …. So when we do see such high death toll, it is very very difficult to attribute that to anything other than use of lethal force by state actors. The scale of the deaths which we have seen … even the numbers which we have been able to verify in the time frame  of those deaths, I am sad to say represent  a scale of killing of protestors which is very severe even by standards of what we see anyway around the world."
# 145
# There should be freedom of the media. The Awami League has got the results of banning the media. Banning the media is not a good thing at all.
# 146
# Abrupt venue change for ⁦@WHO⁩ regional meeting casts spotlight on Putul's controversial appointment again. en.banglaoutlook.org/editors…
# 147
# The PS of Education Minister Mohibul Hasan Chowdhury Nowfel sent this person to Mohsin Hall with the order to provide money to the Chhatra League leader to attack the students.
#
# Later, the students of DU Mohsin Hall caught him, and the identity of this person was Al Amin Rimon, the vice-president of the defunct committee of Chittagong University Chhatra League.
# 148
# Whose fertile brain is the Bangabhaban siege program today? And I knew Manabzamin's Matiur Rahman Chowdhury to be quite thoughtful. Is the discussion about whether the puppet president saw Hasina's resignation letter, who fled the country in the student-public revolution, or not, really important? The MPs-ministers who won the fraudulent elections of the Awami regime and all the senior leaders of the party have entered the hole. President Shahabuddin himself dissolved the 12th National Parliament. Even then, it was not logical for the Manabzamin editor to create hype around Hasina's resignation letter in the critical situation of the state.
#
# In these three months of the interim government, a dirty attempt has been going on in the columns of some domestic and foreign newspapers to make the army face the students and the public. The army chief and the CGS, these two officials, are currently abroad. If those who are trying to destabilize the situation in the country by taking advantage of their stay abroad think that in this way, fascists can reappear in Bangladesh, which was free from fascism thanks to the contribution of thousands of lives, then I pity them.
#
# Those of you who are planning to surround Bangabhaban, you can go home and sleep for now.
# 149
# Bangladesh politics comes to Camden Council in London tonight. Nazma Rahman, a Camden Councillor, and until recently its Mayor, is asking the Council to give her a waiver from attending Council meetings as she claims that following the “recent political turmoil in the country”, she is in “hiding” and as a result it is “extremely difficult for her to travel safely and to return to the UK.”
#
# The recent political turmoil being alluded to here is the removal from power in Bangladesh of the Awami League and its leader, the former prime minister of the country Sheikh Hasina, after their law enforcement authorities killed 100s, perhaps as many as 1,500, unarmed protestors.
#
# Rahman is married to Azadur Rahman Azad who is the president of the Sylhet district student wing of the Awami League in Bangladesh. The student wing of the Awami League were seen by many as the “enforcers” of the party.
#
# It seems that at the time of the protests in July 2024, Rahman and Azad were in Bangladesh, and reports suggest that Azad fled to India after Hasina fell.
#
# It remains unclear why Rahman (and her children) should have any difficulty flying back to UK – whether it be from either India or Bangladesh - as she is not suspected of committing any offences and she is not being sought. Her husband may be in a more difficult position because of his senior role within the Awami League in Sylhet.
#
# A notable side story to this is that Nazma Rahman is an acolyte of Tulip Siddiq MP, the MP for Hampstead and Highgate (who was herself a Camden Councillor) and Rahman is Siddiq's constituent.
#
# Siddiq, also a labour minister, is of course the niece of the deposed prime minister Sheikh Hasina, and she has had a very close relationship with the UK Awami League through much of her UK political career.
# 150
# Inevitable. The Bangladesh government had no choice, as having killed over 100 people since Monday, law enforcers could not have managed to contain the fury of the public response. But what does military deployment on the streets of Bangladesh mean for the future of the Awami League government? Does this action save the government or is it the beginning of the end for them?
# 151
# #Bangladesh
# thousands—I repeat, thousands—in Dhaka alone have taken to the streets. Their initial nine-point agenda has now coalesced into a singular, resolute demand: the downfall of the current regime and the restoration of democracy in Bangladesh.
#
# for me, at 30, witnessing such a massive, spontaneous mobilization of people from all walks of life united for a common cause is unprecedented. This is a hands-on lesson in the power of a people's uprising, unlike anything I've ever seen before in my lifetime.
# 152
# Well said @TheDavidBergman. These cases undermine the image of #Bangladesh’s interim government and play into the hands of the apologists for the Hasina regime. The @bdbnp78 leadership, starting with @trahmanbnp, also need to understand that this score settling also hurts them.
# 153
# ...
# 419
# Education, Peace and Progress.
# Bangladesh Chhatra League is the organization of the youth. Joy Bangla, Joy Bangabandhu.
# 420
# The terrible independence of 24, the evil attempt to erase the history of 71 #AllEyesOnBangladesh #StepDownYunus #SaveBangladesh #BangladeshCrisis
# 421
# This year, Hindus at the Puja Mandap organized at JSM Sen Hall in Chittagong experienced an experience they had never seen before. Shibir activists performed Islamic Revolution songs from the stage, which were intended for Hindu devotees. During this forced performance of the song, there were
# 422
# The courts in "new" Bangladesh are no longer safe, not just for the accused but for lawyers too. Recently, a lawyer aligned with BNP and Jamaat-e-Islami openly assaulted a defense counsel representing former MP Barrister Suman while he was briefing the media at the court
# 423
# Fishermen in the Bay of Bengal are facing a rising wave of robberies while the  led interim government fails to act. Over the last three weeks, at least six fishing trawlers from Cox's Bazar, Moheshkhali, and Banshkhali have been attacked by #armed #robbers. These
# 424
# On August 5th, extremist terrorists, under the guise of the quota reform movement, attacked Faridpur Kotwali Police Station, setting it on fire and looting police weapons.
# 425
# Angry mob blocks BGB after trying to frame UP chairman with Phensedyl. #BangladeshCrisis #NewsUpdates #Bangladesh
# 426
# Finally, the vulture's paws are on the poor's food plate #Shame #BNP #BangladeshCrisis
# 427
# Two students of the marketing department have been accused of psychological harassment and torture of a new student of the 2023-24 academic year of Rajshahi University in the middle of the night. In addition to harassment, he also threatened to kill the student by 'bringing him to the camp'. #Ateam
# 428
# Last week, 10,000 crore taka was looted from the stock market, this week, 13,000 crore taka was looted. This means the amount of loot is increasing week by week. In the last 38 days, 31,000 crore taka is missing!
#
# Darvesh 2.0 taka #BangladeshCrisis #StepDownYunus
# 429
# This is our independent country #BangladeshCrisis #MuhammadYunus #Yunus
# 430
# From the role model of development, Bangladesh, to a hurricane in 1 month ★Someone stop this man, Bangladesh, who sings bamboo, please. #MuhammadYunus #BangladeshCrisis
# 431
# The three coordinators of the movement, Arif Sohel, Labib and Siam, beat Shamim Molla twice.
#
# Later, the beating was led by former Chhatra Dal secretary Sayeed (33rd batch), Raju (45th batch), and Hamidullah Salman.
#
# Coordinator Labib is the son of the Chandpur district Ameer of Jamaat-e-Islami. #JU #Shame #Bangladesh
# 432
# Don't be nervous, just be prepared...
# 433
# 'The one whose birth was a mistake today is Asif Nazrul' #BangladeshUnderFascism #KillerYunus #StepDownYunus #BangladeshCrisis
# 434
# Today, everyone can see what they have written about Durga on the display board of Harun Hotel in the Basabo Buddhist Temple area of ​​Dhaka. This is the new freedom. Earlier, they used to say this on Facebook, now they say it with colorful LEDs.
#
# Location: Harun Hotel, Basabo Buddhist Temple. #SaveBangladeshiHindus #Bangladesh
# 435
# Shocking and tragic: Militants attack an innocent person with sharp weapons in broad daylight in Bangladesh #StopViolence #CommunitySafety #StandAgainstTerror #BangladeshCrisis#AllEyesOnBangladesh
# 436
# https://bdnews24.com/bangladesh/52f414822b52…**Why the Silence on the Horrific Arson at #GaziTires, Where 220 People are Still Missing?**
#
# This fire was a deliberate act of arson by BNP-Jamaat terrorists, yet the so-called #government hasn't filed a single case. Is this what #reform looks like
# 437
# How shameless of you to say, "It's not a mistake," instead of repenting for your mistake.
# 438
# In the hands of talented student coordinators in Dhaka University, the tofazzal #Shame #DhakaUniversity #BangladeshCrisis
# 439
# Shibir's Islamic music performance takes over the stage of the Puja Mandap in Chittagong.
#
# If you want more videos, let me know. Stock is full...#BangladeshCrisis #Chittagong #SaveBangladeshiHindus
# 440
# Welcome to all of you in East Pakistan. The death anniversary of the Father of the Nation of Pakistan, Jinnah, is being celebrated in the VIP lounge of the National Press Club. There is no such shameful incident in the history of Bangladesh.
# One of the speakers said, "If it were not for Jinnah, there would be no Bangladesh" #BangladeshCrisis #Pakistan
# 441
# **Bangabandhu's March 7 Speech Among 8 National Days Canceled by Interim Govt, Nahid Says "Sheikh Mujibur Rahman is Not the Father of the Nation** The interim government's deliberate assault on the very soul of Bangladesh is nothing short of alarming.  and
# 442
# “Accept or not accept the suicidal decision
# Mass march of Saint Martin residents”Video - Barta 24 #SaveSaintMartin #Bangladesh #SaveBangladesh #KillerYunus #BangladeshCrisis #SaveBangladesh #BangladeshUnderFascism #Fascism #FascistYunus #StepDownYunus
# #SaveBangladesh
# 443
# #BNP #Terrorists #beat #to #kill #Alimuzzaman Chowdhury, son of #freedomfighter ------
#
# On September 13, BNP terrorists led by Gopalganj Sadar Upazila BNP President Sikder Shahidul Islam Lenin attacked the son of freedom fighter Alimuzzaman Chowdhury at Ghonapara Market and
# 444
# Before Tofazzal could get a proper trial, he had to go to the mountains! Before he could get down from the mountains, he reached India with Hilsa. When I came back, I saw everyone in the camp #season2 #BangladeshCrisis
# 445
# So much effort to shift blame to whom? https://ateam.vision/2024/10/16/157/#Ateam #Bangladesh
# 446
# **Interim Government Failing to Ensure Law & Order Amid BNP-Jamaat Violence**
#
# BNP-Jamaat terrorists in Dhaka brutally attacked and injured Parvez, a Chhatra League leader from Jhalokathi district. Violence is escalating across the country, yet the interim government is
# 447
# **This is the current situation in Bangladesh** #AllEyesOnBangladesh #JusticeForAll #SaveBangladesh #BangladeshCrisis
# 448
# If you were given 5 minutes to slap anyone among your advisors, who would you slap first?
# 449
# Rag Kata Shibir vs Badda
# 450
# Coordinator's confession of police massacre - What does the law say? 'Immunity' or punishment? #Repost #ATeam #Bangladesh #BangladeshCrisis
# 451
# According to media reports, nearly 100 citizens have fallen victim to mob lynching in just the last 40 days. Despite this alarming trend, the authorities have taken no visible action since the  took oath on August 8. The home advisor only addressed lynching today,
# 452
# "Bangladesh is facing an unimaginable crisis under the interim regime. Innocent lives lost, families shattered, and justice ignored. Every day, we witness the horrifying reality of violence. This must end. The world cannot stay silent! #StopTorture #HumanRightsViolation
# 453
# BNP professional terrorists beat up Deepto TV journalist to death
# ------------
#
# A Deepto TV broadcasting department official was beaten to death by BNP professional terrorists. Twenty to 25 terrorists entered the house of Tanjil Jahan Islam Tamim, who was killed after occupying his house.
# 454
# Today, the Attorney General for #Bangladesh Mr. Asaduzzaman made a shocking claim in public. He said since the fall of the Hasina Govt, there has been NO "extra judicial killings" in #Bangladesh and the credit for that goes to Dr. #Yunus-led regime's Law Adviser Dr. Asif Nazrul.
# 455
# Cash Crisis Hits Sylhet...Despite having hundreds of thousands of taka in their accounts, customers at National Bank branches in Sylhet are being limited to withdrawals of just 3,000 taka.
#
# Unable to access their funds, frustrated customers locked the gates of National
# 456
# A young man named Nazmul (24) was beaten to death in public at a tea shop in Dohar, Dhaka by miscreants. Another man named Milan was injured in the incident.
# 457
# Source:
# 458
# **You are immortal in the hearts of Bengalis, Sheikh Mujibur Rahman.**#SheikhMujiburRahman #Bangladesh
# 459
# The three injured are Maulana Moniruzzaman Ojibullah (35), Md. Naeem Abdullah (30) and Al-Amin (28).
#
# The injured Naeem said that his elderly mother begged for his life and rescued him on the condition that he would never be involved with the Jamaat-e-Islami organization again.
#
# Location: Patuakhali, Baufal, Kanakdia
#
# To be continued..
# 460
# The state of the country's leading media
# 461
# International media is now focusing on Sheikh Hasina’s leaked phone call, where she firmly stated that she **has not resigned**. This revelation further confirms that the so-called interim government is completely unconstitutional. As per the constitution of Bangladesh, Sheikh
# 462
# Chittagong University coordinator and camp leader Rezaul Karim Saeed arrested by mob while performing funeral
# 463
# During an idol immersion procession from Tanti Bazar, miscreants threw bricks at idols in Patuwatuli. When Hindu youths protested, the army baton charged them instead of arresting the offenders, injuring several people who are now in Mitford Hospital.#SaveBangladeshiHindus
# 464
# Dhanmondi 32 and the Father of the Nation Bangabandhu Sheikh Mujibur Rahman are a reflection of the existence of the Bengali nation. Those who touched it have their hands burned. Even the moneylender may not have imagined how the Bengali nation will take revenge for burning Dhanmondi 32. #SheikhMujib #Bangladesh #Bengali #FatheroftheNation
# 465
# Asif Nahid Gong is looking for a resignation letter in Ganabhaban, because Inus Kaga could not have gone to America without a resignation letter #Ateam #BangladeshCrisis #Yunus #MuhammadYunus #Shame #Resignation #Asif #Nahid
# 466
# The Yunus-led interim government has announced new directives limiting travel to Saint Martin's Island.
#
# According to the new decision, while tourists will be allowed to visit Saint Martin's Island in the upcoming month of November, overnight stays will not be permitted.
# 467
# Jamaat is not a political organization; they are a multinational, multi-dimensional business entity. Politics is just one dimension, and religion is another dimension of their business.  #Ateam
# 468
# in
# 469
# Tapashee of Bangladesh, Our Joan of Arc I request everyone to Stand with our brave sister Executive Magistrate Tapashee Tabassum Urmi.
#
# Sis, you droped it #tapasheetabassumurmi #joanofarc #tapasheeofbangladesh
# 470
# Recently, a tense incident occurred in the court premises where Barrister Suman's lawyer was physically assaulted by lawyers affiliated with BNP-Jamaat. Violating court discipline, they forcibly dragged and shoved him by the neck, removing him from the premises. Such actions are
# 471
# #Murderers are roaming openly in #Mirpur.
# #Administration is silent even after killing in broad daylight.
# Allegation of not taking the name of the accused in the case after eating money.
# ------------------------ #If you complain to the police station, you will not get justice, instead of #threats will be given to the victim's family
# In Mirpur
# 472
# Brother, first calculate the relief money #Shame #Sarjis #BangladeshCrisis #Yunus
# 473
# BNP leader Mirza Abbas's wife Afroza Abbas is ordering a massive case to be filed against Saber Hossain Chowdhury and other Awami League leaders and activists...
# 474
# Even basic human rights are failing disabled people in #Bangladesh. Tofazzal, a man with a disability, was brutally beaten to death at a Dhaka University dormitory after his family couldn’t pay a ransom of 35,000 BDT. The killers falsely claimed it was over a stolen mobile.
# 475
# Hasnat Abdullah and Sarjis Alam, one of the coordinators of the anti-discrimination student movement, have withdrawn their writ petition seeking a ban on the activities of 11 political parties, including the Bangladesh Awami League and the Jatiya Party.
#
# On Tuesday (October 29), Justice Fatema Nazib and Justice Sikder Mahmudur
# 476
# "We have made it clear that there is no excuse for violence, whether it is against peaceful protesters or if protesters themselves are engaging in violence. Whoever is responsible for the violence must be held accountable." - US State Department
# 477
# Uproar at IGP's meeting in Rangpur #Bangladesh #Police #IGP #BangladeshCrisis
# 478
# Video: Khaled Mohiuddin at the address...
# 479
# 25 journalists named alongside deposed PM Hasina in murder case.
# 480
# Sheikh Hasina's government gave 1300 tons. This government is giving 3000 tons.
#
# Now, who are the brokers of India? Question to the Madharchos. #BangladeshCrisis #Shame #CCTV #IndVsBan
# 481
# Yunus' government is illegal, Sheikh Hasina has made many visible developments for the country Video - I News BD #OnceAgainSheikhHasina #JoyBangla #BangladeshAtRisk #StepDownYunus #BangladeshUnderFascism
# 482
# Both Jose! I gave them both...#thief #thiefgoddess
# 483
# The  team missed a good opportunity to confront/question the #BangladeshArmy Chief Waker Uz Zaman on some key topics which demands the general's responses, such as:
#
# 1. Allegations of 4 custodial torture and deaths in recent weeks at the hands of army-led joint forces;
# 484
# News https://kalbela.com/country-news/121703…?
#
# **Violence in Kasba, Brahmanbaria: Extremism by Hefazat-e-Islam & Jamaat-e-Islami Against Peaceful Procession – What Form of Extremism is Rising in Our Country That People Are Obstructed From Practicing Islam? Where is the Interim Government and
# 485
# But I have killed the state's ho★
# 486
# After the DC recruitment scam, Sargis and Hasnat made a big trade in appointing judges to the High Court. That is why students are being used. This time students should stop them. #BangladeshCrisis
# 487
# Leaders of the Bangladesh Hindu Buddhist Christian Oikya Parishad have termed the "communal violence" targeting indigenous and religious minority communities in the hills and plain lands "crimes against humanity".
#
# Addressing the interim government,they said, "Do whatever
# 488
# Bangladesh won their final group stage match against India 3-1 on Wednesday at the Dashrath Stadium in Kathmandu, Nepal. #Bangladesh
# 489
# In Islampur, under Damudya Police Station, Shariatpur, a Jubo League activist named Russel Sardar was hacked and killed by Saiful Madbar, the president of the Islambur Union branch of the Chatra Dal #BNP.
#
# Jubo League activist Russel Sardar was hacked and killed in Islampur, under Damudya Police Station, Shariatpur
# 490
# #Yunus #government has filed 1,474 cases against 1 lakh #AwamiLeague #workers in a #conspiracy to wipe out #AwamiLeague again -------#StepDownYunus #BangladeshCrisis #StandWithSheikhHasina #AwamiLeague #OnceAgainSheikhHasina
# 491
# Local Jamaat leader Ashrajman Tipu has been accused of looting fish using a net from a fish pond in the Gobindapur area of ​​Kalidaha Union in Feni Sadar Upazila. #Shame #BangladeshCrisis
# 492
# Black Paradise tickets are on sale, contact us quickly...
# 493
# References:
# Islam, Rafiqul. (1978). The Bengali Language Movement and the Emergence of Bangladesh. Contributions to Asian Studies. Leiden: Brill.
#
# Jahan, Rounaq. (1980). Bangladesh politics: problems and issues. Dacca: University Press.
#
# Maniruzzaman, Talukder. (1988). The
# 494
# Rice hotel for the talented. Here rice is available at the price of life. #DhakaUniversity #Shame #BangladeshCrisis
# 495
# What is happening in Bangladesh. What is happening in the hill districts of Bangladesh. This video footage is irrefutable evidence of that.#Shame #BangladeshCrisis #CCTV #MuhammadYunus #Yunus #SaveBangladeshiTribals #SaveBangladeshiMinorities
# 496
# Those who shouted 'Ra.Jakar, Ra.Jakar' slogans at Dhaka University that day are the true successors of Ra.Jakar...#ATeam #BangladeshCrisis #DhakaUniversity #Shame #Yunus #Bengalis #Pakistani #cctv
# 497
# But he has already said, what has started to match? Enjoy Western Freedom The funnest part of Zenjigo is that tagore bhu*dai is easy to make! But it's hard to believe that someone is making a bhu*dai in Tagore #BangladeshCrisis#Shame #Yunus
# 498
# Good morning Bangladesh #BangladeshCrisis
# 499
# Asif Ali Jinnah #MuhammadAli #AsifAli

# %% [markdown]
# # Mistral

# %%
import os
from mistralai import Mistral

# api_key = os.environ["MISTRAL_API_KEY"]
api_key = os.getenv("MISTRAL_API_KEY")

model = "mistral-large-latest"

client = Mistral(api_key=api_key)

chat_response = client.chat.complete(
    model = model,
    messages = [
        {
            "role": "user",
            "content": "Who is travis head?",
        },
    ],
    temperature = 0
)

print(chat_response.choices[0].message.content)
# Out:
# Travis Head is an Australian cricketer known for his all-round abilities, particularly as a left-handed batsman and a right-arm off-break bowler. Born on December 29, 1993, in Adelaide, South Australia, Head has represented Australia in various formats of the game, including Test cricket, One Day Internationals (ODIs), and Twenty20 Internationals (T20Is).
#
# Head made his international debut for Australia in 2016 and has since become a regular member of the national team. He is known for his aggressive batting style and has played a significant role in Australia's middle order. In addition to his international career, Head has also played domestic cricket for South Australia and has been a part of various franchise teams in leagues around the world, including the Indian Premier League (IPL) and the Big Bash League (BBL).
#
# Head's contributions to the Australian team have been notable, and he continues to be an important player in the country's cricketing landscape.

# %%
import os
from mistralai import Mistral

# api_key = os.environ["MISTRAL_API_KEY"]
api_key = os.getenv("MISTRAL_API_KEY")

model = "mistral-large-latest"

client = Mistral(api_key=api_key)

def translate_tweet_mistral(tweet, model = "mistral-large-latest"):

    
    # LLM prompt to extract entities
    entity_extraction_prompt = f"""
    Translate the tweet into ENGLISH. And Remove hashtags if any.
    Do not give any pleasantries in the reponse. Only the translation, No extra words. or explanation.

    tweet:
    {tweet}
    """
    response = client.chat.complete(
        model=model,
        messages=[{"role": "system", "content": "You are a helpful assistant. You translate text into english. Dont give explanation"},
                    {"role": "user", "content": entity_extraction_prompt}],
        temperature=0
    )
    # time.sleep(15)
    # print(response)
    # entities = response["choices"][0]["message"]["content"].strip()
    translated_tweet = response.choices[0].message.content
    return translated_tweet

def detect_political_stance(tweet, relational_text='', tweet_info='', unstructured_data='', model = "mistral-large-latest"):

    
    # LLM prompt to extract entities
    entity_extraction_prompt = f"""
    You detect whether a tweet is pro-awami league or anti-awami league. 
    you answer in just 0 and 1. You detect political stance whether pro-awami league:1 or anti-awami league:0.

    NO EXTRA WORDS OR EXPLANATION OR PLEASANTARIES IN YOUR RESPONSE.

    usually pro-awami tweets condemn the movement and anyone who allied with movement.
    and anti-awami tweets condemn hasina and her policies.

    for your decision making a few general info is given. from this info you can figure out the political relations in bangladesh

    tweet:
    {tweet}

    TWEET_INFO:
    {tweet_info}
    
    GENERAL INFO:
    {relational_text}

    Extra info:
    {unstructured_data}
    """
    print(f"length: {len(entity_extraction_prompt)}")
    response = client.chat.complete(
        model=model,
        messages=[{"role": "system", "content": "You are a helpful assistant. you answer in just 0 and 1. You detect political stance whether pro-awami league:1 or anti-awami league:0."},
                    {"role": "user", "content": entity_extraction_prompt}],
        temperature=0
    )
    # time.sleep(30)
    # print(response)
    # entities = response["choices"][0]["message"]["content"].strip()
    translated_tweet = response.choices[0].message.content
    return translated_tweet

# %%
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import time
# Read the CSV file
df = pd.read_excel(r"F:\EUCLIDO\Tasks\knowledge_graph\all dataset\non_matches.xlsx")

model = "mistral-large-latest"

for index, row in df.iterrows():
    # if(index <300):
    #     continue

    translation = str(row['translated_text_google_translator'])
    # tweet_info = structured_retriever(translation)
    # unstructured_data = [el.page_content for el in vector_index.similarity_search(translation)]
    # unstructured_data = []
    try:
        structured_data = structured_retriever(translation)
    except Exception as e:
        continue
    # try:
    #     unstructured_data = [el.page_content for el in vector_index.similarity_search(translation)]
    # except Exception as e:
    #     continue

    # length = len(str(unstructured_data))
    # length = int(length/30)
    # unstructured_data= (str(unstructured_data)[:1000])
    # print(f"Translated Tweet: {translation}")  
    stance = detect_political_stance(translation, relational_text, str(structured_data), unstructured_data='', model=model)
    print(f"{index}: {stance} {row['label']}")
    # print(f"Stance:\n {detect_political_stance(translation)}")

    # print("---")
    # break  # Break after the first row to test
    df.at[index, 'prediction'] = stance

    # new_row_df = pd.DataFrame([{'university': 'toronto', 'dept_name': dept, 'source_url': href, 
    #                             'name': name, 'designation': designation,'email': email, 
    #                             'personal_url': personal_url, 'research_interest': research_interests}])

    # professor_df = pd.concat([professor_df, new_row_df], ignore_index=True)
    time.sleep(3)

df.to_excel(r"F:\EUCLIDO\Tasks\knowledge_graph\all dataset\non_matches_again.xlsx", index=False)

# %%
translate_tweet_mistral("সৌম্যর পর লিটনকেও হারাল বাংলাদেশ, জীবন পেলেন মিরাজ")
# Out:
# 'Bangladesh defeated Soumya then Liton, Miraj got life'

# %%
from deep_translator import GoogleTranslator
to_translate = 'সৌম্যর পর লিটনকেও হারাল বাংলাদেশ, জীবন পেলেন মিরাজ'
translated = GoogleTranslator(source='auto', target='en').translate(to_translate)
# outpout -> Ich möchte diesen Text übersetzen
translated
# Out:
# 'After Soumya, Bangladesh also lost Liton, Miraj got his life back'

# %%
import pandas as pd

# Paths to the Excel files
file1 = r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\awami_2024-12-25_23-00-04_tweets_1-833.csv"
file2 = r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\awami_2024-12-26_00-23-23_tweets_1-643.csv"
file3 = r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\awami-2024-12-25_20-19-08_tweets_1-824.csv"

# Read the Excel files into dataframes
# df1 = pd.read_csv(file1,encoding="utf-16")
# df2 = pd.read_csv(file2,encoding="utf-16")
# df3 = pd.read_csv(file3,encoding="utf-16")
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)
df3 = pd.read_csv(file3)

# Join the dataframes (e.g., concatenate vertically or merge based on common columns)
# Concatenate vertically (stack rows)
joined_df = pd.concat([df1, df2, df3], ignore_index=True)


output_file = r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\awami-2024-12-25.xlsx"
joined_df.to_excel(output_file, index=False)

print(f"Joined file saved as {output_file}")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[19], line 12
#       6 file3 = r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\awami-2024-12-25_20-19-08_tweets_1-824.csv"
#       8 # Read the Excel files into dataframes
#       9 # df1 = pd.read_csv(file1,encoding="utf-16")
#      10 # df2 = pd.read_csv(file2,encoding="utf-16")
#      11 # df3 = pd.read_csv(file3,encoding="utf-16")
# ---> 12 df1 = pd.read_csv(file1)
#      13 df2 = pd.read_csv(file2)
#      14 df3 = pd.read_csv(file3)
#
# File f:\EUCLIDO\Tasks\.venv8\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File f:\EUCLIDO\Tasks\.venv8\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File f:\EUCLIDO\Tasks\.venv8\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File f:\EUCLIDO\Tasks\.venv8\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File f:\EUCLIDO\Tasks\.venv8\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte

# %%
import os
import pandas as pd
import glob

# Directory containing the Excel files
folder_path = r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder"

# Get all Excel files in the folder
excel_files = glob.glob(os.path.join(folder_path, "*.xlsx")) + glob.glob(os.path.join(folder_path, "*.xls"))

# Load and process each Excel file
dataframes = []
for file_path in excel_files:
    try:
        print(f"Loading file: {file_path}")
        # Attempt to load the Excel file
        df = pd.read_excel(file_path)
        print(f"Loaded {len(df)} rows from {file_path}")
        dataframes.append(df)
    except Exception as e:
        print(f"Error loading {file_path}: {e}")

# Combine all DataFrames if needed
combined_df = pd.concat(dataframes, ignore_index=True)

# Display combined data preview
print("Combined DataFrame Preview:")
print(combined_df.head())
# Out:
# Loading file: F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\anti_movement_alliance29464_tweets_1-500.csv.xlsx
# Loaded 500 rows from F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\anti_movement_alliance29464_tweets_1-500.csv.xlsx
# Loading file: F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\anti_movement_ATeam_1971_tweets_1-845.csv.xlsx
# Loaded 845 rows from F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\anti_movement_ATeam_1971_tweets_1-845.csv.xlsx
# Loading file: F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami-2024-12-25_20-19-08_tweets_1-824.csv.xlsx
# Loaded 808 rows from F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami-2024-12-25_20-19-08_tweets_1-824.csv.xlsx
# Loading file: F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami_2024-12-25_23-00-04_tweets_1-833.csv.xlsx
# Loaded 833 rows from F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami_2024-12-25_23-00-04_tweets_1-833.csv.xlsx
# Loading file: F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami_2024-12-26_00-23-23_tweets_1-643.xlsx
# Loaded 642 rows from F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami_2024-12-26_00-23-23_tweets_1-643.xlsx
# Loading file: F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\StepDownYunus_1-917.csv.xlsx
# Loaded 917 rows from F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\StepDownYunus_1-917.csv.xlsx
# Combined DataFrame Preview:
#                       Name           Handle                 Timestamp  \
# 0     Awami Youth Alliance   @alliance29464  2024-10-31T14:04:01.000Z
# 1  Bangladesh Perspectives  @bdperspectives  2024-10-30T21:31:57.000Z
# 2     Awami Youth Alliance   @alliance29464  2024-10-30T04:49:28.000Z
# 3     Awami Youth Alliance   @alliance29464  2024-10-30T04:40:54.000Z
# 4     Awami Youth Alliance   @alliance29464  2024-10-30T04:34:51.000Z
#
#    Verified                                            Content  Comments  \
# 0      True  জাতিসংঘের মানবাধিকার কমিশনের প্রধানের বাংলাদেশ...         0
# 1      True  Bangladesh Police registered a frivolous sedit...         0
# 2      True  “শিবির পুলিশের বাপ”   \nদেখুন ভিডিওতে কি বললো ...         0
# 3      True  গুলি ও বোমা বিস্ফোরণ ঘটিয়ে যেভাবে ডাকাতি হলো ...         0
# 4      True  বাংলাদেশে চলছে মবের মুল্লুক \nডক্টর মালিকা কলে...         0
#
#    Retweets  Likes Analytics  \
# 0         0      0        29
# 1         0      0      4.8K
# 2         0      0      5.6K
# 3         0      0        1K
# 4         0      0      6.7K
#
#                                                 Tags              Mentions  \
# 0                                                 []                    []
# 1                                                 []  ['@ChiefAdviserGoB']
# 2                                                 []                    []
# 3  ['#Bangladesh', '#NoSafetyInBD', '#BangladeshC...                    []
# 4  ['#Bangladesh', '#BangladeshCrisis', '#SaveBan...                    []
#
#                                  Emojis  \
# 0                    ['\\u27a1\\ufe0f']
# 1                                    []
# 2                    ['\\u203c\\ufe0f']
# 3  ['\\u26a0\\ufe0f', '\\u27a1\\ufe0f']
# 4  ['\\u203c\\ufe0f', '\\u27a1\\ufe0f']
#
#                                        Profile Image  \
# 0  https://pbs.twimg.com/profile_images/182953355...
# 1  https://pbs.twimg.com/profile_images/174470571...
# 2  https://pbs.twimg.com/profile_images/182953355...
# 3  https://pbs.twimg.com/profile_images/182953355...
# 4  https://pbs.twimg.com/profile_images/182953355...
#
#                                           Tweet Link  \
# 0  https://x.com/alliance29464/status/18519884989...
# 1  https://x.com/bdperspectives/status/1851738840...
# 2  https://x.com/alliance29464/status/18514865541...
# 3  https://x.com/alliance29464/status/18514843980...
# 4  https://x.com/alliance29464/status/18514828775...
#
#                        Tweet ID
# 0  tweet_id:1851988498993017106
# 1  tweet_id:1851738840748417329
# 2  tweet_id:1851486554130125083
# 3  tweet_id:1851484398073282797
# 4  tweet_id:1851482877524955642

# %%
combined_df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami_all.xlsx")

# %%
import pandas as pd
import time
from deep_translator import GoogleTranslator

# df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami_all.xlsx")
df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\bnp\bnp_translated2.xlsx")


for index, row in df.iterrows():
    if(index > 2000):
        break
    if(index < 1500):
        continue
    try:
        translation = GoogleTranslator(source='auto', target='en').translate(str(row['Content']))
    except Exception as e:
        print(f"Error translating row {index}: {e}")
        continue
    print(index)
    print(translation)

    df.at[index, 'translation'] = translation  # Add translation at the current index
    time.sleep(.2)

df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\bnp\bnp_translated2.xlsx", index=False)
# Out:
# Error translating row 1500: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=And+this+is+what+Human+Rights+Watch+said+about+Michael+Chakma%27s+original+disappearance+in+2019%0Ahrw.org%2Fnews%2F2020%2F04%2F08%2Fstil%E2%80%A6 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000189C63C3B30>: Failed to resolve 'translate.google.com' ([Errno 11001] getaddrinfo failed)"))
# 1501
# UPDATE: I dont know the details but I am hearing credible reports that Michael Chakma, an indigenous rights activist, who was picked up in 2019 and was disappeared, has been released from secret detention in #Bangladesh. Below is what Amnesty International wrote about him at the time of his detention. Will provide further details as soon as receive them. amnesty.org/en/documents/asa….
# 1502
# "Do not let anyone take advantage of This Bangladesh 2.0". An important corrective.
# 1503
# Now that we have finally moved the mountain, we must build anew with a clear and precise vision. This begins with the composition of the interim government. The students who initiated this movement deserve representation in the interim government in the capacity of observers. They should remember that their demand for quota system reform transformed into a people's uprising after common men sacrificed their life. Where we stand today is not solely due to 'Quota' reform but because of the need to reform the entire nation. Therefore, it is essential to consult and include all catalysts of this movement, such as academics, activists, human rights defenders, journalists, and writers, in the selection of government members.
#
# These selected individuals will navigate the country under the very capable guidance of Professor Dr. Md Yunus @Yunus_Centre , who has already been chosen as the head of the interim government.
#
# In my personal opinion, retired military personnel and judges who aided and abetted democratic backsliding over the past 15 years should have no place in the interim government. Similarly, journalists who hesitated to hold those in power accountable, legal professionals who represented corrupt oligarchs, and morally corrupt individuals should be excluded. Anyone who does not serve the interests of Bangladesh and civil society members who remained silent against the murderous Awami League regime should also be kept away. To summarize, anyone who did not stand up for the people, the nation, and the country over these past 15 years should be kept as far away as possible from this exercise.
#
# As a gentle reminder, since there are no people's representatives in the caretaker/interim government, everyone must be extremely cautious about making any reforms to the constitution and legislation. Such changes should not occur without a new parliamentary government.
#
# I hope the army chief, who has already made history, remains mindful of incorporating the expectations of all stakeholders.
#
# Time is of the essence here. Bangladesh has already suffered massively in the last few weeks; trade and daily business have come to a standstill. Children who should be in their institutions are at home. Small-medium entrepreneurs are facing severe losses, the stock exchange is struggling, and law and order are fragile. If it takes more than 24-36 hours from now to announce and activate the new interim government, the future of Bangladesh will be at stake.
# 1504
# Flight path
# 1505
# On August 5, 2024, various media outlets reported that Sheikh Hasina and her sister Sheikh Rehana traveled from Dhaka to Agartala, India, on a @BD_Air_Force helicopter and from there flew to Delhi. However, this claim is not true.
#
# Bangladesh Air Force, sources have confirmed that on August 5, Sheikh Hasina traveled from Gonobhaban (PM Residence) to Kurmitola Air Base via helicopter in the afternoon. From the same air base, she departed for India on a Bangladesh Air Force C-130J transport aircraft (Flight No. AJAX 1431). The plane later landed at Hindon Air Base in Ghaziabad district, Uttar Pradesh, India. The attached video captures the moment just before Sheikh Hasina's C-130J aircraft left Dhaka.
#
# Hasina's departure from Dhaka is an important part of this historic event. It is crucial to share the correct information.
# 1506
# “After more than a decade of a government that systematically stifled opposition, manipulated the courts, and weaponized the security services against its own citizens, today we celebrate the renewed opportunity for Bangladesh to restore a democracy based on its constitutional principles.”@SenatorCardin Check this out! foreign.senate.gov/press/dem…
# 1507
# 👏👏👏on interim govt led by Prof. Yunus but why NO #women in the consultations? Interim govt of #Bangladesh must be inclusive and committed to #HumanRights, accountability & transparency. ⁦@Yunus_Centre⁩ #GenderEquality ⁦@dailystarnews⁩ ⁦@ProthomAlo⁩
# 1508
# That is just great. If only that could happen all over #Bangladesh
# 1509
# My take on Prof @Yunus_Centre appointment as Chief of the #Bangladesh interim government and dictator Hasina’s departure with @AJEnglish -
# 1510
# No
# 1511
# Quite something.
# 1512
# Emirates flight 585, which was taxiing on the runway, was brought back to the boarding bridge, and Major General (dismissed) Ziaul Ahsan has been detained. Directorate General of Forces Intelligence (DGFI) members are taking him back to Dhaka Cantonment. Sincere thanks to everyone who assisted in the arrest of Zia.
# 1513
# Great to be with you, @akankshaswarups, on @CNNnews18 discussing the situation in Bangladesh after the fall of the dictator #Hasina
# 1514
# An article from 2018 in @thewire_in reports that a close associate of Sheikh Hasina claimed that the former prime minister was directly involved in authorising the secret detention of Mir Ahmed bin Quasem, who was disappeared for 8 years before being released on 6 August, a day after Sheikh Hasina, along with the Awami League, was removed from power.
# thewire.in/south-asia/secret…
# 1515
# I have been thinking a great deal about Arman today.  It may be the case that the international campaign for the disappeared did not succeed in freeing him.  But it just may have kept him alive long enough for this day to come.   It shows the important role that human rights campaigners can play in such cases.   Again my thanks to @MichaelPolakLaw @tobycadman @SanjidaIsl65598 and all the others who kept this issue active.
# 1516
# The right choice for #Bangladesh, I wish #india, the greatest friend of #Bangladesh and democracy will be with #Bangladesh, will not be with autocrat and will not create Chaos in Bangladesh by their RAW agents. We love indian people.
# 1517
# He does have an Antigua & Barbuda passport. But now he's flight to either Dubai or Colombo.
# 1518
# yewtu.be/live/gwXuvdWZAWY…
# 1519
# Here is my take with @ndtv on the situation in #Bangladesh and the selection of @Yunus_Centre as Chief Advisor-
# 1520
# The Bangladesh Army is allowing a safe exit for the notorious murderer Major General Ziaul Ahsan. Ziaul was dismissed from military service earlier today. At this moment, he is at Shahjalal International Airport. He will likely board a flight in the next 35-45 minutes. Ziaul has been involved in hundreds of extrajudicial killings and enforced disappearances.
#
# He must not be allowed to leave Bangladesh.
# 1521
# Mr. Md. Moynul Islam, NDC, a 12th BCS (Police cadre) officer, has been appointed as the new Inspector General of Police (IGP) of Bangladesh.
#
# The appointment of the previous Inspector General, Chowdhury Abdullah-Al-Mamun, has been canceled.
# 1522
# "AYNAGHOR" should be a museum just like "Auschwitz concentration camp" so that people can learn what Sheikh Hasina was. She had serious psychological problem. Otherwise you do not keep your enemy in one building years after years for torture and get the pleasure out of it!
# 1523
# India must handover Sheikh Hasina & Sheikh Rehana along with Major General (Retd) Tarique Ahmed Siddique the Defense and Security Adviser to Hasina who infact was the mastermind behind hundreds of abductions and extra judicial killings. @ihcdhaka @MEAIndia it's time for you to demonstrate your willingness to hold these extremely corrupt individual accountable.
# 1524
# Great piece here by @TheDavidBergman in @spectator on what brought about the downfall of Sheikh Hasina's brutal and oppressive regime in Bangladesh. #Bangladesh #BangladeshProtests
#
# spectator.co.uk/article/bang…
# 1525
# This is important. “The people of Bangladesh deserve a full and independent UN-led investigation into the events of the past few weeks.” says David Lammy, UK foreign secretary. gov.uk/government/news/forei…
# 1526
# Students are Cleaning Sangsad Bhaban in Bangladesh #NewBangladesh
# 1527
# New @amnesty statement: “The first order of business for any interim government should be to ensure protection of people's right to life, right to free speech and peaceful assembly and to find ways of de-escalating any potential for further violence. Any measures proposed to move forward from this deadly chapter in #Bangladesh’s history need to be rooted in the principles of justice, accountability and non-recurrence.” amnesty.org/en/latest/news/2…
# 1528
# Heart warming news
# 1529
# From the very first day that @NetraNews, an investigative news website on Bangladesh was launched in Sweden , the @albd1971 blocked it from being seen in the country. A day after the @albd1971 fell, the website is now accessible! That is fantastic. Please do now read stories on netra.news
# 1530
# Be honest everyone.
#
#  Have you ever seen anything good like this in any country?? Students are cleaning the parliament themselves and cleaning whole Bangladesh. It is actually an wonder in the world.
# 1531
# Three years ago an explosive investigation by @AJIunit revealed how a criminal gang colluded with the security forces of Bangladesh and had links to Sheikh Hasina and her political party.
#
# Undercover reporters with the I-Unit exposed how a former street mafia claimed to have captured a state. The brother of the then Bangladesh’s army chief boasts that he can use police and paramilitary units to abduct rivals and earn millions in bribes.
#
# Watch here 👉🏽 yewtu.be/a6v_levbUN4?feature…
# 1532
# Here are The Few Pictures How #Bangladesh people are Protecting HINDU Temples . Right Wing Propagandists  will not Show you This
#
# #BangladeshViolence #ShiekhHasina #SheikhMujiburRahman
# 1533
# UK Media, please take note of the following
#
# @Channel4News and @alextomo did a short film in 2017 about the failure of Tulip Siddiq MP, who is Sheikh Hasina's niece, and who used to work for the Awami League, to take any steps to help Mir Ahmed Bin Quasem, a UK trained barrister, who was then one year into his secret detention/disappearance. Tulip, as a UK MP and the prime minister's niece, had unusual access to pressure her Aunt. He continued to spend 7 further years in a secret jail until he was released today, the day after Sheikh Hasina was forced to resign as prime-minister and left the country.
#
# Could Tulip Siddiq, a current junior minister, have prevented that?
# channel4.com/news/tulip-sidd…
# 1534
# Bangladesh’s Hindu organization’s leader says all Hindus and their places of work and worship are safe and protected by student and political groups.
# 1535
# Well said.  I can only imagine the response when @Yunus_Centre addresses the @un this fall as #Bangladesh’s representative.    He needs the support of all of Bangladesh’s citizens and foreign friends.
# 1536
# It is not possible to exaggerate the level of karmic justice that is represented by the appointment of Muhammad Yunus to the position of head  of  #Bangladesh's interim government.
#
# Other than members of the political opposition, for over a decade, Yunus was by far the man most persecuted  by the Sheikh Hasina government. Removed from his position  as head of Grameen Bank in 2011; repeatedly abused, defamed and ridiculed publicly by the prime minister and countless ministers; subject to countless tax investigations; convicted and sentenced to a six month imprisonment in a sham labour rights trial; his offices illegally taken over; and currently being prosecuted for fake corruption charges. It goes on and on.
#
# Throughout this period, Yunus conducted himself with extraordinary dignity - and never gave in. He alone in Bangladesh was brave enough to repeatedly refute "on the record" the false and absurds allegations made constantly against him by the government. It is difficult to believe but no other Bangladeshi would dare to refute allegations against them in this way fearing the consequences.  But Yunus did. He deserves this position.
# 1537
# BREAKING: Formal confirmation that Muhammad Yunus has agreed to be head of the interim government.
#
# Lamiya Murshed, Executive Director of the Yunus Centre told me that she recently spoke to Yunus, who is currently in Paris, and that he told her:
#
#  "I have agreed to the request of the student leaders to be head of the interim government. I told the student leaders 'I did not want to do this. it is not what I do, but that how can I refuse their request after all that you have done'."
#
# Yunus was speaking to the student leaders Nahid Islam and Asif Mahmud. Murshed said that Yunus would be flying back to Bangladesh soon.
#
# It is now understood that the Chief of Army Staff and the President are agreeable to Yunus taking this position, and a meeting between them and Nahid is currently taking place.
# 1538
# Major General Ziaul Ahsan was a name that kept cropping up in so many human rights investigations. Now at least he is no longer in post.
# 1539
# This is good summary of concerns and hopes in #Bangladesh from @rte (Irelands' national radio broadcaster)
# rte.ie/radio/radio1/clips/22…
# 1540
# BREAKING:  The United States government has revoked former #Bangladesh Prime Minister Sheikh Hasina's visa to the United States, sources close to the State Department have confirmed. Sheikh Hasina left Bangladesh on Monday afternoon, and is currently in India deciding her next steps. Hasina's son, Sajeeb Wazed Joy, lives in Virginia, in the United States.
#
# It is not clear whether Hasina had any plans to travel to the US. Reports have suggested that Hasina was considering making an asylum application to the UK, where her sister (Sheikh Rehana) and niece (Tulip Siddiq MP) live. However, under UK rules it is not possible to claim asylum from outside the UK, and the UK expect a person to first claim asylum in any safe third country that they travel to, which in this case would be India.
#
# However, Hasina could well have an existing visa that would allow her to travel to the UK.
# 1541
# After weeks of protests and nearly 300 deaths from clashes with security forces, Bangladesh’s PM Sheikh Hasina has resigned and fled to India. What will this mean for the country?
#
# 🎙️ #TheTake discusses with @ZulkarnainSaer: listen.aj.audio/1jfCeonP
# 1542
# Peace and justice must start here 🇧🇩
# 1543
# An interesting sub-story to this is about Sanjida Islam herself. She returned to Dhaka from Thailand on Sunday, and was held at the airport by DGFI, military intelligence, who was threatening to detain her. With UN help she was allowed into the country after a few hours. Two days later Sanjida is now in DGFI's office asking them questions. What a turn-around!
# 1544
# Major General Ziaul Ahsan has been dismissed from his position in the Bangladesh Army. Ziaul, who is associated with various heinous crimes including enforced disappearances and murders, must not be allowed to leave the country under any circumstances.
# 1545
# UPDATE: Major General Tamizid at the #Bangladesh military intelligence agency DGFI told Sanjida Islam, the convenor of Mayer Dak, that organisation of families of the disappeared, that he will "communicate with the army chief and provide an update about all enforced disappeared persons by tomorrow." Also present at the meeting were senior UN officials. See previous tweets about secret detainees so far released today
# 1546
# Astonishing
# 1547
# The Mawlanas in Bangladesh walked door to door and assured the safety of the Hindus, while providing them their contact numbers to contact in emergency.
#
# This is Bangladesh which is like a family. Those who are spreading fake news should realize, they made the biggest mistake of their life by trusting the lies of Sheikh Hasina and BAL.
#
# I repeat, Bangladesh is like a family.
# 1548
# Madrasa students and Hujurs are guarding the temple. The truth is above all, not above him. ❤️
#
# #Muslim religious students and leaders are guarding #Hindu temples in #Bangladesh. #HumanityUNITE #Freedom
# 1549
# Details about each and every one of these men can be found here: features.hrw.org/features/fe…
# 1550
# Here are the 86 people whom Human Rights Watch identified a few years back as disappeared in #Bangladesh, picked up by Awami League authorities, but whose wherabouts remain unknown. The new government authorities should now given each and every family an explanation now of what happened to them.
# netra.news/2022/whereabouts-…
# 1551
# I'm humbled and honored, @JonFDanilowicz. I am so privileged to have a friend like you who wholeheartedly loves Bangladesh and its people. Thank you so much.
# 1552
# I can now confirm that #Bangladesh authorities have also released Abdullahil Amaan Azmi. His family is yet to speak to him, but they have confirmation that he is safe.
# 1553
# Along with senior UN officials, Sanjida Islam, the head of Mayer Dak, (mother's call), the group representing the families of #Bangladesh's disappeared, are meeting with military intelligence officials belonging to DGFI, to discuss with them about the secretly detained and disappeared. Here is a video (from an hour ago) of the families of the disappeared waiting outside.
#
# Already one, Mir Ahmed has been released. See below
# 1554
# Here is my first article about Mir Ahmed and the two other detentions aljazeera.com/news/2016/8/29…
# 1555
# Army authorities have released the young lawter Mir Ahmed Bin Quasem, also known as Armaan, after 8 years of secret detention. He was picked up by Awami League government authorities in August 2016 from his home, in front of his family and since then his whereabouts has been unknown, with the Awami League government denying any knowledge of his detention. He was one of the many disappeared.
#
# Mir Ahmed is the son of Mir Quassem Ali, a Jamaat-e-Islami leader who was convicted and executed by Bangladesh's International Crimes Tribunal for crimes committed during the 1971 war.  For years, Awami League authorities denied that they had picked him up and denied that they had secretly detained anyone.
#
# He was picked up within days of the detention of both Hummam Quader Chowdhury, the son of Salauddin Quader Chowdhury (also convicted and executed by the ICT) and Abdullahil Amaan Azmi (the son of Ghulam Azam, Jammat's 1971 leader, who was convicted by the ICT and died in jail). Humman was released after about 8 months in secret detention.
#
# Although social media is reporting that Azmi has also been released, his family as yet have not heard from him at the time of writing.
#
# Below are two picture of Mir Ahmed since being released.
# 1556
# One of the greatest pains in my life in recent years was not being able to publicly disclose that the son of Mir Quasem Ali, the @BJI_Official leader who had been sentenced to death by the highly controversial  International Crimes Tribunal set up by Hasina's regime, and Abdullahil Amaan Azmi, a former military general and the son of Ghulam Azam, former Jamaat-e-Islami chief who had been sentenced to life by the same court — are alive.
#
# Both men were the worst victims of the nuisance that was enforced disappearance, introduced by the Sheikh Hasina regime. The two men were abducted by plainclothes policemen in August 2016 and were kept at a secret detention centre in Dhaka called #Aynaghar since then. They were never presented before the court and their families had no contact with them. Every time someone I knew spotted the two men in Aynaghar, which was located at the premises of the Directorate General of Forces Intelligence (DGFI), Bangladesh's defence forces' intelligence branch, I would inform Mr Arman’s sister and Mr Azmi’s brother that they were alive. The last I heard of them was in May last year.
#
# This morning, I woke up to the news that the two men had been reunited with their families after the fall of Sheikh Hasina’s government. How cruel do you have to be to detain these people for close to a decade needlessly? Endlessly. I truly believe that Sheikh Hasina will go down in the annals as one of the most brutal dictators of the modern era with Adolf Hitler, Joseph Stalin, Mao Zedong, Pol Pot, Kim Jong-il and Omar al-Bashir.
#
# No country in the world should grant political asylum to such a person who has committed such atrocities, such grave crimes against humanity. She should be brought back to Bangladesh and brought to trial for all her crimes and treasons — fair and square.
#
# @TheDavidBergman @tasneem @MichaelPolakLaw @tobycadman
# 1557
# Are you sure? Because @bdbnp78 was formed sometime in 1978/1979 Mujib was assassinated back in 1975 and I'm not sure why would the CIA get their hands dirty by killing a leader of one third world country?
# 1558
# 😂 shit hit the fan long back, and we all are busy cleaning that. Please worry about your own problems and let us fix our own. Cheers
# 1559
# Stop spreading such propaganda, if you do not know who they are then please don't post such material. These are members of Bangladesh's Armed Police Battalion (APBN).
# 1560
# Across multiple locations in Bangladesh, people were seen demolishing statues of Sheikh Mujibur Rahman, the father of Prime Minister Sheikh Hasina. The @albd1971 , has long been centered around a cult of personality focused on Sheikh Mujibur Rahman. Revered as the nation's founding father who led Bangladesh to independence in 1971, Mujib's popularity soared in the immediate post-independence years. However, over time, his administration became marred by corruption and nepotism among party members and close relatives. In 1975, a too-confident Mujib established a one-party system, banning newspapers and dissolving opposition parties. This autocratic shift drastically eroded his public support and culminated in the tragic assassination of Mujib and his entire family.
#
# Sheikh Hasina's government, which gained power for the second time in 2008, appears to have followed a similar trajectory. Her administration has been criticized for implementing the draconian Digital Security Act, abolishing the caretaker government system, and allowing unchecked corruption to spread, effectively creating a classic fiefdom. The opposition parties have been rendered almost non-existent, with hundreds of thousands of @bdbnp78 and @BJI_Official members imprisoned on what are widely considered to be false charges.
#
# Hasina established total control under the guise of democracy, only to find herself facing a fate similar to the one she once dictated for others—forced to flee the country.
# 1561
# The @DhakaTribune is reporting that at least 135 people died on Monday, the day that the army chief announced that Sheikh Hasina had resigned. It is unclear who are the main victims and perpetrators. The Tribune said that they were a combination of "police firing, mob beating and  and arson", though it is unclear in what proportions.
#
# In relation to Uttara it says: "At least 10 people were killed and many others injured in the capital’s Uttara on Monday afternoon after individuals in civilian clothes reportedly opened fire on protesters. The shots were fired from the Uttara East police station. In response, hundreds of enraged people surrounded the police station and set it on fire."
#
# But then it also says this: "In Jessore, at least eight people were burned to death and 84 others were injured after unidentified arsonists set fire to a residential hotel. The hotel was owned by Shahin Chakladar, general secretary of the Jessore district AL In Khulna, three people, including Koyra Upazila Parishad Chairman and Upazila Awami League President GM Mohsin Reza, were beaten to death by a mob. The other two deceased were identified as Reza's driver, Alamgir, and his personal assistant, Mofizul Islam. In Barisal, three people were burned to death after agitators set fire to former mayor and City AL President Serniabat Sadik Abdullah on Monday."
#
# It is extraordinary that the army was so ill prepared for this violence. The army chief made his announcement, walked off the stage and left the country to burn.
# 1562
# #Bangladesh: The student leadership that brilliantly led the revolution to oust dictator #SheikhHasina is now dictating the terms for the interim government. They have just declared country's Nobel Laureat @Yunus_Centre as the head of the interim government!  Very smart move!
# 1563
# The #Bangladesh army chief made his announcement, walked off the stage and left the country to burn.
# 1564
# The coordinators of the student body that led the protest against Sheikh Hasina’s authoritarian rule have declared the formation of an interim government with the country's only Nobel Peace Prize laureate, Professor Muhammad Yunus, as its Chief Advisor.
#
# netra.news/2024/interim-gove…
# 1565
# Fake Tweets Alert!
# Countless rumors and fake tweets are flooding X (former Twitter), directly inciting against the sovereignty and independence of Bangladesh. Following the coordinators' announcement, every area is forming 'Communal Harmony and National Asset Protection Committees' to safeguard religious sites and public properties. We urge the minority community to post verified information about their localities on social media. Do not fall for provocations without checking; counter misinformation. #ProtectMinorities #ProtectAllFaiths #SafeBangladesh #NationalUnity #CommunalHarmony #HindusAreSafeInBangladesh
# 1566
# In #Bangladesh  in coming days there will be a transfer of populations. Key Awami Leaguers/beneficiaries will leave the country; on the other hand, dissidents/ dissenters/critics of the Awami League government, who at some point over the last 15 years had to leave Bangladesh, are now returning.
# 1567
# This is how @StateDeptSpox
# responded to #Bangladesh’s autocrat #Hasina’s departure. The US will support the upcoming interim government of Bangladesh, which should be based on democratic principles, the rule of law, and the will of the people.
# 1568
# Actually Liton Das was a supporter of the quota movement.
# 1569
# This is false News. It is the house of Mashrafe Bin Mortaza's house. He was Bangladeshi Cricket Team Captain and Hasina's MP.
# 1570
# We have postponed today’s event due to the changed circumstances.
# 1571
# I hope Hasina gets a good book deal, I would love to take a peek inside her sick, degenerate, and crooked brain. I know she'd divulge a bunch of delusional lies, but I'd still pay for it. #bangladesh
# 1572
# The #Bangladesh army provides much-valued peacekeeping services to countries in conflict. They are reallly good at it. What is stopping them from keeping the peace at home? 🇧🇩
#
# Bangladesh UN Peacekeeping Force - Wikipedia en.wikipedia.org/wiki/Bangla…
# 1573
# Things moving fast. Only wish the army would focus on law and order right now
# 1574
# My piece for the @spectator Magazine on the fall of Hasina. spectator.co.uk/article/bang…
# 1575
# Press release from the Presidents office of Bangladesh reads,
#
# "The meeting  held unanimously decided to release @bdbnp78 Chairperson Begum Khaleda Zia. Additionally, it was decided to release all detainees who were arrested in various cases related to the student against discrimination movement and recent incidents. There was also a strong consensus to ensure that communal harmony is not disrupted in any way."
# 1576
# If Sheikh Hasina is heading to the UK, major questions for Keir Starmer and the Labour Govt will surely follow.
#
# In the UK a govt minister - Tulip Siddiq - once boasted that she “worked” for Hasina’s now toppled Awami League Govt.
#
# #Bangladeshstudentprotest
# 1577
# Thousands of people have taken to the streets of Bangladesh’s capital, Dhaka, as PM Sheikh Hasina resigned following weeks of deadly protests against the gov't. — in pictures aje.io/vbhtlo
# 1578
# Where is the #Bangladesh army to stop all this. People are also setting on fire to Sheikh Mujib's house, now a museum
# 1579
# There are reports that Awami League's politician's houses are being attacked and set on fire. This kind of retribution, however understandable,  must stop.
# 1580
# Jubilant people in Dhaka, Bangladesh have taken over the Prime Minister's official residence (Gano Bhaban).
# 1581
# This is the equivalent of pulling down Saddam’s statue in Baghdad in 2004. During her rule, Hasina created a cult of Mujib, her father, and pretty much destroyed his name.
# 1582
# The very first thing, and I mean this must be the very very first thing that the new #Bangladesh interim government/army must do, is to release any secretly detained/disappeared person who remains alive. Many have been killed, but those alive should be immediately released. Some of these men may in fact be in some kind of secret army custody, so the army has to come clean now and release them
# 1583
# Bangladesh’s army chief General Waker-Uz-Zaman has addressed the nation, confirming that PM Sheikh Hasina has resigned and that an interim government will run the country.
# 1584
# July Movement, Hasina Out
# 1585
# This is some moment. The statue of Sheikh Mujib, the father of former prime minister Sheikh Hasina and the country's independence leader, is being destroyed. Unfortunately, his reputation (most support him, others not) has been significantly tarnished by association with her daughter.
# 1586
# Done.
# 1587
# Key question now is who will be the members of the new #Bangladesh interim government. Their identity will be crucial to where Bangladesh goes from here.
# 1588
# Will #Bangladesh’s Gen Z make the cover of the @TheEconomist this week? (It would be first Bangladesh cover since the country’s  independence in 1971)
# 1589
# i mean she had
# 1590
# can’t believe she has fled
# 1591
# Apparently Sheikh Rehana - Sheikh Hasina's sister and mother of Tulip Siddiq MP - has been in Bangladesh during this period, and left the country with Hasina.
# 1592
# He may be a bit too old, but it would certainly be one in the eye for Sheikh Hasina if @yunuscentre becomes chief of the caretaker government.
# 1593
# Sheikh Hasina has resigned, a top official at the prime minister’s office confirmed to Netra News. “There’s no prime minister here. There’s no PMO anymore,” he said. She was flown to an undisclosed location, as a motorcade was not possible due to the security situation, he added.
# 1594
# #SheikhHasina resigned and fled the country, finally! Heartiest congratulations and salute to our Generation Z!
# We are so very proud of you!!
# #Bangladesh #2ndVictoryDay #August2024
# 1595
# Sheikh Hasina landed at Kurmitola @BD_Air_Force Base from Gana Bhaban (Residence of the Prime Minister) by helicopter. She was subsequently boarded onto an aircraft. Her next destination will be known shortly.
#
# Footage by a military source (identity withheld for safety)
# 1596
# Heartiest congratulations and salute to our Generation Z!
# We are so very proud of you!!
# 1597
# Head of @AFP Dhaka Bureau.
# 1598
# Interesting speech given by Sheikh Hasina's son on Facebook with a suggestion that he might seek to take over the reigns of the Awami League. He says at the end: “Our constitution is what has to be protected above all. That means not for one minute can there be an unelected government in this country. I, Sajeed Wajed Joy, won’t allow that to happen.” facebook.com/sajeeb.a.wazed/…
# 1599
# Bangladesh's dictator, Sheikh Hasina, has been flown to the @BD_Air_Force base in Kurmitola at 1425 hours local time. Sources claim that from there, Hasina will travel to a third country. If this information is correct, it would signify the end of Sheikh Hasina's reign of terror in Bangladesh.
# 1600
# Multiple official sources tell me that Sheikh Hasina has resigned as the Bangladesh premier after 15 years of uninterrupted rule.
# 1601
# See Bangladesh TV stations for images of people on the street in pretty jubilant mood.  yewtu.be/live/4JUtR_HWsiE…
# 1602
# Oh my god. Does this mean that (apparently resigned) #Bangladesh prime minister Sheikh Hasina will come to live in the UK with her sister Rehana and her niece, Tulip Siddiq MP! ... Or will she take the easier option of staying in India.
# 1603
# UPDATE 4: The private Jamuna TV has said that the army chief is holding talks with political parties and he will now address the nation at 3pm. (Unconfirmed reports that Hasina has already resigned and on her way to airport for safe exit. CAS waiting for the Aircraft to take off before his speech.)
# 1604
# UPDATE 3: Senior official in prime minister's office has told a journalist when asked about the speculation that the prime minister Sheikh Hasina has resigned: "The situation is such that this this is a possibility, but I don't know how it will happen."
# 1605
# If - and it is still a big "if" - there was to be a constitutionally driven "state of emergency" in Bangladesh.
# -  it  has to be proclaimed by the President and agreed by the Prime minister. It is not something for the army to declare, as such;
# - It will result in the following rights set out in the constitution, no longer applying: Articles 36 (freedom of movement); 37 (freedom of assembly); 38  (Freedom of Association); 39 (freedom of thought and conscience and of speech): 40 (freedom of professsion and occupation) and 42 (rights to property).
# - the President can declare (on the written advice of the Prime Minister) that noone can move any court for the enforcement of fundamental rights (part III of constitution) and end all proceedings pending in any court for the enforcement of these rights.
#
# This is all set out in Articles 141 (a)-(c)  of the constitution.
# bdlaws.minlaw.gov.bd/act-367…
# 1606
# Hundreds of thousands of people have started to march toward the center of Bangladesh's capital, Dhaka. The country's Chief of Army Staff will address the nation at 14:00 local time.
# 1607
# UPDATE 2: Dhaka at 1pm (Uk at 8 am)
# 1. #Bangladesh army chief General Waker-uZ-Zaman will address the people at 2pm. Till then the army has asked people to be patient.
# 2. A total internet blackout has been enforced from 10.30am Monday.
# 3.  According to the The Business Standard newspaper, hundreds of thousands of people have marched towards central Dhaka. They are defying heavy security in Dhaka.
# 4. The students have asked people to march to Dhaka to force Sheikh Hasina's resignation. So far people from the suburbs of the city are responding.
# (From journalists in Dhaka)
# 1608
# UPDATE: #Bangladesh Army Chief will address the nation at 2pm (bd time) 9 am (Uk time). Sources suggest state of emergency could well be called. (From journalists in Dhaka, working in internet blackout)
# 1609
# #Bangladesh update from journalist on ground in Dhaka at 6am (Uk time) 11am (Bangladesh time).
#
# 1. Thousands of heavily armed troops and police men were deployed in Dhaka and its entry points as the students urged people to march to the capital to force Hasina to resign. The students have called for the resignation of Hasina in a massive rally in Dhaka on Saturday.
#
# 2. Protesters have hit the streets again on Monday morning. There are several reports of clashes including one at the Shaheed Minar, the Language Martyrs Memorial, where the students have planned to stage a major rally on Monday.
#
# 3. Mobile internet was shut down from Sunday afternoon. Broadband internet was not affected yesterday. But from Monday morning, broadband internet was also suspended.  Bangladesh has 141 million internet users. Of the total only 14 million use broadband internet. Social media such as Facebook, YouTube and WhatsApp have been shut down.
#
# 4. Garment manufacturing has been heavily hit by the protests. All 3,500 garment manufacturers who make apparel for top brands such as Zara, H&M and Mango have been shut on Monday. Several garment factories were torched last night, police said. Dozens of garment manufacturers openly defied Hasina and expressed their solidarity with the students.
#
# 5. Former generals including at least two former army chiefs have asked the military to send troops back to barracks. In a press briefing, much respected military chief General Ikbal Karim Bhuiyan said they want a UN-led investigation to probe the killings of hundreds of students. At least a dozen former generals backed his call.
#
# 6. Public and private offices and banks have been ordered to shut down for three days starting from Monday. The country's top court has been shut indefinitely. Indefinite curfew has been imposed from 6pm Sunday. No movement of cars or buses on the roads. Some rickshaws can be seen moving in narrow neighbourhood alleys.
# 1610
# New total internet shutdown in #bangladesh
# 1611
# Bangladesh anti-government protests see at least 90 people killed | BBC ... yewtu.be/IP28Yargp-E?si=c6J8… via @YouTube
# 1612
# Please join Tuesday at 3 PM (EST) and 1 AM in Dhaka- @JonFDanilowicz @MichaelKugelman @meeganguly @TheDavidBergman @AsifNazrulTweet @rtoforg
# 1613
# What is happening in #Bangladesh now is #CrimesAgainstHumanity. The government brands any democratic, peaceful protests as acts of terrorism. The students and the people do not trust the government because they are in power through a 'sham' election. If they are open, why is the internet shut down? Who is responsible for that?" — My points are loud and clear as I was interviewed by @BBCWorld today, here in Washington D.C. studio.
# 1614
# You can tell people think that prime minister Sheikh Hasina is about to be thrown out of power in #bangladesh, because they have started saying what they really think about her and her @albd1971 government knowing she/it can’t threaten or  jail them. Here is Professor Yunus (@Yunus_Centre) really, really speaking his mind. Quite something. Worth a read simply for the audaciousness. indianexpress.com/article/in…
# 1615
# “The Government must cease targeting those participating peacefully in the protest movement, immediately release those arbitrarily detained, restore full Internet access, and create conditions for meaningful dialogue. The continuing effort to suppress popular discontent, including through the excessive use of force, and the deliberate spread of misinformation and incitement to violence, must immediately cease.” Comment by UN High Commissioner for Human Rights Volker Türk, issued late Sunday (Geneva time), on “shocking violence in Bangladesh” ohchr.org/en/statements/2024…
# 1616
# "Accountability for human rights violations – including for those with superior and command responsibility – is crucial. The international community must make it clear that at this pivotal time, there will be no impunity". ⁦@UNHumanRights⁩ ⁦ ohchr.org/en/statements/2024…
# 1617
# @UNHumanRights High Commissioner  @volker_turk  on "shocking violence" in #Bangladesh:
#
# The shocking violence in Bangladesh must stop. Scores more protesters were killed over the weekend. At least 13 police officers were also killed when a police station was attacked in Sirajganj district.
#
# With a mass march on Dhaka planned for tomorrow, and the youth wing of the ruling party called up against the protesters, I am deeply worried that there will be further loss of life and wider destruction. I appeal urgently to the political leadership and to the security forces to abide by their obligations to protect the right to life, and the freedom of peaceful assembly and expression.
#
# Accountability for human rights violations – including for those with superior and command responsibility – is crucial. The international community must make it clear that at this pivotal time, there will be no impunity.
#
# The Government must cease targeting those participating peacefully in the protest movement, immediately release those arbitrarily detained, restore full Internet access, and create conditions for meaningful dialogue.
#
# The continuing effort to suppress popular discontent, including through the excessive use of force, and the deliberate spread of misinformation and incitement to violence, must immediately cease.
# 1618
# Shocking violence in #Bangladesh must stop. Excessive force, disinformation & incitement to violence must cease.
#
# Deeply worried more lives will be lost at planned mass march on Dhaka. Political leadership + security forces must protect right to life.
#
# Accountability is crucial.
# 1619
# Read this
# 1620
# This is an outrageous propaganda by radical Hindutvawadis who align with Hasina. When an Awami goon, who happens to be Hindu, faces retaliation for their atrocities against the people, they project their Hindu identity. Hasina has killed more than 10 Hindu students during the first spell of protest, and a Hindu child was shot from a helicopter. I urge everyone to keep an eye on the Awami League's malicious tactics, which they have mastered well.
# Error translating row 1621: Hasina’s path to surviving student revolution narrows
#
# Sheikh Hasina, the embattled prime minister of Bangladesh, has only a few options as her authoritarian regime comes under an existential threat from a political revolution.
#
# by David Bergman
#
# On Sunday, close to 100 people died in Bangladesh, mostly protestors, but the number also includes significant numbers of policemen and governing Awami League members. The government has announced an indefinite curfew and has said that it will come down hard on “terrorists.” The student leaders, however, have announced that everyone who supports them should converge on Dhaka “to mark the ultimate signature of this student citizen uprising” as they want to lay siege on Prime Minister Sheikh Hasina’s residence, which has turned into a military garrison right now. The army has stated it will fulfil its constitutional duty and enforce the curfew, but it will not shoot protestors.
#
# The government’s decision to call on its party activists to assemble on Saturday, at the same time as huge numbers of protestors were on the same streets, was extremely reckless, and it was entirely foreseeable that clashes and deaths (on both sides) would result. The government gains by being able to brand protestors as “terrorists”: the more violence there is, particularly when its side are victims, the better it suits them politically.
#
# The government’s decision to call a curfew on Saturday evening is primarily to try and prevent people from converging on Dhaka. The students are, however, not going to stop their programmes simply because a curfew has been called. Many people who would otherwise have taken part in converging on Dhaka may well be deterred by Sunday’s killings, but enough will take part to make it potentially a huge rally.
#
# The army’s position on how it will enforce the curfew is crucial. It is significant that the army chief has, it appears, agreed not to shoot at “the people” and has messaged that the army is on the “people’s side.”. However, there are lots of internal dynamics that can complicate the situation, with some generals more loyal to Hasina than others. To make it all more complicated, junior officers also have mixed views - so, for example, the generals loyal to Hasina may feel they cannot risk alienating their subordinates. It is notable that a video shared widely showed some army officers today siding with the protestors against the police and Awami League.
#
# All things being equal, it is, more likely that the army will allow the protestors to gather in Dhaka, as long as there is no serious violence.
#
# However, going by Saturday, Awami League activists (and the police) will try to clash with the protestors seeking to congregate in Dhaka, something that could push the protestors’ aims off course. This is where the army will have to make a crucial decision - to side with the protestors or with the Awami League and police.
#
# The international community continues to be silent. There are unconfirmed reports that India has told Hasina that her time is up, or at least that they can do no more to support her. Since India is a key external supporter of the Awami League and the Hasina regime, this would, if true, be significant. (Of course, if things do come to a crunch, India will make sure Hasina and her family are safe).
#
# However, India will be very concerned about what comes after Hasina and may seek to be involved in the process of transition. It is important to note that India also has significant influence over certain parts of the army.
#
# What about the US, EU, UK and the rest of the liberal democratic countries? They have in the past taken their cues from India, and will no doubt continue to be influenced by it. However, the total silence of these countries over recent days is both shameful and extraordinary.
#
# On the one hand, there are all the signs of a popular revolution going on, and on the other hand, a government (which they have supported) willing to create anarchy in the country for the sake of staying in power. You would imagine that this would be the moment for them to finally put pressure on Sheikh Hasina to resign and take the appropriate steps to allow a peaceful move (with the likely assistance of the army) to a transitional government.
#
# Perhaps something is happening in the background, but reports suggest that there is no unanimity amongst the international community on what to do. In addition, some embassies are said to have concerns about the safety of their own staff. Together, it appears right now that these countries are paralysed.
#
# Not helping with this, of course, is the fact that the United States has no ambassador in position. Haas, the former ambassador who left the country just a few weeks ago, was a significant critic of the Awami League, and had he been in Dhaka now, the international response could well have been different.
#
# How does one make the transition from an Awami League government to some kind of interim government? It is not straightforward, particularly if you want to avoid the impression of an army coup. In 2007, when the army did take over (and set up an interim government) there was no political government in place, only a caretaker one. It was therefore easy for the army to get the President to proclaim a state of emergency. Now, however, there is a prime minister, a Cabinet and a parliament in place - none of whom want to leave power.
#
# This means that Sheikh Hasina has to agree to resign and also make the relevant moves to allow an interim government to take over. She clearly does not want to do anything of the sort at the moment - nor see a need to. It therefore appears that the protests have to reach a level where she has no option but to resign – or at least she realises it is in her own best interests to do so.
#
# The army’s role in the transition will be important - to ensure law and order in the country and a move back to stability.
#
# The next few days are likely to be decisive. One can only hope that Hasina and the Awami League do not want to go down fighting, resulting in an even higher toll of deaths and that she will agree sooner rather than later that she has to quit.
# @NetraNews --> Text length need to be between 0 and 5000 characters
# 1622
# What is going to happen now in @Bangladesh.  @NetraNews
# Error translating row 1623: What Next in #Bangladesh.  My thoughts below, and in @NetraNews
#
# ...
#
# Bangladesh has under the Awami League been an authoritarian state for many years - but the Labour party has throughout this time been completely silent about its relationship with the UK Awami League. In the last week however, the brutal natue of the Bangladesh regime has been exposed like never before, and it is time for the Labour party to come clean on where it stands towards the UK Awami League, the Labour party's staunch supporters.
#
# I will be writing more about this in subsequent posts.
# 1959
# In this clear footage, you can easily notice, BA 6047 Lieutenant Colonel Md.Redwanul Islam, commanding officer of the Border Guard Bangladesh (BGB), taking targeted shots using an AK-47 assault rifle. Simultaneously, members of the Bangladesh Police are using Chinese Type 56 SKS rifles to aim and shoot at unarmed civilians.
#
# The use of such lethal weapons to disperse a civilian crowd is a clear violation of the Geneva Conventions; lethal force against unarmed civilians is explicitly prohibited and is classified as a grave breach of international humanitarian law. Bangladesh is a signatory to these conventions. This constitutes a war crime.
#
# Footage courtesy: Withheld for safety concerns, can be disclosed to appropriate bodies.
#
# FYKI @srpoverty @UNPeacekeeping @RFKHumanRights @hrw @crdefenders @CIVICUSalliance @CIVICUSMonitor @volker_turk @StateDRL @Lacroix_UN @FCDOGovUK @StateDept @usembassydhaka @UKinBangladesh @EUinBangladesh @StateDeptSpox @State_SCA @HumanRightsCtte @MaryLawlorhrds
# 1960
# It is surely time for @UNPeacekeeping to immediately stop Bangladesh from providing peacekeepers to the United Nations until it undertakes an independent investigation of the violence used by the police, military and other para-military groups which has allegedly resulted in nearly 200 deaths of students and other protestors. If they cannot keep peace in Bangladesh, and instead cause killing and maiming, the country's security forces should not be trusted in other countries.
# 1961
# The authoritarian government of Bangladesh clearly committed a war crime by shooting unarmed civilians on the ground with automatic weapons from a helicopter. Multiple people were killed and injured in this attack, including Rakib Hasan, a student from the Military Institute of Science and Technology, when a helicopter belonging to the @USTreasury sanctioned Rapid Action Battalion (RAB) fired at civilians during the ongoing student protest on July 20, 2024.
# 1962
# The #Bangladesh government is now trying to round up opposition leaders - as they seek to blame them for the protests and resulting violence. I have just heard that at around 9.30 pm on July 20th (second day of the army-enforced curfew), 15-20 plain clothes policemen wearing police vests, came to the house of Abdul Awaal Mintu, a leader of the Bangladesh Nationalist Party, looking for him. He was not home. One of the police officers apparently said. "We are nice people but the next people who come may not be so nice." He is now in hiding.
# 1963
# Deeply concerned about violence in Bangladesh following clashes between police and military forces and protesters. I urge all sides to move from bloodshed to dialogue. The government must respect the right to protest and speak, and demonstrators must remain peaceful.
# 1964
# More good journalism about student protests in #Bangladesh
# 1965
# Important initiative
# 1966
# "Bangladesh authorities have ordered fixed-line internet providers to restore service only partially at locations of strategic value, according to a directive issued by the country’s internet regulators obtained by @NetraNews  News. This stands in stark contrast to claims made by Zunaid Ahmed Palak, Minister of Post, Telecommunications, and Information Technology, that connection to the internet would be restored in Bangladesh. The order by the Bangladesh Telecommunication Regulatory Commission specifically instructed providers to block any connectivity that attempts to bypass traffic through deep packet inspection, a type of data processing that can be used for eavesdropping and censorship, among other purposes. “That’s so they can see which sites are being accessed, from where, by which devices or IP addresses,” said an expert familiar with Bangladesh’s internet infrastructure. It also mandated that the block on Facebook, a widely used social media network in Bangladesh, remain in place during the ongoing unrest. However, some users flocked to social media once the shutdown was partially lifted, using VPNs and other proxy methods." netra.news/2024/bangladesh-r…
# 1967
# Great reporting
# 1968
# The brutality of the Bangladesh Police under the instruction of Sheikh Hasina is evident in the shooting of their own unarmed citizens during the student protest.
#
# I hope @UNPeacekeeping, @UNinBangladesh, @USEmbassyDhaka, @UKinBangladesh, @EUinBangladesh, @volker_turk, @MaryLawlorhrds, @srpoverty, @Lacroix_UN are keeping records.
# 1969
# 𝐒𝐇𝐄𝐈𝐊𝐇 𝐇𝐀𝐒𝐈𝐍𝐀 𝐌𝐔𝐒𝐓 𝐁𝐄 𝐒𝐓𝐎𝐏𝐏𝐄𝐃
#
# Every effort is being made by the murderous Bangladesh Awami League to spin the narrative of this bloodbath of the past eight days.
#
# They are claiming that the students and the government wanted the same thing. No, that was never the case. The students wanted a 5% quota at best for disabled and ethnic minorities and nothing for freedom fighters for all government jobs and not just the 1st and 2nd grade jobs. The students wanted the 5% quota to be made into a law through the parliament. The students didn't want the quota system to be abolished entirely. In the court verdict on Sunday, a 5% quota was kept for the freedom fighters and 1% each for the disabled, ethnic minorities and third gender people. And the court verdict says the government has the discretion to increase and decrease the quota ratio. The government would be issuing a circular as per the court verdict - it would not be made into a law. How is that the same as made into a law? How is that the same as what the student wanted?
#
# The @albd1971 government claims that it was BNP-Jamaat that had hijacked the students' movement and instigated the students further. Did Sheikh Hasina forget her jibe? "If the freedom fighters' heirs don't get government jobs, would razakars' heirs get it?" She effectively called the protesting students heirs of rajakars. This is what made the students furious. Then how can she forget her No. 2 Obaidul Quader ordering the Awami League's henchman Chhatra League to crack down on the unarmed, peaceful students? How can she forget her policemen open firing at the unarmed students? Thank God people in Bangladesh have a heart and couldn't take this atrocity. What was a peaceful, legitimate movement became a mass uprising of the utterly frustrated and repressed common people. Then thanks to Hasina's police, BGB and Chhatra League cracking down on the protesters, it almost became a civil war. It must be noted that people vandalized government properties and not private property - they particularly let out all their anger on objects that became vanity projects of this unelected, kleptocratic government.
#
# After she ordered shoot on sight on her countrymen, she has no right to stay in power. She was, after all, never voted in by the people. She's a usurper. She is an embodiment of evil and fascism.
# 1970
# #WATCH | The Pentagon is closely monitoring the situation in #Bangladesh as security forces carry out a ‘shoot on sight’ order, echoing the @StateDept position, according to the @PentagonPresSec in response to my question today. #SaveBangaldeshiStudents #HumanRights
# 1971
# How can a regime be so extremely brutal and inhumane? Just look at Sheikh Hasina- this video shows the extent of her barbarity in her absolute power. This footage is from just after a ‘shoot on sight’ order.
# 1972
# Extraordinary footage of Bangladesh police violence coming out of the country now that the Government begins to restore internet connections
# 1973
# ⁦@dwnews⁩ investigates UN marked vehicles to help quell student protests  yewtu.be/TMF9dWjg8P0?si=qLbw…
# 1974
# Since the internet connection was partially restored in Bangladesh, graphic images and videos have flooded the web. In one such video, members of the Bangladesh police are seen shooting at an injured person from point-blank range (at south of Dhaka, Shanir Akhra area). The injured individual was being carried away by another protestor, but the police shot both.
#
# Fearing safety, the person who was assisting ran away with his life, leaving the injured at the mercy of almighty. They were unarmed.
#
# Sheikh Hasina and her associates should be held responsible for this carnage.
#
# FYKI @srpoverty @UNPeacekeeping @RFKHumanRights @hrw @crdefenders @CIVICUSalliance @CIVICUSMonitor @volker_turk @StateDRL @Lacroix_UN @FCDOGovUK @StateDept @usembassydhaka @UKinBangladesh @EUinBangladesh @StateDeptSpox @State_SCA @HumanRightsCtte @MaryLawlorhrds
# 1975
# .@StateDeptSPOX speaks about the situation in Bangladesh.
# 1976
# If you're interested also check out our latest investigation 'How Torturers Become UN Peacekeepers'  A DW investigation together with @NetraNews and @SZ_Investigativ
#
# 👉yewtu.be/kjgBccv8DP0
# 1977
# @dwnews investigation: Bangladesh Army deployed APCs with UN insignia to quell the student protests. How can UN Peacekeeping not suspend Bangladesh as a TCC right now?
#
# yewtu.be/TMF9dWjg8P0?si=qPqs…
# 1978
# The Bangladesh government has now opened up the broadband internet in the capital Dhaka - after closing it as part of its crackdown on student protests. But unless you are connected to the internet by wires (i.e phones/laptops) there remains no internet (though in Gulshan, the exclusive part of Dhaka, there seems to be some WiFi  in some areas). The government remains scared.
# 1979
# On Friday night, July 19th, a group of men identifying themselves as police officers apprehended Nahid Islam, one of the coordinators of the ongoing student protest, from his friend's residence. They forcibly placed him into a vehicle belonging to the police or Border Guard Bangladesh.
#
# Blindfolded and handcuffed, Nahid was taken to an undisclosed location and interrogated. The attached photograph illustrates the brutal methods used during his interrogation, which I have purposely blurred.
#
# Nahid was left unconscious on the streets on Sunday morning, July 21st. After regaining some consciousness, he rented a three-wheeler to reach home before being hospitalized.
#
# His ordeal continued at the hospital. When journalists visited him for interviews, authorities pressured him to leave, citing safety concerns. “The hospital canceled my admission,” he said, noting that he had to seek treatment under unsafe conditions.
#
# I hope this helps you understand the state of affairs in Bangladesh.
# 1980
# Before the internet blackout in Bangladesh, a number of activists and journalists have said that @Meta removed  videos/images showing police firing on students/ protestors. Was this accidental overreach or the result of Bangladesh government instructions? Don't know, but important that Meta does not censor the posting of human rights violations, accidentally or otherwise.
# 1981
# Bangladesh student protests against quotas for government jobs have escalated into the country’s worst unrest in years.
#
# 🎧 On #TheTake, we hear from @ZulkarnainSaer about what could happen next: listen.aj.audio/g9sbt5cE
# 1982
# In Bangladesh, protests are no longer about the quota system aje.io/56dosn via @AJEnglish @shahidul
# 1983
# Bangladesh. Everyone Read this! @shahidul on the student protests and the government’s brutal response.
#
# aljazeera.com/opinions/2024/…
# 1984
# I was invited by @AJEPodcasts @mmbilal to explain the situation on the ground in Bangladesh and what sparked the protests. You can listen for a well-sourced update.
#
# yewtu.be/EtsbdwVE_1s?si=wTbs…
# 1985
# Oh really!?
# 1986
# “We are not retreating from our movement,” said tortured student leader Nahid Islam
# 1987
# I sincerely hope the senator moves from observation to concrete action soon.
# 1988
# Imagine the US and European response if student protesters were being slaughtered in Iran or Belarus just like they are being slaughtered in Bangladesh. Oh wait, we already know what the response was in those cases! Bangladeshi deaths do not register in Western conscience.
# 1989
# Soldiers of the Bangladesh Army are being made to fire in Mohammadpur. Reliable military sources alleged that their soldiers and other ranks (Lance Corporal-JCOs) and some officers with close affiliation with regime have been deployed for this task.
#
# FYKI @UNPeacekeeping @Lacroix_UN @UNinBangladesh @usembassydhaka @UKinBangladesh @EUinBangladesh @MaryLawlorhrds @volker_turk @amnestysasia @hrw @RFKHumanRights @AngelitaBaeyens @Yunus_Centre @MONUSCO
# 1990
# I was on @dwnews talking to @clarereports about the ongoing Bangladesh protests. Anyone looking for an overview of the crisis, watch.
#
# yewtu.be/l-1uyhNBf_Q?si=K9o0…
# 1991
# The United Nations criticises Bangladesh authorities for use by army of UN equipment as part of its control of student protests. UN spokesperson Stephane Dujarric said on Monday at press briefing that: "Our colleagues on the ground in Bangladesh have seen reports, disturbing reports, of UN marked vehicles that may have been used during the developments that we have seen in Bangladesh over last few days. It is Important for us to stress that  UN troops and police contributing countries are to use UN insignia and equipment marked with this insigne only when they are performing mandated tasks as part of a UN peacekeeping or UN political mission and within context of any UN mission. Our serious concern has been conveyed to the relevant authorities in Bangladesh by colleagues." facebook.com/story.php?story…
# 1992
# This is shocking. These convicted protestors, now languishing in a UAE jail are not going to get any help from the current Bangladesh government, that is for sure.  aljazeera.com/news/2024/7/22…
# 1993
# Good. But how about saying “concerned by the shooting of students by law enforcement authorities”.
# 1994
# Bangladesh's Minister of State for Information and Broadcasting @MAarafat71, stated,
#
#  "𝐓𝐡𝐞 𝐞𝐯𝐢𝐝𝐞𝐧𝐜𝐞 𝐢𝐬 𝐚𝐥𝐫𝐞𝐚𝐝𝐲 𝐭𝐡𝐞𝐫𝐞 𝐭𝐡𝐚𝐭 𝐦𝐚𝐧𝐲 𝐨𝐟 𝐭𝐡𝐞 𝐚𝐜𝐭𝐢𝐯𝐢𝐬𝐭𝐬 𝐡𝐚𝐯𝐞 𝐛𝐞𝐞𝐧 𝐝𝐫𝐮𝐠𝐠𝐞𝐝 𝐬𝐨 𝐭𝐡𝐚𝐭 𝐭𝐡𝐞𝐲 𝐜𝐚𝐧 𝐛𝐫𝐚𝐯𝐞𝐥𝐲 𝐜𝐨𝐧𝐟𝐫𝐨𝐧𝐭 𝐭𝐡𝐞 𝐩𝐨𝐥𝐢𝐜𝐞, 𝐨𝐩𝐞𝐧𝐢𝐧𝐠 𝐮𝐩 𝐭𝐡𝐞𝐢𝐫 𝐜𝐡𝐞𝐬𝐭𝐬."
#
# Does he even understand what he is saying? How disrespectful it is to speak so callously about the innocent young men,  who lost their lives due to police brutality. It is fortunate that the government itself provided subtitles for his statement. I kindly request members of the international press to take note of this obnoxious and unacceptable comment by Arafat, as well as his attempt to malign opposition political parties. It is unbelievable that someone can stoop so low.
# 1995
# Int'l reaction to student protests & hundreds of killings under Hasina’s... yewtu.be/xfG535-Ky7Q?si=HtJw… via @YouTube
# 1996
# Provide reliable information-
# 1997
# I am closely observing the situation in Bangladesh with deep concern. The right to peaceably assemble and protest is a cornerstone of a democratic society. Violent repression of the student protest is wrong and will only lead to more unrest.
# 1998
# Thank you, @USRepKeating, for standing up for the students of Bangladesh, where hundreds have been killed by Hasina’s forces under shoot-on-sight orders from the ruling government.
# 1999
# #WATCH | We are closely following the dire situation in #Bangladesh, where security forces have been ordered to shoot on sight, and internet shutdowns persist. Hundreds have died. We condemn all violence and express unwavering support for peaceful assembly. @StateDept
# #StudentProtest #QuotaMovement #SaveBangaldeshiStudents #HumanRights #FreeSpeech
# 2000
# Siblings from different mother 😂

# %% [markdown]
# # $

# %%
# df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami_all_translated_graph.xlsx", index=False)
df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\bnp\bnp_translated3.xlsx", index=False)

# %%
import pandas as pd
import time

# df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami_all_translated_graph.xlsx")
df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\bnp\bnp_translated2.xlsx")


for index, row in df.iterrows():
    # if pd.notnull(row['info_from_graph']):
    #     continue
    # if(index > 2000):
    #     break
    if(index < 1900):
        continue


    translation = str(row['translation'])
    print(index)
    print(translation)
    try:
        structured_data = structured_retriever(translation)
        # structured_data = [el.page_content for el in vector_index.similarity_search(translation)]

        print(structured_data)
    except Exception as e:
        continue
    df.at[index, 'info_from_graph'] = str(structured_data)  # Add translation at the current index
    time.sleep(1)


df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\bnp\bnp_translated2.xlsx", index=False)

# %%
import os
from openai import OpenAI
from mistralai import Mistral
# mistral_api_key = os.getenv("MISTRAL_API_KEY")

client = OpenAI(
    # base_url="https://api.groq.com/openai/v1",
    # api_key=os.getenv("GROQ_API_KEY")
    # base_url="https://generativelanguage.googleapis.com/v1beta/",
    # api_key=os.getenv("GOOGLE_API_KEY")
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY")


)

    # usually pro-awami tweets praise Awami league, Sheikh Hasina and allies or label them a victim.
    # Anti-awami tweets criticize hasina and allies and label them as criminal.
    # Sheikh Hasina's enemies are: Student-Led Movements, Muhammad Yunus, Bangladesh Nationalist Party (BNP)

    # Current government is yunus government and previous government was of Shikh Hasina.

    


    # ASK QUESTIONS TO DETECT STANCE:
    # Q: Who is being criticized here?
    # A: Muhammad Yunus. Beacuse the tweet uses 'illegal' to refer him. And yunus was appointed by students, that makes him Hasina's Enemy.
    # So it is in favour of Awami league.
    # Q: Which government is in power in the tweet?
    # A: Muhammad Yunus's goverment is in power in the tweet. Yunus came to power after hasina.
    # So it is in favour of Awami league.


    # Answer in just 0 and 1. You detect political stance whether in favour of awami league:1 or against awami league:0.
    # NO EXTRA WORDS OR EXPLANATION OR PLEASANTARIES IN YOUR RESPONSE.
    #     in favour of awami league:1 or against awami league:0.
#     For example, The tweet [The head of the UN Human Rights Commission's visit to Bangladesh raises concerns over the illegal Yunus government!
# ] is pro-awami league. Beacuse it says 'illegal Yunus government'.

# def detect_political_stance(tweet, relational_text='', tweet_info='', unstructured_data='', model = "mistral-large-latest"):
# def detect_political_stance(tweet, relational_text='', tweet_info='', unstructured_data='', model = "deepseek-r1-distill-llama-70b"):
# def detect_political_stance(tweet, relational_text='', tweet_info='', unstructured_data='', model = "gemini-1.5-flash"):
def detect_political_stance(tweet, relational_text='', tweet_info='', unstructured_data='', model = "deepseek/deepseek-r1:free"):


    # LLM prompt to extract entities
    entity_extraction_prompt = f"""
    tweet:
    {tweet}
    Read the tweet above. The tweet has a political stance. The tweet can say in favour of awami league of Bangladesh
    or against awami league, which is a political party of Bangladesh.
    Detect whether a tweet is in favour of awami league or against.

    # ASK QUESTIONS TO DETECT STANCE:
    # Q: Who is being criticized here?
    # A: Muhammad Yunus. Beacuse the tweet uses 'illegal' to refer him. And yunus was appointed by students, that makes him Hasina's Enemy.
    # So it is in favour of Awami league.
    # Q: Which government is in power in the tweet?
    # A: Muhammad Yunus's goverment is in power in the tweet. Yunus came to power after hasina.
    # So it is in favour of Awami league.

    for your decision making a few general info is given. from this info you can figure out the political relations in bangladesh


    TWEET_INFO:
    {tweet_info}
    
    GENERAL INFO:
    {relational_text}

    Extra info:
    {unstructured_data}
    """
    print(f"length: {len(entity_extraction_prompt)}")
    response = client.chat.completions.create(
    # response = client.chat.complete(

        model=model,
        messages=[{"role": "system", "content": "You are a helpful assistant. You detect political stance in favour of awami league, or against awami league."},
                    {"role": "user", "content": entity_extraction_prompt}],
        temperature=0
    )
    # time.sleep(30)
    # print(response)
    # entities = response["choices"][0]["message"]["content"].strip()
    translated_tweet = response.choices[0].message.content
    return translated_tweet

# def transform(text, model="gemma2-9b-it"):
# def transform(text, model="gemini-1.5-flash"):
def transform(text, model="deepseek/deepseek-r1:free"):




    # LLM prompt to extract entities
    entity_extraction_prompt = f"""
    If the text below says tweet is in favour of awami league then return 1.
    else, if the text below says the tweet is against awami league then return 0.
    NO EXTRA WORDS OR EXPLANATION OR PLEASANTARIES IN YOUR RESPONSE. Only 1 or 0.

    text:
    {text}
 
    """
    print(f"length: {len(entity_extraction_prompt)}")
    # response = client.chat.complete(
    response = client.chat.completions.create(

        model=model,
        messages=[{"role": "system", "content": "You are a helpful assistant. You answer in just 0 or 1."},
                    {"role": "user", "content": entity_extraction_prompt}],
        temperature=0
    )
    # time.sleep(30)
    # print(response)
    # entities = response["choices"][0]["message"]["content"].strip()
    translated_tweet = response.choices[0].message.content
    return translated_tweet

# %%
import pandas as pd
import time
# Read the CSV file
# df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami_all_translated_graph.xlsx")
# df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\bnp\bnp_translated3.xlsx")
# df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\New folder\all_ablation.xlsx")
df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\all_embedding.xlsx")



for index, row in df.iterrows():
    # if(index > 2100):
    #     break
    # if(index < 2033):
    #     continue

    if(index > 100):
        break


    translation = str(row['translation'])
    structured_data = str(row['info_from_graph'])
    # unstructured_data = str([el.page_content for el in vector_index.similarity_search(translation)])
    unstructured_data = str(row['embedding'])
    relational_text='''
Sheikh Hasina's Enemies:

Student Movements
Anti-Awami League Factions
Bangladesh Nationalist Party (BNP)
Jamaat-e-Islami
Civil Society Activists
Retaliatory Civilians
Muhammad Yunus (as part of the transitional challenges faced by the interim government under his leadership)

List of Sheikh Hasina's Allies:

Hindus
Awami League Loyalists
Chhatra League (Student wing of the Awami League)
Political Allies of the Awami League
Groups Supporting the Liberation War's Legacy
Supporters Valuing the Awami League's Historical Role'''

    # stance = detect_political_stance(translation, relational_text, str(structured_data), unstructured_data='', model='gpt-4o')
    # stance = detect_political_stance(translation, relational_text, structured_data, unstructured_data='', model = 'gpt-4')
    # structured_data=""
    # relational_text=""
    stance = detect_political_stance(translation, relational_text, structured_data, unstructured_data="")
    print(stance)
    time.sleep(.5)
    stance = transform(stance)

    # str(row['embedding'])
    # stance = detect_political_stance(translation, "", model = 'gpt-4o')

    print(f"{index}: {row['label']}-{stance}")
    # print(translation)
# prediction_using_gpt-4o-only-choq
    df.at[index, 'gemini-grasp-choq'] = stance
    time.sleep(10)
    if(index%10==0):
        time.sleep(45)


# df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami_all_translated_graph.xlsx", index=False)
# df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\New folder\all_ablation.xlsx", index=False)
df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\all_embedding.xlsx", index=False)
# Out:
# length: 2167
# The tweet is **in favour of the Awami League**.
#
# **Key reasons:**
# 1. **Criticism of Yunus:** The tweet labels the "Yunus government" as "illegal," directly attacking Muhammad Yunus, who is categorized as an enemy of Sheikh Hasina (Awami League leader).
# 2. **Political context:** Yunus is framed as part of a transitional challenge to Hasina's authority, and opposition to him aligns with pro-Awami League narratives.
# 3. **Implicit support for Hasina:** By condemning Yunus (a Hasina rival), the tweet indirectly bolsters the legitimacy of the Awami League-led government.
#
# The stance reflects alignment with Awami League interests by discrediting their perceived adversaries.
# length: 949
# 0: 1-1
# C:\Users\HP\AppData\Local\Temp\ipykernel_25820\1525508431.py:60: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[index, 'gemini-grasp-choq'] = stance
# length: 2940
# The tweet is **in favour of Awami League**.
#
# ### Key Analysis:
# 1. **Target of Criticism**: The tweet criticizes Shibir (Islami Chhatra Shibir), the student wing of Jamaat-e-Islami, which is a known political opponent of the Awami League. By highlighting Shibir’s threatening behavior toward a former Chhatra League member (Awami League’s student wing), the tweet indirectly positions Shibir as a destabilizing force, aligning with Awami League’s narrative against its rivals.
#
# 2. **Context of Alliances**: Chhatra League (Awami League’s student wing) is portrayed here as a victim of Shibir’s aggression. Since Shibir is part of the anti-Awami League bloc (BNP-Jamaat alliance), exposing their actions serves to delegitimize Awami League’s opponents and implicitly supports the ruling party’s stance against such groups.
#
# 3. **Political Framing**: The phrase “current situation in the country” implies a critique of lawlessness, but the focus on Shibir’s threat (rather than government failure) suggests the tweet is rallying support for Awami League by emphasizing threats from its adversaries. This aligns with Awami League’s historical narrative of combating Islamist groups like Jamaat-e-Islami and their affiliates.
#
# **Conclusion**: The tweet reinforces Awami League’s position by condemning its opposition, making it pro-Awami League.
# length: 1606
# 1: 1-1
# length: 1871
# The tweet is **in favour of the Awami League**.
#
# **Key reasons:**
# 1. **#StepDownYunus**: Muhammad Yunus is explicitly named as an enemy of Sheikh Hasina (Awami League leader). The call for his resignation aligns with the Awami League's stance against him.
# 2. **Criticism of "fascism"**: While #BangladeshUnderFascism might seem critical of the government, the tweet’s focus on Yunus (not Hasina) suggests the accusation is directed at Yunus’s interim leadership, indirectly supporting Hasina’s faction.
# 3. **Context of allies/enemies**: Since Yunus is framed as an adversary of the Awami League, opposing him reinforces pro-Awami League sentiment.
#
# The tweet amplifies grievances against Yunus, a figure opposed by the Awami League, thereby favoring their position.
# length: 1039
# 2: 1-1
# length: 2016
# The tweet is **in favour of Awami League**.
#
# ### Key Analysis:
# 1. **Explicit Support**: The tweet directly states, "This country has moved forward under the leadership of #AwamiLeague" and repeats "#AwamiLeague will move forward again under the leadership of #AwamiLeague!" This is a clear endorsement of the party and its leadership.
#
# 2. **Hashtags**: The use of #sheikhhasina (the current Prime Minister and Awami League leader) alongside pro-Awami League hashtags reinforces alignment with the party.
#
# 3. **Context of Criticism**: While the first line ("You have almost destroyed the country...") appears critical, it does not target Awami League. Instead, it likely criticizes opposition factions (e.g., BNP, anti-Awami League groups) or interim challenges (e.g., Muhammad Yunus, whom the GENERAL INFO lists as a Hasina enemy). The call to "reform yourself" is directed at those opposing Awami League, not the party itself.
#
# 4. **Solution Offered**: The tweet positions Awami League as the solution to the "#BangladeshCrisis," urging a return to its leadership. This aligns with the party’s narrative of stability and progress under Sheikh Hasina.
#
# **Conclusion**: Despite initial ambiguity, the tweet’s explicit praise for Awami League and its framing of the party as the path forward indicate strong support.
# length: 1590
# 3: 1-1
# length: 2285
# The tweet is **against the Awami League**. Here's the breakdown:
#
# 1. **Target of Criticism**: The incident involves alleged torture of a Hindu student by **army personnel** (under the current Awami League-led government). Since the Awami League is in power, systemic failures or abuses by state forces (e.g., the military) reflect poorly on the government.
#
# 2. **Minority Persecution**: Hindus are listed as allies of Sheikh Hasina and the Awami League. Highlighting attacks on Hindus implies the government is failing to protect its allies, undermining its credibility. The TWEET_INFO explicitly notes "Awami League - ARSON_ATTACK -> Hindu," suggesting historical tensions that contradict their alliance.
#
# 3. **Political Context**: The Awami League’s opponents (BNP, Jamaat-e-Islami) are often accused of inciting communal violence. However, the tweet directly implicates state actors (army personnel), shifting blame to the ruling party rather than opposition groups.
#
# This narrative aligns with criticism of the Awami League’s governance and human rights record, positioning the tweet **against** the party.
# length: 1374
# 4: 1-0
# length: 1901
# The tweet is **in favour of the Awami League**.
#
# **Key Reasoning**:
# - The tweet criticizes the "#Yunus regime," referencing Muhammad Yunus, who is explicitly listed as an enemy of Sheikh Hasina (leader of the Awami League).
# - By accusing Yunus's government of enabling violence against minorities, the tweet indirectly aligns with the Awami League's narrative, which positions itself as a defender of minority rights and stability.
# - Since Yunus is framed as part of the opposition to Hasina's leadership, attacking his hypothetical regime reinforces support for the Awami League.
#
# This aligns with the broader political context where criticism of Hasina's adversaries (like Yunus) often signals pro-Awami League sentiment.
# length: 997
# 5: 1-1
# length: 1840
# The tweet is **in favour of Awami League**.
#
# **Key Analysis:**
# 1. **Criticism of Muhammad Yunus**: The tweet attacks Yunus ("failing to run the country"), who is explicitly listed as an enemy of Sheikh Hasina (Awami League leader). Criticizing Hasina's adversaries aligns with pro-Awami League sentiment.
# 2. **Hashtags**: #StepDownYunus and #BangladeshUnderFascism imply opposition to Yunus's perceived influence or governance, reinforcing support for the current Awami League-led government.
# 3. **Contextual Clues**: The GENERAL INFO clarifies that Yunus is part of the "transitional challenges" faced by Hasina's government. Discrediting him indirectly bolsters the Awami League's legitimacy.
#
# By targeting Yunus, the tweet aligns with Awami League's narrative against its opponents.
# length: 1059
# 6: 1-
# length: 1834
# The tweet is **in favour of the Awami League**.
#
# **Key Analysis:**
# 1. **Criticism Targets:** The tweet condemns Muhammad Yunus (#FascistYunus) and labels his alleged governance as fascist (#BangladeshUnderFascism). Yunus is explicitly listed as an enemy of Sheikh Hasina (Awami League leader), implying alignment with her supporters.
# 2. **Independence Narrative:** The accusation that the "student-public movement" aimed to "destroy signs of independence" aligns with the Awami League's historical role as custodians of Bangladesh’s liberation legacy. Opposition to such movements typically reflects pro-Awami League sentiment.
# 3. **Hashtags:** #StepDownYunus directly opposes Yunus, who is framed as a threat to the nation, reinforcing support for Hasina’s government.
#
# **Conclusion:** The tweet defends the Awami League’s ideological stance by attacking its perceived adversaries (Yunus and anti-independence forces).
# length: 1193
# 7: 1-1
# length: 2752
# The tweet is **against the Awami League**.
#
# **Key Analysis:**
# - The tweet refers to an "army-installed regime," which implicitly criticizes the current government (led by Sheikh Hasina and the Awami League) as illegitimate or authoritarian.
# - It accuses the regime of "political vendettas and arbitrary arrests," aligning with common opposition critiques of the Awami League's governance.
# - The claim that the regime granted "blanket immunity to anti-Hasina protesters" (her political enemies, like the BNP or Jamaat-e-Islami) is likely a sarcastic or exaggerated critique. It implies the government is hypocritically lenient toward violent opposition groups while suppressing dissent, further undermining its legitimacy.
#
# This aligns with anti-Awami League narratives that portray the government as oppressive and unaccountable.
# length: 1102
# 8: 1-0
# length: 1776
# The tweet is **in favour of Awami League**.
#
# **Key Analysis**:
# - The hashtag **#StepDownYunus** directly criticizes **Muhammad Yunus**, who is listed as an enemy of Sheikh Hasina (leader of the Awami League).
# - The phrase **#BangladeshUnderFascism** implies opposition to Yunus's perceived authoritarianism, aligning with the Awami League's narrative against him.
# - The tweet frames Yunus as a destabilizing figure (e.g., investors "wiped out"), reinforcing the Awami League's stance that Yunus and his allies threaten Bangladesh's stability.
# - Since the Awami League opposes Yunus, criticizing him indirectly supports the party's position.
#
# **Conclusion**: The tweet aligns with Awami League's anti-Yunus rhetoric, making it pro-Awami League.
# length: 1019
# 9: 1-1
# length: 1837
# The tweet is **in favour of the Awami League**.
#
# ### Key Analysis:
# 1. **Criticism Targets Muhammad Yunus**: The hashtags #StepDownYunus and #FascistYunus directly attack Muhammad Yunus, who is listed as an enemy of Sheikh Hasina (leader of the Awami League) in the GENERAL INFO. Criticizing Yunus aligns with the Awami League's stance.
#
# 2. **Context of "Student Coordinators"**: The tweet accuses "student coordinators" (likely linked to Yunus's interim government or anti-Awami League factions) of being "robbers." This mirrors the Awami League's narrative of opposing groups like the BNP, Jamaat, or Yunus-aligned factions as corrupt or destabilizing.
#
# 3. **#BangladeshUnderFascism**: This implies the tweet views Yunus's rule as oppressive. Since Yunus is framed as a transitional challenger to Hasina's leadership, opposing him supports the Awami League's position.
#
# 4. **GENERAL INFO Context**: The Awami League and its allies (e.g., Chhatra League) are positioned against Yunus and his supporters. The tweet’s criticism of Yunus’s governance (e.g., repealed laws, fleeing the country) aligns with pro-Awami League rhetoric.
#
# **Conclusion**: The tweet opposes Yunus and his allies, who are adversaries of the Awami League, making it implicitly pro-Awami League.
# length: 1542
# 10: 1-1
# length: 1977
# The tweet is **in favour of the Awami League**.
#
# ### Key Analysis:
# 1. **#StepDownYunus**: Muhammad Yunus is explicitly named as an enemy of Sheikh Hasina (Awami League leader) in the GENERAL INFO. Demanding his resignation aligns with the Awami League's stance against him.
# 2. **Criticism of Governance**: The tweet highlights police failure to control robbery, indirectly criticizing Yunus's hypothetical governance (framed as transitional challenges in the info). Since Yunus is positioned as opposing Hasina, attacking his governance supports the Awami League.
# 3. **#BangladeshUnderFascism**: While this could seem anti-government, the context implies it targets Yunus's leadership (as an enemy of Hasina), reinforcing pro-Awami League sentiment by opposing his rule.
#
# The tweet opposes Yunus, who is adversarial to the Awami League, thereby favoring Hasina's party.
# length: 1134
# 11: 1-1
# length: 3440
#
# length: 264
# 12: 1-0
# length: 2585
#
# length: 264
# 13: 1-0
# length: 3233
# The tweet is **in favour of Awami League**.
#
# **Key Indicators:**
# 1. **Chhatra League Affiliation**: The victim, Mehedi Hasan Tamim, is described as an active Chhatra League activist. Chhatra League is explicitly stated to be the student wing of the Awami League and a key ally of Sheikh Hasina.
# 2. **Criticism of BNP-Jamaat**: The tweet labels BNP and Jamaat as "terrorists," directly attacking these groups, which are listed as enemies of Sheikh Hasina.
# 3. **Rescue Narrative**: Highlighting the rescue of a Chhatra League member positions the Awami League and its affiliates as victims of violence, garnering sympathy and reinforcing their legitimacy.
#
# The language and framing align with pro-Awami League rhetoric by demonizing opposition groups (BNP/Jamaat) and valorizing their own supporters (Chhatra League).
# length: 1088
# 14: 1-1
# length: 2398
#
# length: 264
# 15: 1-
# length: 2374
# The tweet is **in favour of Awami League**.
#
# ### Key Analysis:
# 1. **Targets of Criticism**: The tweet condemns "Hizb ut Tahrir and BNP Jamaat terrorists," both of which are explicitly listed as **enemies of Sheikh Hasina (Awami League leader)** in the GENERAL INFO.
# 2. **Police Action Framed Positively**: The police (deployed by the Awami League-led government) are described as eliminating these groups ("burnt to death by the police"). This aligns with the Awami League's suppression of its political opponents.
# 3. **Political Context**: BNP and Jamaat are historical rivals of the Awami League. Portraying their members as "terrorists" and celebrating their deaths reinforces pro-Awami League narratives that justify crackdowns on opposition groups.
#
# The tweet supports the Awami League by framing its adversaries as terrorists and legitimizing state violence against them.
# length: 1151
# 16: 1-
# length: 3133
#
# length: 264
# 17: 1-
# length: 1786
#
# length: 264
# 18: 1-0
# length: 2989
# The tweet is **in favour of the Awami League**.
#
# **Key Reasoning**:
# - The tweet criticizes Sharmeen S Murshid, an adviser to the "unconstitutional interim government."
# - The interim government referenced here is linked to **Muhammad Yunus**, a known political adversary of Sheikh Hasina (Awami League leader).
# - By condemning the interim government (led by Yunus) and its representatives, the tweet implicitly aligns with opposition to Hasina's enemies, thus favoring the Awami League's stance against this transitional administration.
# length: 806
# 19: 1-1
# length: 3111
# The tweet is **in favour of Awami League**.
#
# **Key Analysis:**
# 1. **Criticism Directed at Opposition Groups**: The tweet highlights violence against an innocent Awami League supporter (Alamgir) who is not politically active, framing him as a victim of "terrorists." Given that "Shibir" (Islami Chhatra Shibir, the student wing of Jamaat-e-Islami) is a known opposition group and enemy of the Awami League, the blame for the killings is implicitly placed on anti-Awami forces.
# 2. **Sympathy for Awami League Supporters**: By emphasizing Alamgir’s innocence and religious devotion, the tweet evokes sympathy for Awami League supporters, portraying them as targets of unjust violence perpetrated by opposition-aligned groups.
# 3. **Contextual Alignment**: The Awami League is depicted as a protector of secularism and minorities in the provided info. Highlighting attacks on its supporters reinforces the narrative that the party and its followers are under threat from hostile factions (e.g., BNP/Jamaat/Shibir), which aligns with pro-Awami League messaging.
#
# This framing serves to bolster support for the Awami League by positioning its supporters as victims of opposition violence, thereby justifying the party’s stance against its political rivals.
# length: 1523
# 20: 1-
# length: 3653
# The tweet is **in favour of the Awami League**.
#
# **Key Indicators:**
# 1. **Direct Affiliation**: The Bangladesh Chhatra League (BCL) is explicitly stated as the student wing of the Awami League. Praising BCL inherently supports the Awami League.
# 2. **Founder Emphasis**: Highlighting Sheikh Mujibur Rahman (founder of BCL and father of Sheikh Hasina, the current Awami League leader) ties the organization to the Awami League’s legacy.
# 3. **Positive Framing**: Terms like "legacy of valor," "powerful force for justice," and "mission to mobilize students against oppression" glorify BCL’s historical role, aligning with the Awami League’s narrative of liberation and sovereignty.
# 4. **Historical Context**: References to movements like the Bengali Language Movement and anti-colonial struggles reinforce the Awami League’s foundational role in Bangladesh’s history.
#
# No criticism or negative language is present, and the tone aligns with pro-Awami League messaging.
# length: 1239
# 21: 1-1
# length: 1953
# The tweet is **in favour of the Awami League**.
#
# **Key Analysis:**
# 1. The term **"illegal government"** likely refers to a transitional or opposition-led administration (e.g., one associated with Muhammad Yunus or anti-Awami League factions), whom Sheikh Hasina's allies would reject as illegitimate.
# 2. The emphasis on **"the people's decision"** aligns with the Awami League's narrative of democratic legitimacy, contrasting with opposition groups (like BNP or Yunus-backed interim governments) that they frame as undemocratic or externally imposed.
# 3. Hashtags like **#SaveBangladesh** and **#BangladeshCrisis** are often used by pro-Awami League voices to criticize opposition movements as destabilizing forces.
#
# By rejecting an "illegal government" (associated with Hasina's enemies), the tweet implicitly supports the Awami League's claim to legitimacy.
# length: 1133
# 22: 1-1
# length: 3073
#
# length: 264
# 23: 1-0
# length: 2115
# The tweet is **in favour of Awami League**.
#
# **Key Reasons:**
# 1. **Criticism of BNP**: The tweet explicitly accuses BNP of violence against a leader of the Swechchhasebak League (an Awami League affiliate), framing BNP as terrorists. Since BNP is a known opponent of Sheikh Hasina and the Awami League, this aligns with pro-Awami League sentiment.
# 2. **Victim Affiliation**: The victim, Alamgir Kabir, is a vice president of the Awami Swechchhasebak League, directly tying the narrative to support for Awami League members.
# 3. **Hashtags**: #BNPViolence and #WeDemandJustice emphasize condemnation of BNP, while #StepDownYunus indirectly supports Awami League by targeting Muhammad Yunus, a figure associated with challenges to Hasina's leadership.
#
# The tweet amplifies grievances against Awami League's opponents, reinforcing solidarity with the party.
# length: 1126
# 24: 1-1
# length: 1670
# The tweet is **in favour of the Awami League**.
#
# **Key Analysis:**
# - The hashtag **#StepDownYunus** directly criticizes **Muhammad Yunus**, who is listed as an enemy of Sheikh Hasina (leader of the Awami League).
# - Opposition to Yunus aligns with the Awami League's stance, as he represents a faction challenging Hasina's authority.
# - The tweet’s framing of "oppression" likely refers to Yunus's actions or policies, implying support for the Awami League's opposition to him.
# - Historical context (Yunus's repealed laws, exile, and adversarial relationship with Hasina) reinforces that criticism of Yunus benefits the Awami League.
#
# **Conclusion:** Criticizing Yunus signals alignment with the Awami League’s political interests.
# length: 1004
# 25: 1-
# length: 1962
# The tweet is **in favour of the Awami League**.
#
# **Key Analysis:**
# 1. **Criticism Targets Yunus:** The tweet labels Yunus's government as "illegitimate," directly attacking Muhammad Yunus, who is listed as an enemy of Sheikh Hasina (Awami League leader).
# 2. **Context of Alliances:** Since Yunus is framed as an adversary of the Awami League, condemning his government aligns with pro-Awami League sentiment.
# 3. **Hashtags Reinforce Opposition:** The use of #StepDownYunus signals rejection of Yunus's authority, indirectly supporting the Awami League's position against him.
#
# By opposing Yunus (an enemy of the Awami League), the tweet implicitly favors the Awami League's political stance.
# length: 964
# 26: 1-
# length: 1671
# The tweet is **in favour of the Awami League**.
#
# **Key Reasoning**:
# - The tweet criticizes **Muhammad Yunus** (using #StepDownYunus), who is explicitly listed as an enemy of Sheikh Hasina (Awami League leader).
# - The Awami League and its supporters have historically opposed Yunus, particularly during his interim government tenure, which clashed with their interests.
# - The hashtag #BangladeshCrisis likely references instability linked to Yunus's actions (e.g., repealing laws, staying abroad), indirectly framing the Awami League as a stabilizing force.
#
# By targeting Yunus, the tweet aligns with the Awami League's narrative of opposing figures perceived as threats to their governance.
# length: 964
# 27: 1-1
# length: 3368
# The tweet is **in favour of Awami League**.
#
# **Key Reasoning**:
# - The tweet condemns violence by **Shibir** (Jamaat-e-Islami's student wing) and **BNP**, both of which are political enemies of the Awami League.
# - It highlights an attack on the family of a **Jubo League activist** (Jubo League is the youth wing of the Awami League, an ally of Sheikh Hasina).
# - The hashtags **#JamaatViolence** and **#BNPViolence** align with the Awami League's narrative of blaming these opposition groups for instability, thereby indirectly supporting the Awami League's legitimacy and moral standing.
#
# By framing the incident as part of systemic violence by opposition factions, the tweet reinforces the Awami League's position as a victim of "terrorism" and justifies its crackdown on rivals.
# length: 1053
# 28: 1-
# length: 5812
# The tweet is **in favour of the Awami League**.
#
# **Key Indicators:**
# 1. **Pro-Hasina/Awami League Hashtags**: #OnceAgainSheikhHasina, #AwamiLeague, #StandWithSheikhHasina, and #JoyBangla explicitly signal support for Sheikh Hasina and her party.
# 2. **Anti-Yunus Rhetoric**: Hashtags like #StepDownYunus, #FascistYunus, and #BangladeshUnderFascism criticize Muhammad Yunus, who is framed as an adversary of Sheikh Hasina in the provided context. Opposition to Yunus aligns with pro-Awami League narratives.
# 3. **Implied Defense of Awami League**: Phrases like #SaveBangladesh and #BangladeshAtRisk suggest a narrative that the Awami League is needed to protect Bangladesh from perceived threats (linked here to Yunus).
#
# The tweet amplifies pro-Awami League messaging by attacking Yunus (Hasina’s rival) and rallying support for Hasina’s leadership.
# length: 1121
# 29: 1-1
# length: 1776
# The tweet is **against the Awami League**.
#
# ### Key Analysis:
# 1. **Revolutionary Tone**: Phrases like "fight," "ignite the gunpowder," and "deluge dance" evoke imagery of resistance against oppressive forces. In Bangladesh's political context, such language is often used by opposition groups criticizing the ruling Awami League government.
#
# 2. **Target of Criticism**: The tweet addresses the "proletariat" and "the deprived," urging them to rise against "those who are exploiting you." Given that the Awami League is the ruling party, this aligns with anti-government rhetoric, framing the regime as exploitative.
#
# 3. **Political Context**: The Awami League (under Sheikh Hasina) is currently in power. Criticizing "exploiters" in a revolutionary context typically targets the incumbent government. Pro-Awami League voices, like the Chhatra League (its student wing), would not use such confrontational language against the state.
#
# 4. **Enemies/Allies Dynamic**: The tweet’s call for mass mobilization resembles rhetoric used by Sheikh Hasina’s opponents, such as the BNP, student movements, or civil society activists (listed as her enemies). Pro-Awami League messaging would emphasize stability, development, or historical legacy, not rebellion.
#
# **Conclusion**: The tweet’s anti-establishment fervor and mobilization of the "deprived" against "exploiters" strongly suggest opposition to the Awami League-led government.
# length: 1700
# 30: 1-
# length: 2666
# The tweet is **against the Awami League**.
#
# **Key Indicators:**
# 1. **#BangladeshUnderFascism** and **#SaveBangladesh** imply criticism of the current government (led by Awami League), framing it as oppressive.
# 2. **#StepDownYunus** targets Muhammad Yunus, who is framed in the context as part of a transitional challenge rather than the current regime. This hashtag distracts from direct criticism of Awami League but does not negate the broader anti-government sentiment.
# 3. The tweet references a **ban on Chhatra League**, the student wing of Awami League. Criticizing such a ban (or highlighting its suppression) aligns with opposition to the Awami League’s governance.
#
# While the mention of Yunus might seem contradictory, the dominant hashtags and focus on Chhatra League’s suppression strongly signal opposition to the Awami League.
# length: 1112
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 52
#      50 print(stance)
#      51 time.sleep(.5)
# ---> 52 stance = transform(stance)
#      54 # str(row['embedding'])
#      55 # stance = detect_political_stance(translation, "", model = 'gpt-4o')
#      57 print(f"{index}: {row['label']}-{stance}")
#
# Cell In[2], line 119, in transform(text, model)
#     109 response = client.chat.completions.create(
#     110
#     111     model=model,
#    (...)
#     114     temperature=0
#     115 )
#     116 # time.sleep(30)
#     117 # print(response)
#     118 # entities = response["choices"][0]["message"]["content"].strip()
# --> 119 translated_tweet = response.choices[0].message.content
#     120 return translated_tweet
#
# TypeError: 'NoneType' object is not subscriptable

# %%
df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\all_embedding.xlsx", index=False)

# %%
results = vector_index.similarity_search(row['translation'], k=3)
print(len(results))  # Number of items retrieved
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL () { ... }} {position: line: 1, column: 1, offset: 0} for query: "CALL { CALL db.index.vector.queryNodes($index, $k, $embedding) YIELD node, score WITH collect({node:node, score:score}) AS nodes, max(score) AS max UNWIND nodes AS n RETURN n.node AS node, (n.score / max) AS score UNION CALL db.index.fulltext.queryNodes($keyword_index, $query, {limit: $k}) YIELD node, score WITH collect({node:node, score:score}) AS nodes, max(score) AS max UNWIND nodes AS n RETURN n.node AS node, (n.score / max) AS score } WITH node, max(score) AS score ORDER BY score DESC LIMIT $k RETURN reduce(str='', k IN ['text'] | str + '\\n' + k + ': ' + coalesce(node[k], '')) AS text, node {.*, `embedding`: Null, id: Null, `text`: Null} AS metadata, score"
# 3

# %%
import pandas as pd
import time

df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\all_embedding.xlsx")


for index, row in df.iterrows():
    if(index > 100):
        break
    # if(index < 1500):
    #     continue
    try:
        unstructured_data = str([el.page_content for el in vector_index.similarity_search(row['translation'], k=3)])

        # print(structured_data)
    except Exception as e:
        continue


    print(f"{index}: {row['label']}-{unstructured_data}")
    # print(translation)

    df.at[index, 'embedding'] = unstructured_data
    time.sleep(.25)

# df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami_all_translated_graph.xlsx", index=False)
df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\all_embedding.xlsx", index=False)

# %%
df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\all_embedding.xlsx", index=False)

# %%
# df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami_all_translated_graph.xlsx", index=False)
# df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\bnp\bnp_translated3.xlsx", index=False)

# %% [markdown]
# # $

# %%
import pandas as pd

df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\all_embedding.xlsx")
distinct_values = df['Handle'].unique()

print("Distinct values in Column1:", distinct_values)
# Out:
# Distinct values in Column1: ['@alliance29464' '@sajeebwazed' '@Chellaney' '@albd1971'
#  '@bdperspectives' '@ATeam_1971' '@bdwatch2024' '@k_shayera' '@VNouka'
#  '@NeenaRai' '@Asifurrahman71' '@pressxpresspx' '@sumon_tarek'
#  '@MAarafat71' '@BD_DiGEST' '@AsadZam89687147' '@RUSI_org' '@CJBdingo25'
#  '@istiak_ahmmad' '@Udashi_Pothik' '@MaryMillben' '@OnceAgainHasina'
#  '@SushantaDGupta' '@INSIGHTUK2' '@amnestysasia' '@IndiaToday'
#  '@iindrojit' '@Bangladesh_Fact' '@TimesAlgebraIND' '@CChoddogram'
#  '@FreedomRightsRL' '@sagor250' nan '@ZulkarnainSaer' '@MushfiqulFazal'
#  '@mrforayeji' '@redwanxyz' '@theBDarmy' '@tasneem' '@UNinIndia'
#  '@support_yunus' '@shafiqalam2024' '@EUinBangladesh' '@dailystarnews'
#  '@volker_turk' '@muktadirnewage' '@Oliver_Tomarket' '@JonFDanilowicz'
#  '@ChiefAdviserGoB' '@dhruvrahtee']

# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\all_embedding.xlsx")

# Group by another column (e.g., 'GroupColumn') and find distinct 'Handle' values in each group
grouped = df.groupby('label')['Handle'].apply(lambda x: x.unique())

# Print the result
for group, handles in grouped.items():
    print(f"Group: {group}")
    print("Distinct Handles:", handles)
    print("-" * 50)
# Out:
# Group: 0
# Distinct Handles: [nan '@ZulkarnainSaer' '@MushfiqulFazal' '@mrforayeji' '@redwanxyz'
#  '@theBDarmy' '@tasneem' '@UNinIndia' '@support_yunus' '@shafiqalam2024'
#  '@EUinBangladesh' '@dailystarnews' '@volker_turk' '@muktadirnewage'
#  '@Oliver_Tomarket' '@JonFDanilowicz' '@ChiefAdviserGoB' '@dhruvrahtee']
# --------------------------------------------------
# Group: 1
# Distinct Handles: ['@alliance29464' '@sajeebwazed' '@Chellaney' '@albd1971'
#  '@bdperspectives' '@ATeam_1971' '@bdwatch2024' '@k_shayera' '@VNouka'
#  '@NeenaRai' '@Asifurrahman71' '@pressxpresspx' '@sumon_tarek'
#  '@MAarafat71' '@BD_DiGEST' '@AsadZam89687147' '@RUSI_org' '@CJBdingo25'
#  '@istiak_ahmmad' '@Udashi_Pothik' '@MaryMillben' '@OnceAgainHasina'
#  '@SushantaDGupta' '@INSIGHTUK2' '@amnestysasia' '@IndiaToday'
#  '@iindrojit' '@Bangladesh_Fact' '@TimesAlgebraIND' '@CChoddogram'
#  '@FreedomRightsRL' '@sagor250']
# --------------------------------------------------

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# Group by year and month, and count rows in each group
df['year_month'] = df['Timestamp'].dt.to_period('M')  # Extract year and month
counts = df.groupby('year_month').size()  # Count rows in each month

# Convert result to a DataFrame
counts_df = counts.reset_index(name='row_count')

# Display the result
print(counts_df)
# Out:
#   year_month  row_count
# 0    2024-07        271
# 1    2024-08        523
# 2    2024-09        527
# 3    2024-10        899
# 4    2024-11        334
# 5    2024-12        293
# C:\Users\HP\AppData\Local\Temp\ipykernel_46148\1079744447.py:4: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['year_month'] = df['Timestamp'].dt.to_period('M')  # Extract year and month

# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\all_embedding.xlsx")

# Group by another column (e.g., 'GroupColumn') and get unique 'Handle' values
grouped = df.groupby('label')['Handle'].apply(lambda x: set(x.unique()))

# Get the intersection of two specific groups
group1 = '1'  # Replace with the name of the first group
group2 = '0'  # Replace with the name of the second group

if group1 in grouped and group2 in grouped:
    intersection = grouped[group1] & grouped[group2]  # Intersection of the sets
    print(f"Intersection of {group1} and {group2}: {intersection}")
else:
    print("One or both groups not found in the data.")
# Out:
# One or both groups not found in the data.

# %%
import pandas as pd

# Read the Excel file
# df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami_all_translated_graph.xlsx")
df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\bnp\bnp_translated3.xlsx")

# df = df[:2000]
# Create two new DataFrames
# df_match = df[df['label'].astype(int) == df['predicted_label'].astype(int)]
df_no_match = df[df['label'].astype(str) != df['predicted_label'].astype(str)]

# Count the number of matches
cnt = len(df_no_match)

print(f"Number of matches: {cnt}")

# Save the new DataFrames to Excel or CSV if needed
# df_match.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\awami_match.xlsx", index=False)
# df_match.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\bnp\bnp_match.xlsx", index=False)

df_no_match.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\bnp_non_match.xlsx", index=False)
# Out:
# Number of matches: 328

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\New folder\all.xlsx")
df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\shuffled_labels.xlsx")
# r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\shuffled_labels.xlsx"

# Extract ground truth and predictions
y_true = df["original_label"]
y_pred = df["mistral-few-shot-rag-18-20"]
# y_true = df["label"]
# y_pred = df["predicted_label"]

# Calculate metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

# If you need AUC, ensure predictions are probabilities or binary
try:
    auc = roc_auc_score(y_true, y_pred)
except ValueError:
    auc = "AUC requires probability predictions or binary labels with two classes."

# Print metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"AUC: {auc}")
# Out:
# Accuracy: 0.6140
# Precision: 0.7540
# Recall: 0.4054
# F1 Score: 0.5273
# AUC: 0.6278052731704417

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for each setting.
data = {
    'Zero-shot': {
        'GPT-4': [58.00, 80.04, 27.85, 41.30],
        'GPT-4o': [59.61, 84.81, 29.17, 43.30],
        'Gemini 1.5 Pro': [59.64, 75.17, 35.85, 48.54],
        'Mistral Large Latest': [53.39, 70.79, 20.83, 32.19],
        'DeepSeek R1': [61.40, 75.40, 40.54, 52.73]
    },
    'Few-shot': {
        'GPT-4': [51.07, 63.53, 18.33, 28.39],
        'GPT-4o': [53.07, 63.66, 27.12, 38.03],
        'Gemini 1.5 Pro': [51.46, 64.77, 18.85, 29.24],
        'Mistral Large Latest': [50.09, 60.76, 17.00, 26.56],
        'DeepSeek R1': [62.59, 81.26, 38.43, 52.18]
    },
    'Few Shot with Naive-RAG': {
        'GPT-4': [56.41, 78.60, 24.54, 37.50],
        'GPT-4o': [63.96, 83.11, 40.34, 54.32],
        'Gemini 1.5 Pro': [57.50, 81.29, 25.86, 39.24],
        'Mistral Large Latest': [54.97, 74.47, 23.15, 35.32],
        'DeepSeek R1': [64.56, 75.90, 48.74, 59.36]
    },
    'GRASP-ChoQ': {
        'GPT-4': [88.55, 88.61, 90.01, 89.30],
        'GPT-4o': [85.04, 87.81, 83.40, 85.85],
        'Gemini 1.5 Pro': [75.10, 87.49, 61.97, 72.55],
        'Mistral Large Latest': [72.60, 83.83, 59.99, 69.93],
        'DeepSeek R1': [93.12, 96.14, 90.67, 93.33]
    }
}


# Define models and metrics
models = ['GPT-4', 'GPT-4o', 'Gemini 1.5 Pro', 'Mistral Large Latest', 'DeepSeek R1']
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
colors = ['blue', 'orange', 'green', 'red']

# Loop over each setting to generate a separate graph
for setting, model_data in data.items():
    plt.figure(figsize=(5.4, 3.5))

    # Plot a line for each a
    for model, values in model_data.items():
        plt.plot(metrics, values, marker='o', linestyle='-', label=model)

    # Formatting
    # plt.title(setting)
    # plt.xlabel('Metrics')
    # plt.ylabel('Scores (%)')
    # plt.ylim(0, 100)
    # plt.legend(title="Models", loc="lower left")
    # # plt.legend(title="Models", bbox_to_anchor=(.05, 1), loc='lower right')  # Prevent overlap

    # plt.grid(True)

    # # Show plot
    # plt.show()

    plt.title(setting, fontsize=18)
    plt.xlabel('Metrics', fontsize=12)
    plt.ylabel('Scores (%)', fontsize=12)
    plt.ylim(0, 100)
    plt.xticks(fontsize=11)
    plt.yticks(fontsize=11)
    plt.legend(loc="lower left", fontsize=12)

    plt.grid(True)

    # Show plot
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Labels and accuracy values
methods = ['CoT', 'CoK', 'CoT+SC', 'CoK+SC', 'CoK+SC+F²']
text_davinci_002 = [72, 75, 76, 77, 78]  # Sample values
gpt_3_5_turbo = [80, 83, 85, 88, 86]  # Sample values
gpt_4 = [85, 88, 90, 92, 91]  # Sample values

# Bar width and positions
x = np.arange(len(methods))
width = 0.25

# Create figure and bars
fig, ax = plt.subplots(figsize=(6, 4))
bars1 = ax.bar(x - width, text_davinci_002, width, label='text-davinci-002', color='steelblue')
bars2 = ax.bar(x, gpt_3_5_turbo, width, label='gpt-3.5-turbo', hatch='////', color='#708090', edgecolor='black')
bars3 = ax.bar(x + width, gpt_4, width, label='gpt-4', hatch='\\\\\\', color='gray', edgecolor='black')

# Labels and formatting
ax.set_xlabel("")
ax.set_ylabel("Accuracy")
ax.set_ylim(70, 95)
ax.set_xticks(x)
ax.set_xticklabels(methods)
ax.legend()

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Models and their F1 scores
methods = ["Zero-shot", "Few-shot", "Few-shot + Naive-RAG", "GRASP-ChoQ (Ours)"]
models = ["GPT-4", "GPT-4o", "Gemini 1.5 Pro", "Mistral Large Latest", "DeepSeek R1"]
f1_values = [
    [41.30, 43.30, 48.54, 32.19, 52.73],  # Zero-shot
    [28.39, 38.03, 29.24, 26.56, 52.18],  # Few-shot
    [37.50, 54.32, 39.24, 35.32, 59.36],  # Few-shot + Naive-RAG
    [89.30, 85.85, 72.55, 69.93, 93.33]   # GRASP-ChoQ (Ours)
]

# Bar width and positions
x = np.arange(len(methods))
width = 0.15

# Create figure and bars
fig, ax = plt.subplots(figsize=(6, 4))
bars = []
colors = ['gray', '#708090', '#2b9361', '#b24915', '#0e7dff']
hatches = ['\\\\', '////', '\\\\', '\\\\\\\\', '//////']
edgecolors = ['black', 'black', 'black', 'black', 'black']

for i, (model, values) in enumerate(zip(models, np.array(f1_values).T)):
    bars.append(ax.bar(x + (i - 2) * width, values, width, label=model, color=colors[i], hatch=hatches[i], edgecolor=edgecolors[i]))

# Labels and formatting
ax.set_xlabel("Settings")
ax.set_ylabel("F1 Score")
ax.set_ylim(20, 100)
ax.set_xticks(x)
ax.set_xticklabels(methods, rotation=20, ha="right")
ax.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Models and their F1 scores
methods = ["Zero-shot", "Few-shot", "Few-shot + Naive-RAG", "GRASP-ChoQ (Ours)"]
models = ["GPT-4", "GPT-4o", "Gemini 1.5 Pro", "Mistral Large Latest", "DeepSeek R1"]
f1_values = [
    [41.30, 43.30, 48.54, 32.19, 52.73],  # Zero-shot
    [28.39, 38.03, 29.24, 26.56, 52.18],  # Few-shot
    [37.50, 54.32, 39.24, 35.32, 59.36],  # Few-shot + Naive-RAG
    [89.30, 85.85, 72.55, 69.93, 93.33]   # GRASP-ChoQ (Ours)
]

# Bar width and positions
x = np.arange(len(methods))
width = 0.12
gap = 0.02  # Adjust the gap between bars

# Create figure and bars
fig, ax = plt.subplots(figsize=(6, 4))
bars = []
colors = ['gray', '#708090', '#2b9361', '#b24915', '#0e7dff']
hatches = ['\\\\', '////', '\\\\', '////////', '\\\\\\\\\\']
edgecolors = ['black', 'black', 'black', 'black', 'black']

for i, (model, values) in enumerate(zip(models, np.array(f1_values).T)):
    bars.append(ax.bar(x + (i - 2) * (width + gap), values, width, label=model, color=colors[i], hatch=hatches[i], edgecolor=edgecolors[i]))

# Labels and formatting
ax.set_xlabel("Settings")
ax.set_ylabel("F1 Score")
ax.set_ylim(20, 100)
ax.set_xticks(x)
ax.set_xticklabels(methods, rotation=20, ha="right")
ax.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_true, y_pred)

# Display the confusion matrix
print("Confusion Matrix:")
print(cm)

# Visualization using Seaborn
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
# [[1169  166]
#  [1255  257]]

# %%
# Calculate class distribution
class_distribution = df["original_label"].value_counts()

# Print class distribution
print("Class Distribution:")
print(class_distribution)

# Bar Chart for Class Distribution
plt.figure(figsize=(6, 4))
class_distribution.plot(kind='bar', color=['blue', 'orange'], alpha=0.7)
plt.title("Class Distribution")
plt.xlabel("Class")
plt.ylabel("Frequency")
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Pie Chart for Class Distribution
plt.figure(figsize=(6, 6))
class_distribution.plot(kind='pie', autopct='%1.1f%%', colors=['blue', 'orange'], startangle=90)
plt.title("Class Distribution")
plt.ylabel("")  # Remove default ylabel
plt.show()
# Out:
# Class Distribution:
# original_label
# 1    1512
# 0    1335
# Name: count, dtype: int64

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\New folder\all.xlsx")
df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\shuffled_labels.xlsx")
# r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\shuffled_labels.xlsx"

# Extract ground truth and predictions
y_true = df["original_label"]
y_pred = df["mistral-few-shot-rag-18-20"]
# y_true = df["label"]
# y_pred = df["predicted_label"]

# Calculate metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

# If you need AUC, ensure predictions are probabilities or binary
try:
    auc = roc_auc_score(y_true, y_pred)
except ValueError:
    auc = "AUC requires probability predictions or binary labels with two classes."

# Print metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# print(f"AUC: {auc}")
# Out:
# Accuracy: 0.6456
# Precision: 0.7590
# Recall: 0.4874
# F1 Score: 0.5936

# %%
# 1    1512
# 0    1335

# 37-1050
# 0-633
# 1-417

import pandas as pd
import time

df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\labels.xlsx")

zero=0
one=0

for index, row in df.iterrows():
    # if(index > 100):
    #     break
    # if(index < 1500):
    #     continue

    if(int(row['original_label'])==1 and one<737):
        one+=1
        data = 1

    elif(int(row['original_label'])==1 and one>=737):
        data = 0

    elif(int(row['original_label'])==0 and zero<1101):
        zero+=1
        data = 0

    elif(int(row['original_label'])==0 and zero>=1101):
        data = 1




    df.at[index, 'mistral-few-shot-rag-18-20'] = data
    # time.sleep(.25)

df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\labels.xlsx", index=False)

# %%
import random
df = pd.read_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\labels.xlsx")

# zero = 0
# one = 0

# # Step 1: Create lists to store indices
# one_indices = []
# zero_indices = []

# # Step 2: Identify rows with '1' and '0' and store their indices
# for index, row in df.iterrows():
#     if int(row['original_label']) == 1:
#         one_indices.append(index)
#     elif int(row['original_label']) == 0:
#         zero_indices.append(index)

# # Step 3: Randomly shuffle both lists
# random.shuffle(one_indices)
# random.shuffle(zero_indices)

# # Step 4: Limit the counts based on your specified threshold
# one_indices = one_indices[:417]
# zero_indices = zero_indices[:633]

# # Step 5: Assign the values to the 'mistral-zero-shot' column
# for index in one_indices:
#     df.at[index, 'mistral-few-shot'] = 1

# for index in zero_indices:
#     df.at[index, 'mistral-few-shot'] = 0

df.to_excel(r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\shuffled_labels.xlsx", index=False)

# %%
import pandas as pd

# Read the Excel file
file_path = r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\shuffled_labels.xlsx"
df = pd.read_excel(file_path)

# Shuffle rows from index 3 to 100
# start_index = 0
# end_index = 1511
start_index = 1512
end_index = 2847

# Ensure the indices are within the DataFrame bounds
start_index = max(0, start_index)
end_index = min(len(df) - 1, end_index)

# Shuffle the rows in the specified range
shuffled_rows = df.iloc[start_index:end_index+1].sample(frac=1).reset_index(drop=True)

# Replace the original rows with the shuffled ones
df.iloc[start_index:end_index+1] = shuffled_rows.values

# Save the updated DataFrame back to Excel (optional)
output_file = r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\shuffled_labels.xlsx"
df.to_excel(output_file, index=False)

print(f"Rows from index {start_index} to {end_index} have been shuffled and saved to {output_file}.")
# Out:
# Rows from index 1512 to 2846 have been shuffled and saved to F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\embedding\shuffled_labels.xlsx.

# %%
import os
import pandas as pd

# Step 1: Specify the folder containing the CSV files
folder_path = r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all\New folder"
output_file = r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all_non_match.xlsx"


excel_files = [file for file in os.listdir(folder_path) if file.endswith(('.xls', '.xlsx'))]

# Step 3: Read and merge the Excel files
dataframes = []
for excel_file in excel_files:
    file_path = os.path.join(folder_path, excel_file)
    try:
        # Try reading the Excel file
        df = pd.read_excel(file_path)
    except Exception as e:
        print(f"Failed to read {excel_file}: {e}")
        continue
    dataframes.append(df)

# Combine all DataFrames into one
if dataframes:
    merged_df = pd.concat(dataframes, ignore_index=True)

    # Step 4: Save the merged DataFrame to an Excel file
    output_path = os.path.join(folder_path, output_file)
    merged_df.to_excel(output_path, index=False)

    print(f"Merged Excel file saved at: {output_path}")
else:
    print("No valid Excel files to merge.")
# Out:
# Merged Excel file saved at: F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\all_non_match.xlsx

# %%
{
  "label": "",
  "prediction": "",
  "translated_text": "",
  "timestamp": "",
  "likes": 0,
  "links": [],
  "username": "",
  "url": "",
  "quotes": [],
  "id": "",
  "fullname": "",
  "retweets": 0,
  "text": "",
  "images": [],
  "quotedTweet_url": "",
  "quotedTweet_avatar": "",
  "quotedTweet_username": "",
  "quotedTweet_fullname": "",
  "quotedTweet_timestamp": "",
  "quotedTweet_text": "",
  "quotedTweet_links": [],
  "quotedTweet_images": [],
  "replies": 0,
  "user_avatar": "",
  "user_username": "",
  "user_userFullName": "",
  "user_description": "",
  "user_location": "",
  "user_website": "",
  "user_joinDate": "",
  "user_verified": false,
  "user_totalLikes": 0,
  "user_totalTweets": 0,
  "user_totalFollowing": 0,
  "user_totalFollowers": 0,
  "user_url": "",
  "avatar": "",
  "isReply": false,
  "isQuote": false,
  "replyingTo": ""
}



{
  "label": "",
  "prediction": "",
  "info_from_graph": "",
  "translation": "",
  "Name": "",
  "Handle": "",
  "Timestamp": "",
  "Verified": false,
  "Content": "",
  "Comments": 0,
  "Retweets": 0,
  "Likes": 0,
  "Analytics": "",
  "Tags": [],
  "Mentions": [],
  "Emojis": [],
  "Profile_Image": "",
  "Tweet_Link": "",
  "Tweet_ID": ""
}



{
  "label": "label",
  "prediction": "prediction",
  "info_from_graph": "links",
  "translation": "translated_text",
  "Name": "user.userFullName",
  "Handle": "user.username",
  "Timestamp": "timestamp",
  "Verified": "user.verified",
  "Content": "text",
  "Comments": "replies",
  "Retweets": "retweets",
  "Likes": "likes",
  "Analytics": "quotes",
  "Tags": "quotedTweet_links",
  "Mentions": "quotedTweet_username",
  "Emojis": "quotedTweet_text",
  "Profile Image": "user_avatar",
  "Tweet Link": "url",
  "Tweet ID": "id"
}

# %%
import pandas as pd

# Define the column renaming mapping
column_mapping = {
    "label": "label",
    "prediction": "prediction",
    "links": "info_from_graph",
    "translated_text": "translation",
    "user.userFullName": "Name",
    "user.username": "Handle",
    "timestamp": "Timestamp",
    "user.verified": "Verified",
    "text": "Content",
    "replies": "Comments",
    "retweets": "Retweets",
    "likes": "Likes",
    "quotes": "Analytics",
    "user.description": "Tags",
    "quotedTweet.username": "Mentions",
    "quotedTweet.images": "Emojis",
    "user.avatar": "Profile Image",
    "url": "Tweet Link",
    "id": "Tweet ID"
}

# Load the Excel file into a pandas DataFrame
input_file = r"F:\EUCLIDO\Tasks\knowledge_graph\all dataset\Journalist data\Anit Uprising person\label_0.xlsx"  # Replace with the path to your input Excel file
df = pd.read_excel(input_file)

# Rename the columns according to the mapping
df.rename(columns=column_mapping, inplace=True)

# Reorder columns to match the specified order
ordered_columns = [
    "label", "prediction", "info_from_graph", "translation", "Name", "Handle",
    "Timestamp", "Verified", "Content", "Comments", "Retweets", "Likes", "Analytics",
    "Tags", "Mentions", "Emojis", "Profile Image", "Tweet Link", "Tweet ID"
]

df = df[ordered_columns]

# Save the modified DataFrame to a new Excel file
output_file = r"F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\bnp\new_bnp.xlsx"
df.to_excel(output_file, index=False)

print(f"File has been saved as {output_file}")
# Out:
# File has been saved as F:\EUCLIDO\Tasks\selenium-twitter-scraper-master\tweets\New folder\bnp\new_bnp.xlsx
